# %%
import pandas as pd
import numpy as np
from math import sqrt
import os
import pysubgroup as ps

# %%
PATH: str = "../data/spadl_format/"
LEAGUES: list[str] = ["England", "Spain", "France", "Italy", "Germany"]

teams_df = pd.read_json("../data/wyscout/teams/teams.json")
players_df = pd.read_json("../data/wyscout/players/players.json")
ranking_df = pd.read_json('../data/wyscout/playeranks/playeranks.json')

df_dict = {}
if not os.path.exists("../data/processed/"):
    os.mkdir("../data/processed")
for league in LEAGUES:

    df = pd.read_csv(f"{PATH}{league}.csv", index_col=0)

    # remove not used columns
    df.drop(["original_event_id", "result_name","bodypart_id", "type_id"], inplace=True, axis=1)

    df_dict[league] = df
all_df = pd.concat([df for df in df_dict.values()])
all_df
# Out:
#         game_id  period_id  time_seconds  team_id  player_id  start_x  \
# 0       2499719          1      2.758649     1609      25413    51.45
# 1       2499719          1      4.946850     1609     370224    32.55
# 2       2499719          1      6.542188     1609       3319    53.55
# 3       2499719          1      8.143395     1609     120339    36.75
# 4       2499719          1     10.302366     1609     167145    43.05
# ...         ...        ...           ...      ...        ...      ...
# 389146  2517044          2   2817.761761     2463      94831    87.15
# 389147  2517044          2   2818.280436     2451      14917    17.85
# 389148  2517044          2   2823.180681     2451      14804    23.10
# 389149  2517044          2   2828.080925     2451      14804     0.00
# 389150  2517044          2   2829.509819     2463      15317    99.75
#
#         start_y   end_x  end_y  result_id  action_id     type_name  \
# 0         34.68   32.55  14.96          1          0          pass
# 1         14.96   53.55  17.00          1          1          pass
# 2         17.00   36.75  19.72          1          2          pass
# 3         19.72   43.05   3.40          1          3          pass
# 4          3.40   75.60   8.16          1          4          pass
# ...         ...     ...    ...        ...        ...           ...
# 389146    36.72   87.15  36.72          0       1148          shot
# 389147    31.96   23.10  27.20          1       1149  interception
# 389148    27.20    0.00   3.40          1       1150       dribble
# 389149     3.40    5.25   4.76          0       1151          pass
# 389150    63.24  105.00   0.00          1       1152  interception
#
#        bodypart_name        player_name
# 0               foot       A. Lacazette
# 1               foot         R. Holding
# 2               head            M. Özil
# 3               head     Mohamed Elneny
# 4               foot           Bellerín
# ...              ...                ...
# 389146    foot_right           Y. Ōsako
# 389147          foot          R. Knoche
# 389148          foot  J. Błaszczykowski
# 389149          foot  J. Błaszczykowski
# 389150          foot     L. Bittencourt
#
# [2320430 rows x 14 columns]

# %%
print(all_df["type_name"].unique())
# Out:
# ['pass' 'interception' 'dribble' 'take_on' 'tackle' 'foul'
#  'freekick_short' 'cross' 'shot' 'clearance' 'throw_in' 'goalkick'
#  'corner_short' 'corner_crossed' 'keeper_save' 'freekick_crossed'
#  'shot_freekick' 'bad_touch' 'shot_penalty']

# %% [markdown]
# ## Pre-process
#
# Falta decidir se posições serão float ou discretizadas.

# %%
GOAL_CENTER_X: int = 105
GOAL_CENTER_Y: int = 34

UPPER_CROSSBAR_X: int = 105
UPPER_CROSSBAR_Y: int = 38

LOWER_CROSSBAR_X: int = 105
LOWER_CROSSBAR_Y: int = 30


def get_shot_angle(shot_pos_x, shot_pos_y):
    v1 = np.array([UPPER_CROSSBAR_X - shot_pos_x, UPPER_CROSSBAR_Y - shot_pos_y])
    v2 = np.array([LOWER_CROSSBAR_X - shot_pos_x, LOWER_CROSSBAR_Y - shot_pos_y])
    return np.arccos(np.dot(v1 / np.linalg.norm(v1), v2 / np.linalg.norm(v2)))

def calcular_media_global():
    # Filtrar jogadores com dados válidos
    jogadores_validos = ranking_df[ranking_df['playerankScore'].notna()]
    media_global = np.sum(jogadores_validos['playerankScore'] * jogadores_validos['minutesPlayed']) / jogadores_validos['minutesPlayed'].sum()
    return media_global

media_rank_global = calcular_media_global()

def calcular_ranking_medio(player_id):
    jogador_rankings = ranking_df[ranking_df['playerId'] == player_id]
    if jogador_rankings.empty:
        return media_rank_global
    ranking_ponderado = np.sum(jogador_rankings['playerankScore'] * jogador_rankings['minutesPlayed']) / jogador_rankings['minutesPlayed'].sum()
    return ranking_ponderado

def calculate_distance(x1, y1, x2, y2):
    return sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)

def discretize_start_x(x):
    if x < 26.25:
        return 'defensive'
    elif x < 52.5:
        return 'pre-defensive'
    elif x < 78.75:
        return 'pre-attacking'
    else:
        return 'attacking'

def discretize_start_y(y):
    if y < 22.67:
        return 'left'
    elif y < 45.33:
        return 'center'
    else:
        return 'right'

def generate_shots_with_counts_events(df):
    shot_data = []
    result_ids = []
    grouped = df.groupby(['game_id', 'period_id'])
    
    for (game_id, period_id), group in grouped:
        group = group.sort_values(by='time_seconds').reset_index(drop=True)
        start_index = 0

        while start_index < len(group):
            shot_index = group[start_index:].index[group['type_name'][start_index:] == 'shot']
            if len(shot_index) == 0:
                break
            shot_index = shot_index[0]

            shot_row = group.loc[shot_index]
            play_events = group.loc[start_index:shot_index]
            
            for idx in play_events.index[::-1]:
                if play_events.loc[idx, 'team_id'] != shot_row['team_id']:
                    start_index = idx + 1
                    break
            else:
                start_index = play_events.index[0]

            play_events = group.loc[start_index:shot_index]

            player_rank = calcular_ranking_medio(shot_row['player_id'])
            
            play_distance = 0
            play_distance_towards_goal = 0
            play_distances_to_goal = []

            for i in range(1, len(play_events)):
                x1, y1 = play_events.iloc[i - 1][['start_x', 'start_y']]
                x2, y2 = play_events.iloc[i][['start_x', 'start_y']]
                dist = calculate_distance(x1, y1, x2, y2)
                play_distance += dist
                play_distance_towards_goal += x2 - x1
                play_distances_to_goal.append(sqrt((x2 - GOAL_CENTER_X) ** 2 + (y2 - GOAL_CENTER_Y) ** 2))

            if len(play_events) > 1:
                play_mean_distance_to_the_goal = np.mean(play_distances_to_goal)
                play_std_distance_to_the_goal = np.std(play_distances_to_goal)
            else:
                play_mean_distance_to_the_goal = 0
                play_std_distance_to_the_goal = 0

            play_duration = play_events['time_seconds'].iloc[-1] - play_events['time_seconds'].iloc[0]
            ratio_distance = play_distance_towards_goal / play_distance if play_distance != 0 else 0
            total_time_per_play = play_duration / len(play_events) if len(play_events) != 0 else 0
            play_speed = play_distance / play_duration if play_duration != 0 else 0
            play_speed_towards_goal = play_distance_towards_goal / play_duration if play_duration != 0 else 0

            shot_data.append({
                'game_id': game_id,
                'period_id': period_id,
                'team_id': shot_row['team_id'],
                'player_id': shot_row['player_id'],
                'time_seconds': shot_row['time_seconds'],
                'start_x': shot_row['start_x'],
                'start_y': shot_row['start_y'],
                # 'disc_start_x': discretize_start_x(shot_row['start_x']),
                # 'disc_start_y': discretize_start_y(shot_row['start_y']),
                'num_events': len(play_events),
                'num_passes': (play_events['type_name'] == 'pass').sum(),
                'num_dribbles': (play_events['type_name'] == 'dribble').sum(),
                'play_duration': play_duration,
                'player_rank': player_rank,
                'bodypart_name': shot_row['bodypart_name'],
                'play_distance': play_distance,
                'play_mean_distance_to_the_goal': play_mean_distance_to_the_goal,
                'play_std_distance_to_the_goal': play_std_distance_to_the_goal,
                'play_distance_towards_goal': play_distance_towards_goal,
                'ratio_distance': ratio_distance,
                'total_time_per_play': total_time_per_play,
                'play_speed': play_speed,
                'play_speed_towards_goal': play_speed_towards_goal,
            })

            result_ids.append(shot_row['result_id'])
            start_index = shot_index + 1

    shots_df = pd.DataFrame(shot_data)
    shots_df["shot_distance_from_goal"] = shots_df.apply(lambda x: sqrt((x["start_x"] - GOAL_CENTER_X)**2 + (x["start_y"] - GOAL_CENTER_Y)**2), axis=1)
    shots_df["shot_angle_from_goal"] = shots_df[["start_x", "start_y"]].apply(lambda pos: get_shot_angle(pos["start_x"], pos["start_y"]), axis=1)
    shots_df["result_id"] = result_ids
    return shots_df

shots_df = generate_shots_with_counts_events(all_df)

# %%
shots_df.head()
# Out:
#    game_id  period_id  team_id  player_id  time_seconds  start_x  start_y  \
# 0  2499719          1     1609      25413     94.595788    92.40    40.12
# 1  2499719          1     1631      26150    179.854785    89.25    32.64
# 2  2499719          1     1631      14763    254.745027   100.80    32.64
# 3  2499719          1     1609       7868    425.824035    85.05    45.56
# 4  2499719          1     1609       7868    815.462015    78.75    47.60
#
#    num_events  num_passes  num_dribbles  ...  play_mean_distance_to_the_goal  \
# 0           7           4             0  ...                       30.932864
# 1           2           0             0  ...                       15.808608
# 2           7           3             0  ...                       21.086920
# 3           6           3             1  ...                       57.591081
# 4           1           0             0  ...                        0.000000
#
#    play_std_distance_to_the_goal play_distance_towards_goal  ratio_distance  \
# 0                       8.413575                      24.15        0.154870
# 1                       0.000000                      -9.45       -0.258190
# 2                      12.262251                       4.20        0.034728
# 3                      22.443334                      75.60        0.783021
# 4                       0.000000                       0.00        0.000000
#
#    total_time_per_play  play_speed  play_speed_towards_goal  \
# 0             2.836950    7.852377                 1.216095
# 1             2.273328    8.050087                -2.078450
# 2             2.705084    6.386817                 0.221805
# 3             2.161246    7.445480                 5.829970
# 4             0.000000    0.000000                 0.000000
#
#    shot_distance_from_goal  shot_angle_from_goal  result_id
# 0                14.007655              0.509981          1
# 1                15.808608              0.494098          0
# 2                 4.414703              1.467310          1
# 3                23.057235              0.300168          0
# 4                29.563872              0.240030          0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Binary Goal/Not Goal

# %%
shots_df_cp = shots_df.copy()
shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.BinaryTarget('result_id', 1)

search_space = ps.create_selectors(shots_df_cp, ignore=['result_id'])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.WRAccQF())

# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)
result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(10).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# Quality: 0.031155481651607888
# Subgroup: shot_angle_from_goal>=0.60
# Size of Subgroup: 8189
# ----------------------------------------
# Quality: 0.030839137893783095
# Subgroup: shot_distance_from_goal<11.26
# Size of Subgroup: 8045
# ----------------------------------------
# Quality: 0.029720454021914134
# Subgroup: shot_angle_from_goal>=0.60 AND shot_distance_from_goal<11.26
# Size of Subgroup: 6797
# ----------------------------------------
# Quality: 0.02758813287621146
# Subgroup: shot_distance_from_goal<11.26 AND start_x>=96.60
# Size of Subgroup: 6127
# ----------------------------------------
# Quality: 0.0264073773750995
# Subgroup: shot_angle_from_goal>=0.60 AND start_x>=96.60
# Size of Subgroup: 5007
# ----------------------------------------
# Quality: 0.0264073773750995
# Subgroup: shot_angle_from_goal>=0.60 AND shot_distance_from_goal<11.26 AND start_x>=96.60
# Size of Subgroup: 5007
# ----------------------------------------
# Quality: 0.025837991718490057
# Subgroup: start_x>=96.60
# Size of Subgroup: 8522
# ----------------------------------------
# Quality: 0.02043518101198387
# Subgroup: num_dribbles: [0:1[ AND shot_distance_from_goal<11.26
# Size of Subgroup: 5752
# ----------------------------------------
# Quality: 0.020287986521196743
# Subgroup: num_dribbles: [0:1[ AND shot_angle_from_goal>=0.60
# Size of Subgroup: 5780
# ----------------------------------------
# Quality: 0.019697773086338598
# Subgroup: num_dribbles: [0:1[ AND shot_angle_from_goal>=0.60 AND shot_distance_from_goal<11.26
# Size of Subgroup: 4841
# ----------------------------------------
#      quality                                           subgroup  size_sg  \
# 0   0.031155                         shot_angle_from_goal>=0.60     8189
# 1   0.030839                      shot_distance_from_goal<11.26     8045
# 2   0.029720  shot_angle_from_goal>=0.60 AND shot_distance_f...     6797
# 3   0.027588   shot_distance_from_goal<11.26 AND start_x>=96.60     6127
# 4   0.026407      shot_angle_from_goal>=0.60 AND start_x>=96.60     5007
# ..       ...                                                ...      ...
# 95  0.008752  shot_distance_from_goal<11.26 AND total_time_p...     1439
# 96  0.008741  num_dribbles: [0:1[ AND shot_distance_from_goa...     1424
# 97  0.008726  play_speed>=9.72 AND shot_angle_from_goal>=0.6...     2576
# 98  0.008719  play_duration<1.34 AND shot_distance_from_goal...     1404
# 99  0.008670  play_speed_towards_goal: [0.0:0.74[ AND shot_a...     1243
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0          40461          2125               4271            32272
# 1          40461          2097               4271            32416
# 2          40461          1920               4271            33664
# 3          40461          1763               4271            34334
# 4          40461          1597               4271            35454
# ..           ...           ...                ...              ...
# 95         40461           506               4271            39022
# 96         40461           504               4271            39037
# 97         40461           625               4271            37885
# 98         40461           501               4271            39057
# 99         40461           482               4271            39218
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.202392                  0.797608     0.497542
# 1           0.198833                  0.801167     0.490986
# 2           0.167989                  0.832011     0.449543
# 3           0.151430                  0.848570     0.412784
# 4           0.123749                  0.876251     0.373917
# ..               ...                       ...          ...
# 95          0.035565                  0.964435     0.118473
# 96          0.035194                  0.964806     0.118005
# 97          0.063666                  0.936334     0.146336
# 98          0.034700                  0.965300     0.117303
# 99          0.030721                  0.969279     0.112854
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.502458         0.259494                 0.066497
# 1              0.509014         0.260659                 0.067066
# 2              0.550457         0.282478                 0.069837
# 3              0.587216         0.287743                 0.073047
# 4              0.626083         0.318953                 0.075422
# ..                  ...              ...                      ...
# 95             0.881527         0.351633                 0.096484
# 96             0.881995         0.353933                 0.096498
# 97             0.853664         0.242624                 0.096239
# 98             0.882697         0.356838                 0.096526
# 99             0.887146         0.387772                 0.096614
#
#     target_share_dataset      lift
# 0               0.105558  2.458301
# 1               0.105558  2.469332
# 2               0.105558  2.676030
# 3               0.105558  2.725910
# 4               0.105558  3.021582
# ..                   ...       ...
# 95              0.105558  3.331170
# 96              0.105558  3.352954
# 97              0.105558  2.298482
# 98              0.105558  3.380474
# 99              0.105558  3.673525
#
# [100 rows x 15 columns]

# %%
import pandas as pd

# Supondo que `result_df` é o DataFrame contendo os resultados dos subgrupos
# E que `shots_df_cp` é o dataframe original

def get_covered_indices(subgroup, df):
    """
    Retorna os índices dos registros no dataframe que são cobertos pelo subgrupo.
    """
    condition = subgroup.covers(df)
    return df[condition].index

# Lista para armazenar todos os índices cobertos
covered_indices = set()

# Iterar sobre os subgrupos e adicionar os índices cobertos ao conjunto
for sg_result in result.to_dataframe().itertuples():
    subgroup = sg_result.subgroup  # Ajuste conforme a coluna correta
    indices = get_covered_indices(subgroup, shots_df_cp)
    covered_indices.update(indices)
    print(len(covered_indices) / len(shots_df_cp))

# Cobertura total (proporção de registros cobertos)
total_coverage = len(covered_indices) / len(shots_df_cp)

print(f"Total Coverage: {total_coverage:.4f}")
# Out:
# 0.20239242727564816
# 0.23323694421788882
# 0.23323694421788882
# 0.23323694421788882
# 0.23323694421788882
# 0.23323694421788882
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# 0.5099231358592224
# Total Coverage: 0.5099

# %% [markdown]
# ## XG

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from xgboost import XGBClassifier

# %%
# constans
RANDOM_STATE: int = 123
TEST_SIZE: float  = 0.3

shots_df_cp = shots_df.copy()


# Random Forest Classifier
rfc = RandomForestClassifier(random_state=RANDOM_STATE)
X = shots_df_cp[["bodypart_name", "shot_distance_from_goal", "shot_angle_from_goal"]]
X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
y = shots_df_cp["result_id"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)
rfc.fit(X=X_train, y=y_train)
y_pred = rfc.predict(X=X_test)
classification_report(y_test, y_pred, output_dict=True)
# Out:
# /tmp/ipykernel_25122/1161188708.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
# {'0': {'precision': 0.9070434415858287,
#   'recall': 0.9876010286554004,
#   'f1-score': 0.9456096381304138,
#   'support': 10888.0},
#  '1': {'precision': 0.5246478873239436,
#   'recall': 0.11910471622701839,
#   'f1-score': 0.19413680781758957,
#   'support': 1251.0},
#  'accuracy': 0.8980970425899992,
#  'macro avg': {'precision': 0.7158456644548862,
#   'recall': 0.5533528724412095,
#   'f1-score': 0.5698732229740017,
#   'support': 12139.0},
#  'weighted avg': {'precision': 0.8676351840372977,
#   'recall': 0.8980970425899992,
#   'f1-score': 0.8681656550410867,
#   'support': 12139.0}}

# %%
shots_df_cp["xg"] = rfc.predict(X=X)

# %%
print("Comparação 0/1: ", shots_df_cp[shots_df_cp["xg"]==0].shape[0], " VS " , shots_df_cp[shots_df_cp["xg"]==1].shape[0])
# Out:
# Comparação 0/1:  39526  VS  935

# %%
shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.BinaryTarget('xg', 1)

search_space = ps.create_selectors(shots_df_cp, ignore=['xg'])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.WRAccQF())

# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)
result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(10).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    # print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# Quality: 0.018716662379767844
# Subgroup: shot_angle_from_goal>=0.60 AND start_x>=96.60
# ----------------------------------------
# Quality: 0.018716662379767844
# Subgroup: shot_angle_from_goal>=0.60 AND shot_distance_from_goal<11.26 AND start_x>=96.60
# ----------------------------------------
# Quality: 0.018398288803861684
# Subgroup: shot_distance_from_goal<11.26 AND start_x>=96.60
# ----------------------------------------
# Quality: 0.018238065116663007
# Subgroup: shot_angle_from_goal>=0.60 AND shot_distance_from_goal<11.26
# ----------------------------------------
# Quality: 0.017846586326198236
# Subgroup: shot_distance_from_goal<11.26
# ----------------------------------------
# Quality: 0.017443045908338128
# Subgroup: shot_angle_from_goal>=0.60
# ----------------------------------------
# Quality: 0.017079852018944016
# Subgroup: start_x>=96.60
# ----------------------------------------
# Quality: 0.01321760482222617
# Subgroup: start_x>=96.60 AND start_y: [31.96:37.40[
# ----------------------------------------
# Quality: 0.01321760482222617
# Subgroup: shot_distance_from_goal<11.26 AND start_x>=96.60 AND start_y: [31.96:37.40[
# ----------------------------------------
# Quality: 0.01321760482222617
# Subgroup: shot_angle_from_goal>=0.60 AND start_x>=96.60 AND start_y: [31.96:37.40[
# ----------------------------------------
#      quality                                           subgroup  size_sg  \
# 0   0.018717      shot_angle_from_goal>=0.60 AND start_x>=96.60     5007
# 1   0.018717  shot_angle_from_goal>=0.60 AND shot_distance_f...     5007
# 2   0.018398   shot_distance_from_goal<11.26 AND start_x>=96.60     6127
# 3   0.018238  shot_angle_from_goal>=0.60 AND shot_distance_f...     6797
# 4   0.017847                      shot_distance_from_goal<11.26     8045
# ..       ...                                                ...      ...
# 95  0.006342  play_distance_towards_goal: [0.0:7.35[ AND sta...     1662
# 96  0.006332  shot_distance_from_goal<11.26 AND start_x>=96....     1160
# 97  0.006317  ratio_distance: [0.0:0.12[ AND shot_angle_from...     1533
# 98  0.006316  play_duration<1.34 AND shot_distance_from_goal...     1187
# 99  0.006315  bodypart_name=='foot_right' AND num_dribbles: ...     1666
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0          40461           873                935            35454
# 1          40461           873                935            35454
# 2          40461           886                935            34334
# 3          40461           895                935            33664
# 4          40461           908                935            32416
# ..           ...           ...                ...              ...
# 95         40461           295                935            38799
# 96         40461           283                935            39301
# 97         40461           291                935            38928
# 98         40461           283                935            39274
# 99         40461           294                935            38795
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.123749                  0.876251     0.933690
# 1           0.123749                  0.876251     0.933690
# 2           0.151430                  0.848570     0.947594
# 3           0.167989                  0.832011     0.957219
# 4           0.198833                  0.801167     0.971123
# ..               ...                       ...          ...
# 95          0.041077                  0.958923     0.315508
# 96          0.028670                  0.971330     0.302674
# 97          0.037888                  0.962112     0.311230
# 98          0.029337                  0.970663     0.302674
# 99          0.041175                  0.958825     0.314439
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.066310         0.174356                 0.001749
# 1              0.066310         0.174356                 0.001749
# 2              0.052406         0.144606                 0.001427
# 3              0.042781         0.131676                 0.001188
# 4              0.028877         0.112865                 0.000833
# ..                  ...              ...                      ...
# 95             0.684492         0.177497                 0.016495
# 96             0.697326         0.243966                 0.016590
# 97             0.688770         0.189824                 0.016543
# 98             0.697326         0.238416                 0.016601
# 99             0.685561         0.176471                 0.016523
#
#     target_share_dataset       lift
# 0               0.023109   7.545042
# 1               0.023109   7.545042
# 2               0.023109   6.257644
# 3               0.023109   5.698109
# 4               0.023109   4.884103
# ..                   ...        ...
# 95              0.023109   7.680969
# 96              0.023109  10.557314
# 97              0.023109   8.214400
# 98              0.023109  10.317173
# 99              0.023109   7.636552
#
# [100 rows x 15 columns]

# %%
def get_covered_indices(subgroup, df):
    """
    Retorna os índices dos registros no dataframe que são cobertos pelo subgrupo.
    """
    condition = subgroup.covers(df)
    return df[condition].index

# Lista para armazenar todos os índices cobertos
covered_indices = set()

# Iterar sobre os subgrupos e adicionar os índices cobertos ao conjunto
for sg_result in result.to_dataframe().itertuples():
    subgroup = sg_result.subgroup  # Ajuste conforme a coluna correta
    indices = get_covered_indices(subgroup, shots_df_cp)
    covered_indices.update(indices)
    print(len(covered_indices) / len(shots_df_cp))

# Cobertura total (proporção de registros cobertos)
total_coverage = len(covered_indices) / len(shots_df_cp)

print(f"Total Coverage: {total_coverage:.4f}")
# Out:
# 0.12374879513605694
# 0.12374879513605694
# 0.15142977187909346
# 0.1956699043523393
# 0.19883344455154345
# 0.23323694421788882
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.29242974716393566
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.3967771434220608
# 0.5045599466152592
# 0.5045599466152592
# 0.5045599466152592
# 0.5045599466152592
# 0.5045599466152592
# 0.5045599466152592
# 0.5045599466152592
# 0.5045599466152592
# 0.5045599466152592
# 0.5045599466152592
# Total Coverage: 0.5046

# %% [markdown]
# ## VAEP

# %%
from tqdm import tqdm
import socceraction.spadl as spd
from socceraction.vaep import features as ft
import socceraction.vaep.labels as lab
import socceraction.vaep.formula as fm
import xgboost as xgb
import sklearn.metrics as mt

# %%
def features_transform(spadl):
    spadl.loc[spadl.result_id.isin([2, 3]), ["result_id"]] = 0
    spadl.loc[spadl.result_name.isin(["offside", "owngoal"]), ["result_name"]] = "fail"

    xfns = [
        ft.actiontype_onehot,
        ft.bodypart_onehot,
        ft.result_onehot,
        ft.goalscore,
        ft.startlocation,
        ft.endlocation,
        ft.team,
        ft.time,
        ft.time_delta
    ]

    features = []
    for game in tqdm(np.unique(spadl.game_id).tolist()):
        match_actions = spadl.loc[spadl.game_id == game].reset_index(drop=True)
        match_states = ft.gamestates(actions=match_actions)
        match_feats = pd.concat([fn(match_states) for fn in xfns], axis=1)
        features.append(match_feats)
    features = pd.concat(features).reset_index(drop=True)

    return features

def labels_transform(spadl):
    yfns = [lab.scores, lab.concedes]

    labels = []
    for game in tqdm(np.unique(spadl.game_id).tolist()):
        match_actions = spadl.loc[spadl.game_id == game].reset_index(drop=True)
        labels.append(pd.concat([fn(actions=match_actions) for fn in yfns], axis=1))

    labels = pd.concat(labels).reset_index(drop=True)

    return labels

def train_vaep(X_train, y_train, X_test, y_test):
    models = {}
    for m in ["scores", "concedes"]:
        models[m] = xgb.XGBClassifier(random_state=0, n_estimators=50, max_depth=3)

        print("training " + m + " model")
        models[m].fit(X_train, y_train[m])

        p = sum(y_train[m]) / len(y_train[m])
        base = [p] * len(y_train[m])
        y_train_pred = models[m].predict_proba(X_train)[:, 1]
        train_brier = mt.brier_score_loss(y_train[m], y_train_pred) / mt.brier_score_loss(y_train[m], base)
        print(m + " Train NBS: " + str(train_brier))
        print()

        p = sum(y_test[m]) / len(y_test[m])
        base = [p] * len(y_test[m])
        y_test_pred = models[m].predict_proba(X_test)[:, 1]
        test_brier = mt.brier_score_loss(y_test[m], y_test_pred) / mt.brier_score_loss(y_test[m], base)
        print(m + " Test NBS: " + str(test_brier))
        print()

        print("----------------------------------------")

    return models

def generate_predictions(features, models):
    preds = {}
    for m in ["scores", "concedes"]:
        preds[m] = models[m].predict_proba(features)[:, 1]
    preds = pd.DataFrame(preds)

    return preds

def calculate_action_values(spadl, predictions):
    action_values = fm.value(actions=spadl, Pscores=predictions["scores"], Pconcedes=predictions["concedes"])
    action_values = pd.concat([
        spadl[["original_event_id", "player_id", "action_id", "game_id", "start_x", "start_y", "end_x", "end_y", "type_name", "result_name"]],
        predictions.rename(columns={"scores": "Pscores", "concedes": "Pconcedes"}),
        action_values
    ], axis=1)

    return action_values

# %%
spadl = {}
for league in LEAGUES:
    spadl[league] = pd.read_csv(f"../data/spadl_format/{league}.csv")

features = {}
for league in LEAGUES:
    features[league] = features_transform(spadl[league])

labels = {}
for league in LEAGUES:
    labels[league] = labels_transform(spadl[league])

models = train_vaep(X_train=features["England"], y_train=labels["England"], X_test=features["Spain"], y_test=labels["Spain"])
# Out:
# 100%|██████████| 380/380 [00:06<00:00, 62.27it/s]
# 100%|██████████| 380/380 [00:06<00:00, 62.92it/s]
# 100%|██████████| 380/380 [00:06<00:00, 62.88it/s]
# 100%|██████████| 380/380 [00:06<00:00, 62.03it/s]
# 100%|██████████| 306/306 [00:04<00:00, 62.03it/s]
# 100%|██████████| 380/380 [00:07<00:00, 53.84it/s]
# 100%|██████████| 380/380 [00:07<00:00, 54.03it/s]
# 100%|██████████| 380/380 [00:07<00:00, 54.10it/s]
# 100%|██████████| 380/380 [00:07<00:00, 53.77it/s]
# 100%|██████████| 306/306 [00:05<00:00, 54.47it/s]
# training scores model
# scores Train NBS: 0.8452471194228581
#
# scores Test NBS: 0.8503677630926355
#
# ----------------------------------------
# training concedes model
# concedes Train NBS: 0.9660641623881886
#
# concedes Test NBS: 0.9766251611701147
#
# ----------------------------------------

# %%
preds = {}
action_values = {}

for league in LEAGUES:
    preds[league] = generate_predictions(features=features[league], models=models)
    action_values[league] = calculate_action_values(spadl=spadl[league], predictions=preds[league])

all_action_values = pd.concat([df for df in action_values.values()])

# %%
shots_df
# Out:
#        game_id  period_id  team_id  player_id  time_seconds  start_x  start_y  \
# 0      2499719          1     1609      25413     94.595788    92.40    40.12
# 1      2499719          1     1631      26150    179.854785    89.25    32.64
# 2      2499719          1     1631      14763    254.745027   100.80    32.64
# 3      2499719          1     1609       7868    425.824035    85.05    45.56
# 4      2499719          1     1609       7868    815.462015    78.75    47.60
# ...        ...        ...      ...        ...           ...      ...      ...
# 40456  2576338          2     3193     116269   1152.032980    99.75    37.40
# 40457  2576338          2     3193       3548   1251.730517    97.65    42.16
# 40458  2576338          2     3193      21177   2065.034482    94.50    36.72
# 40459  2576338          2     3193     349102   2367.252041    82.95    46.24
# 40460  2576338          2     3193      21177   2579.867806    97.65    38.76
#
#        num_events  num_passes  num_dribbles  ...  \
# 0               7           4             0  ...
# 1               2           0             0  ...
# 2               7           3             0  ...
# 3               6           3             1  ...
# 4               1           0             0  ...
# ...           ...         ...           ...  ...
# 40456           9           5             2  ...
# 40457          20          16             2  ...
# 40458           1           0             0  ...
# 40459           3           2             0  ...
# 40460           5           3             0  ...
#
#        play_mean_distance_to_the_goal  play_std_distance_to_the_goal  \
# 0                           30.932864                       8.413575
# 1                           15.808608                       0.000000
# 2                           21.086920                      12.262251
# 3                           57.591081                      22.443334
# 4                            0.000000                       0.000000
# ...                               ...                            ...
# 40456                       25.291699                      10.312188
# 40457                       52.186433                      19.477819
# 40458                        0.000000                       0.000000
# 40459                       27.824216                       2.604777
# 40460                       30.394597                      16.972596
#
#       play_distance_towards_goal  ratio_distance  total_time_per_play  \
# 0                          24.15        0.154870             2.836950
# 1                          -9.45       -0.258190             2.273328
# 2                           4.20        0.034728             2.705084
# 3                          75.60        0.783021             2.161246
# 4                           0.00        0.000000             0.000000
# ...                          ...             ...                  ...
# 40456                      28.35        0.174816             2.465061
# 40457                      75.60        0.262006             2.510138
# 40458                       0.00        0.000000             0.000000
# 40459                       6.30        0.133757             2.367156
# 40460                      56.70        0.848388             1.793403
#
#        play_speed  play_speed_towards_goal  shot_distance_from_goal  \
# 0        7.852377                 1.216095                14.007655
# 1        8.050087                -2.078450                15.808608
# 2        6.386817                 0.221805                 4.414703
# 3        7.445480                 5.829970                23.057235
# 4        0.000000                 0.000000                29.563872
# ...           ...                      ...                      ...
# 40456    7.309718                 1.277859                 6.254798
# 40457    5.747561                 1.505893                10.982172
# 40458    0.000000                 0.000000                10.846585
# 40459    6.632500                 0.887140                25.219439
# 40460    7.453159                 6.323174                 8.756717
#
#        shot_angle_from_goal  result_id
# 0                  0.509981          1
# 1                  0.494098          0
# 2                  1.467310          1
# 3                  0.300168          0
# 4                  0.240030          0
# ...                     ...        ...
# 40456              1.067542          0
# 40457              0.512084          0
# 40458              0.690619          1
# 40459              0.277183          0
# 40460              0.769664          0
#
# [40461 rows x 24 columns]

# %%
all_action_values
# Out:
#         original_event_id  player_id  action_id  game_id  start_x  start_y  \
# 0             177959171.0      25413          0  2499719    51.45    34.68
# 1             177959172.0     370224          1  2499719    32.55    14.96
# 2             177959173.0       3319          2  2499719    53.55    17.00
# 3             177959174.0     120339          3  2499719    36.75    19.72
# 4             177959175.0     167145          4  2499719    43.05     3.40
# ...                   ...        ...        ...      ...      ...      ...
# 389146        251206865.0      94831       1148  2517044    87.15    36.72
# 389147        251206783.0      14917       1149  2517044    17.85    31.96
# 389148                NaN      14804       1150  2517044    23.10    27.20
# 389149        251206790.0      14804       1151  2517044     0.00     3.40
# 389150        251206869.0      15317       1152  2517044    99.75    63.24
#
#          end_x  end_y     type_name result_name   Pscores  Pconcedes  \
# 0        32.55  14.96          pass     success  0.003555   0.000560
# 1        53.55  17.00          pass     success  0.004460   0.000536
# 2        36.75  19.72          pass     success  0.005223   0.000446
# 3        43.05   3.40          pass     success  0.002345   0.000363
# 4        75.60   8.16          pass     success  0.005549   0.000346
# ...        ...    ...           ...         ...       ...        ...
# 389146   87.15  36.72          shot        fail  0.014503   0.009633
# 389147   23.10  27.20  interception     success  0.005530   0.017490
# 389148    0.00   3.40       dribble     success  0.004298   0.008181
# 389149    5.25   4.76          pass        fail  0.002736   0.014004
# 389150  105.00   0.00  interception     success  0.012323   0.004432
#
#         offensive_value  defensive_value  vaep_value
# 0              0.000000        -0.000000    0.000000
# 1              0.000905         0.000024    0.000928
# 2              0.000764         0.000090    0.000854
# 3             -0.002879         0.000083   -0.002795
# 4              0.003204         0.000017    0.003221
# ...                 ...              ...         ...
# 389146         0.007984        -0.002125    0.005859
# 389147        -0.004103        -0.002987   -0.007090
# 389148        -0.001233         0.009310    0.008077
# 389149        -0.001561        -0.005823   -0.007385
# 389150        -0.001681        -0.001695   -0.003376
#
# [2320430 rows x 15 columns]

# %%
shots_df_cp = shots_df.copy()
all_action_values_cp = all_action_values.copy()
all_action_values_cp.drop(["original_event_id", "result_name", "action_id", "type_name"], inplace=True, axis=1)

shots_df_cp = shots_df_cp.merge(all_action_values_cp, on=['game_id', 'player_id', 'start_x', 'start_y'], how='left')

shots_df_cp
# Out:
#        game_id  period_id  team_id  player_id  time_seconds  start_x  start_y  \
# 0      2499719          1     1609      25413     94.595788    92.40    40.12
# 1      2499719          1     1631      26150    179.854785    89.25    32.64
# 2      2499719          1     1631      14763    254.745027   100.80    32.64
# 3      2499719          1     1609       7868    425.824035    85.05    45.56
# 4      2499719          1     1609       7868    815.462015    78.75    47.60
# ...        ...        ...      ...        ...           ...      ...      ...
# 40778  2576338          2     3193     116269   1152.032980    99.75    37.40
# 40779  2576338          2     3193       3548   1251.730517    97.65    42.16
# 40780  2576338          2     3193      21177   2065.034482    94.50    36.72
# 40781  2576338          2     3193     349102   2367.252041    82.95    46.24
# 40782  2576338          2     3193      21177   2579.867806    97.65    38.76
#
#        num_events  num_passes  num_dribbles  ...  shot_distance_from_goal  \
# 0               7           4             0  ...                14.007655
# 1               2           0             0  ...                15.808608
# 2               7           3             0  ...                 4.414703
# 3               6           3             1  ...                23.057235
# 4               1           0             0  ...                29.563872
# ...           ...         ...           ...  ...                      ...
# 40778           9           5             2  ...                 6.254798
# 40779          20          16             2  ...                10.982172
# 40780           1           0             0  ...                10.846585
# 40781           3           2             0  ...                25.219439
# 40782           5           3             0  ...                 8.756717
#
#        shot_angle_from_goal result_id  end_x    end_y   Pscores  Pconcedes  \
# 0                  0.509981         1  105.0  37.4000  0.978135   0.002137
# 1                  0.494098         0  105.0  40.8000  0.018184   0.007322
# 2                  1.467310         1  105.0  34.0000  0.977107   0.002290
# 3                  0.300168         0  105.0  40.8000  0.021434   0.002819
# 4                  0.240030         0  105.0  37.4000  0.017245   0.005117
# ...                     ...       ...    ...      ...       ...        ...
# 40778              1.067542         0  105.0  40.8000  0.034776   0.009745
# 40779              0.512084         0  105.0  40.8000  0.029877   0.010725
# 40780              0.690619         1  105.0  34.0000  0.977372   0.007182
# 40781              0.277183         0  105.0  40.8000  0.015293   0.006782
# 40782              0.769664         0  105.0  30.3416  0.046821   0.008009
#
#        offensive_value  defensive_value  vaep_value
# 0             0.902766        -0.000387    0.902379
# 1            -0.020396        -0.003519   -0.023916
# 2             0.885530         0.000666    0.886196
# 3            -0.004685        -0.001744   -0.006429
# 4            -0.019283        -0.002159   -0.021442
# ...                ...              ...         ...
# 40778        -0.081321        -0.004355   -0.085676
# 40779        -0.052057        -0.005569   -0.057625
# 40780         0.950002        -0.002297    0.947704
# 40781        -0.020930        -0.003574   -0.024504
# 40782        -0.062798        -0.004205   -0.067003
#
# [40783 rows x 31 columns]

# %%
print(min(np.unique(shots_df_cp['Pscores'].tolist())), max(np.unique(shots_df_cp['Pscores'].tolist())))
# Out:
# 0.0024156407453119755 0.9968808889389038

# %%
shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id", "end_x", "end_y"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.NumericTarget('Pscores')

search_space = ps.create_selectors(shots_df_cp, ignore=["Pscores", "Pconcedes", "offensive_value", "defensive_value", "vaep_value"])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.StandardQFNumeric(1.0))
# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)

result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(10).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    # print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

print(result.to_dataframe().shape)
# Out:
# Quality: 1259.5690176784992
# Subgroup: shot_angle_from_goal>=0.60
# ----------------------------------------
# Quality: 1246.4595663398504
# Subgroup: shot_distance_from_goal<11.26
# ----------------------------------------
# Quality: 1193.3499402701855
# Subgroup: shot_angle_from_goal>=0.60 AND shot_distance_from_goal<11.26
# ----------------------------------------
# Quality: 1106.3482034951448
# Subgroup: shot_distance_from_goal<11.26 AND start_x>=96.60
# ----------------------------------------
# Quality: 1053.5573259294033
# Subgroup: start_x>=96.60
# ----------------------------------------
# Quality: 1052.0391435921192
# Subgroup: shot_angle_from_goal>=0.60 AND start_x>=96.60
# ----------------------------------------
# Quality: 1052.0391435921192
# Subgroup: shot_angle_from_goal>=0.60 AND shot_distance_from_goal<11.26 AND start_x>=96.60
# ----------------------------------------
# Quality: 828.5282593220472
# Subgroup: num_dribbles: [0:1[ AND shot_distance_from_goal<11.26
# ----------------------------------------
# Quality: 821.9569552987814
# Subgroup: num_dribbles: [0:1[ AND shot_angle_from_goal>=0.60
# ----------------------------------------
# Quality: 792.7847557067871
# Subgroup: num_dribbles: [0:1[ AND shot_angle_from_goal>=0.60 AND shot_distance_from_goal<11.26
# ----------------------------------------
# (100, 16)

# %%
result.to_dataframe()
# Out:
#         quality                                           subgroup  size_sg  \
# 0   1259.569018                         shot_angle_from_goal>=0.60     8242
# 1   1246.459566                      shot_distance_from_goal<11.26     8083
# 2   1193.349940  shot_angle_from_goal>=0.60 AND shot_distance_f...     6834
# 3   1106.348203   shot_distance_from_goal<11.26 AND start_x>=96.60     6147
# 4   1053.557326                                     start_x>=96.60     8562
# ..          ...                                                ...      ...
# 95   350.894941  play_speed_towards_goal: [0.0:0.75[ AND ratio_...     1429
# 96   350.812498    play_speed>=9.71 AND shot_angle_from_goal>=0.60     3033
# 97   349.976713  play_duration<1.34 AND shot_distance_from_goal...     1418
# 98   349.324554  play_duration<1.34 AND play_std_distance_to_th...     1445
# 99   348.193042  play_distance_towards_goal: [0.0:7.35[ AND pla...     1319
#
#     size_dataset   mean_sg  mean_dataset    std_sg  std_dataset  median_sg  \
# 0          40783  0.278054      0.125231  0.414101     0.292654   0.036029
# 1          40783  0.279438      0.125231  0.414796     0.292654   0.036144
# 2          40783  0.299850      0.125231  0.425310     0.292654   0.036719
# 3          40783  0.305213      0.125231  0.427922     0.292654   0.036634
# 4          40783  0.248281      0.125231  0.396757     0.292654   0.034972
# ..           ...       ...           ...       ...          ...        ...
# 95         40783  0.370784      0.125231  0.452545     0.292654   0.040042
# 96         40783  0.240896      0.125231  0.391269     0.292654   0.035133
# 97         40783  0.372041      0.125231  0.452245     0.292654   0.040868
# 98         40783  0.366978      0.125231  0.450838     0.292654   0.040675
# 99         40783  0.389213      0.125231  0.457275     0.292654   0.041158
#
#     median_dataset    max_sg  max_dataset    min_sg  min_dataset  mean_lift  \
# 0         0.026238  0.995717     0.996881  0.009808     0.002416   2.220332
# 1         0.026238  0.995717     0.996881  0.012183     0.002416   2.231386
# 2         0.026238  0.995717     0.996881  0.012183     0.002416   2.394381
# 3         0.026238  0.995717     0.996881  0.013894     0.002416   2.437200
# 4         0.026238  0.995717     0.996881  0.007717     0.002416   1.982588
# ..             ...       ...          ...       ...          ...        ...
# 95        0.026238  0.990374     0.996881  0.016980     0.002416   2.960801
# 96        0.026238  0.993340     0.996881  0.009808     0.002416   1.923616
# 97        0.026238  0.990374     0.996881  0.015709     0.002416   2.970841
# 98        0.026238  0.990374     0.996881  0.016980     0.002416   2.930412
# 99        0.026238  0.990536     0.996881  0.014663     0.002416   3.107968
#
#     median_lift
# 0      1.373161
# 1      1.377538
# 2      1.399457
# 3      1.396204
# 4      1.332886
# ..          ...
# 95     1.526107
# 96     1.338999
# 97     1.557601
# 98     1.550230
# 99     1.568658
#
# [100 rows x 16 columns]

# %%
def get_covered_indices(subgroup, df):
    # Verifica se a condição cobre algum registro
    condition = subgroup.covers(df)
    return df[condition].index

# Lista para armazenar todos os índices cobertos
covered_indices = set()

# Iterar sobre os subgrupos e adicionar os índices cobertos ao conjunto
for sg_result in result.to_dataframe().itertuples():
    subgroup = sg_result.subgroup
    indices = get_covered_indices(subgroup, shots_df_cp)
    covered_indices.update(indices)
    print(len(covered_indices) / len(shots_df_cp))

# Cobertura total (proporção de registros cobertos)
total_coverage = len(covered_indices) / len(shots_df_cp)

print(f"Total Coverage: {total_coverage:.4f}")
# Out:
# 0.20209400975896818
# 0.232719515484393
# 0.232719515484393
# 0.232719515484393
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.2919353652257068
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.39616997278277716
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# 0.5098693082902189
# Total Coverage: 0.5099

# %%
result.to_dataframe().head()
# Out:
#        quality                                           subgroup  size_sg  \
# 0  1259.569018                         shot_angle_from_goal>=0.60     8242
# 1  1246.459566                      shot_distance_from_goal<11.26     8083
# 2  1193.349940  shot_angle_from_goal>=0.60 AND shot_distance_f...     6834
# 3  1106.348203   shot_distance_from_goal<11.26 AND start_x>=96.60     6147
# 4  1053.557326                                     start_x>=96.60     8562
#
#    size_dataset   mean_sg  mean_dataset    std_sg  std_dataset  median_sg  \
# 0         40783  0.278054      0.125231  0.414101     0.292654   0.036029
# 1         40783  0.279438      0.125231  0.414796     0.292654   0.036144
# 2         40783  0.299850      0.125231  0.425310     0.292654   0.036719
# 3         40783  0.305213      0.125231  0.427922     0.292654   0.036634
# 4         40783  0.248281      0.125231  0.396757     0.292654   0.034972
#
#    median_dataset    max_sg  max_dataset    min_sg  min_dataset  mean_lift  \
# 0        0.026238  0.995717     0.996881  0.009808     0.002416   2.220332
# 1        0.026238  0.995717     0.996881  0.012183     0.002416   2.231386
# 2        0.026238  0.995717     0.996881  0.012183     0.002416   2.394381
# 3        0.026238  0.995717     0.996881  0.013894     0.002416   2.437200
# 4        0.026238  0.995717     0.996881  0.007717     0.002416   1.982588
#
#    median_lift
# 0     1.373161
# 1     1.377538
# 2     1.399457
# 3     1.396204
# 4     1.332886

# %% [markdown]
# ## Análise Uma liga VS Outra Liga

# %% [markdown]
# #### Pre-process

# %%
England_df = pd.read_csv(f"{PATH}England.csv", index_col=0)
England_df.drop(["original_event_id", "result_name","bodypart_id", "type_id"], inplace=True, axis=1)
England_shots_df = generate_shots_with_counts_events(England_df)


Spain_df = pd.read_csv(f"{PATH}Spain.csv", index_col=0)
Spain_df.drop(["original_event_id", "result_name","bodypart_id", "type_id"], inplace=True, axis=1)
Spain_shots_df = generate_shots_with_counts_events(Spain_df)

# %% [markdown]
# ### Binário

# %%
England_shots_df_cp = England_shots_df.copy()
England_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.BinaryTarget('result_id', 1)

search_space = ps.create_selectors(England_shots_df_cp, ignore=['result_id'])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(England_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.WRAccQF())

# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)
result = search_algorithm.execute(task)

# # Exibir os resultados
for sg_result in result.to_dataframe().head(10).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    print(f"Size of Subgroup: {sg_result.size_sg}")
#     print(f"Size of Dataset: {sg_result.size_dataset}")
#     print(f"Positives in Subgroup: {sg_result.positives_sg}")
#     print(f"Positives in Dataset: {sg_result.positives_dataset}")
#     print(f"Size of Complement: {sg_result.size_complement}")
#     print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
#     print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
#     print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
#     print(f"Coverage of Complement: {sg_result.coverage_complement}")
#     print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
#     print(f"Target Share in Complement: {sg_result.target_share_complement}")
#     print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
#     print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# Quality: 0.03192391658395455
# Subgroup: shot_angle_from_goal>=0.61
# Size of Subgroup: 1694
# ----------------------------------------
# Quality: 0.03192076617948671
# Subgroup: shot_distance_from_goal<11.26
# Size of Subgroup: 1685
# ----------------------------------------
# Quality: 0.030326171455848525
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.26
# Size of Subgroup: 1449
# ----------------------------------------
# Quality: 0.02862860751240409
# Subgroup: shot_distance_from_goal<11.26 AND start_x>=96.60
# Size of Subgroup: 1332
# ----------------------------------------
# Quality: 0.027164565549912693
# Subgroup: start_x>=96.60
# Size of Subgroup: 1807
# ----------------------------------------
# Quality: 0.0270340127887659
# Subgroup: shot_angle_from_goal>=0.61 AND start_x>=96.60
# Size of Subgroup: 1096
# ----------------------------------------
# Quality: 0.0270340127887659
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.26 AND start_x>=96.60
# Size of Subgroup: 1096
# ----------------------------------------
# Quality: 0.02187498044123893
# Subgroup: num_dribbles: [0:1[ AND shot_distance_from_goal<11.26
# Size of Subgroup: 1194
# ----------------------------------------
# Quality: 0.02097953747889876
# Subgroup: num_dribbles: [0:1[ AND shot_angle_from_goal>=0.61
# Size of Subgroup: 1190
# ----------------------------------------
# Quality: 0.020551894575536973
# Subgroup: num_dribbles: [0:1[ AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.26
# Size of Subgroup: 1020
# ----------------------------------------
#      quality                                           subgroup  size_sg  \
# 0   0.031924                         shot_angle_from_goal>=0.61     1694
# 1   0.031921                      shot_distance_from_goal<11.26     1685
# 2   0.030326  shot_angle_from_goal>=0.61 AND shot_distance_f...     1449
# 3   0.028629   shot_distance_from_goal<11.26 AND start_x>=96.60     1332
# 4   0.027165                                     start_x>=96.60     1807
# ..       ...                                                ...      ...
# 95  0.009279  num_dribbles: [0:1[ AND shot_distance_from_goa...      292
# 96  0.009270  player_rank>=0.02 AND shot_distance_from_goal<...      302
# 97  0.009235  play_distance_towards_goal: [0.0:6.30[ AND pla...      277
# 98  0.009203  play_speed_towards_goal: [0.0:0.59[ AND ratio_...      298
# 99  0.009174  play_std_distance_to_the_goal: [0.0:2.04[ AND ...      291
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0           8451           453                914             6757
# 1           8451           452                914             6766
# 2           8451           413                914             7002
# 3           8451           386                914             7119
# 4           8451           425                914             6644
# ..           ...           ...                ...              ...
# 95          8451           110                914             8159
# 96          8451           111                914             8149
# 97          8451           108                914             8174
# 98          8451           110                914             8153
# 99          8451           109                914             8160
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.200450                  0.799550     0.495624
# 1           0.199385                  0.800615     0.494530
# 2           0.171459                  0.828541     0.451860
# 3           0.157614                  0.842386     0.422319
# 4           0.213821                  0.786179     0.464989
# ..               ...                       ...          ...
# 95          0.034552                  0.965448     0.120350
# 96          0.035735                  0.964265     0.121444
# 97          0.032777                  0.967223     0.118162
# 98          0.035262                  0.964738     0.120350
# 99          0.034434                  0.965566     0.119256
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.504376         0.267414                 0.068226
# 1              0.505470         0.268249                 0.068283
# 2              0.548140         0.285024                 0.071551
# 3              0.577681         0.289790                 0.074168
# 4              0.535011         0.235196                 0.073600
# ..                  ...              ...                      ...
# 95             0.879650         0.376712                 0.098541
# 96             0.878556         0.367550                 0.098540
# 97             0.881838         0.389892                 0.098605
# 98             0.879650         0.369128                 0.098614
# 99             0.880744         0.374570                 0.098652
#
#     target_share_dataset      lift
# 0               0.108153  2.472559
# 1               0.108153  2.480278
# 2               0.108153  2.635382
# 3               0.108153  2.679446
# 4               0.108153  2.174667
# ..                   ...       ...
# 95              0.108153  3.483146
# 96              0.108153  3.398427
# 97              0.108153  3.605005
# 98              0.108153  3.413016
# 99              0.108153  3.463342
#
# [100 rows x 15 columns]

# %%
def show_coverage(result, df):# Lista para armazenar todos os índices cobertos
    covered_indices = set()

    # Iterar sobre os subgrupos e adicionar os índices cobertos ao conjunto
    for sg_result in result.to_dataframe().itertuples():
        subgroup = sg_result.subgroup  # Ajuste conforme a coluna correta
        indices = get_covered_indices(subgroup, df)
        covered_indices.update(indices)
        print(len(covered_indices) / len(df))

    # Cobertura total (proporção de registros cobertos)
    total_coverage = len(covered_indices) / len(df)

    print(f"Total Coverage: {total_coverage:.4f}")

show_coverage(result, England_shots_df_cp)
# Out:
# 0.20044965092888414
# 0.22837534019642647
# 0.22837534019642647
# 0.22837534019642647
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# 0.49804756833510827
# Total Coverage: 0.4980

# %%
Spain_shots_df_cp = Spain_shots_df.copy()
Spain_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.BinaryTarget('result_id', 1)

search_space = ps.create_selectors(Spain_shots_df_cp, ignore=['result_id'])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(Spain_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.WRAccQF())

# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)
result = search_algorithm.execute(task)

# # Exibir os resultados
for sg_result in result.to_dataframe().head(10).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    print(f"Size of Subgroup: {sg_result.size_sg}")
#     print(f"Size of Dataset: {sg_result.size_dataset}")
#     print(f"Positives in Subgroup: {sg_result.positives_sg}")
#     print(f"Positives in Dataset: {sg_result.positives_dataset}")
#     print(f"Size of Complement: {sg_result.size_complement}")
#     print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
#     print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
#     print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
#     print(f"Coverage of Complement: {sg_result.coverage_complement}")
#     print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
#     print(f"Target Share in Complement: {sg_result.target_share_complement}")
#     print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
#     print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# Quality: 0.030671627196098374
# Subgroup: shot_distance_from_goal<11.04
# Size of Subgroup: 1582
# ----------------------------------------
# Quality: 0.030533135443692964
# Subgroup: shot_angle_from_goal>=0.61
# Size of Subgroup: 1601
# ----------------------------------------
# Quality: 0.029297500625192017
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# Size of Subgroup: 1347
# ----------------------------------------
# Quality: 0.02877760286939455
# Subgroup: shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 1231
# ----------------------------------------
# Quality: 0.027403476298488192
# Subgroup: shot_angle_from_goal>=0.61 AND start_x>=96.60
# Size of Subgroup: 996
# ----------------------------------------
# Quality: 0.027403476298488192
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 996
# ----------------------------------------
# Quality: 0.026542634686763367
# Subgroup: start_x>=96.60
# Size of Subgroup: 1753
# ----------------------------------------
# Quality: 0.019402086637342813
# Subgroup: num_dribbles: [0:1[ AND shot_distance_from_goal<11.04
# Size of Subgroup: 1139
# ----------------------------------------
# Quality: 0.0190433934698335
# Subgroup: num_dribbles: [0:1[ AND shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 876
# ----------------------------------------
# Quality: 0.018887607919152234
# Subgroup: num_dribbles: [0:1[ AND shot_angle_from_goal>=0.61
# Size of Subgroup: 1158
# ----------------------------------------
#      quality                                           subgroup  size_sg  \
# 0   0.030672                      shot_distance_from_goal<11.04     1582
# 1   0.030533                         shot_angle_from_goal>=0.61     1601
# 2   0.029298  shot_angle_from_goal>=0.61 AND shot_distance_f...     1347
# 3   0.028778   shot_distance_from_goal<11.04 AND start_x>=96.60     1231
# 4   0.027403      shot_angle_from_goal>=0.61 AND start_x>=96.60      996
# ..       ...                                                ...      ...
# 95  0.008452       num_events>=8 AND shot_angle_from_goal>=0.61      321
# 96  0.008448  play_duration<1.31 AND shot_distance_from_goal...      231
# 97  0.008422  play_distance_towards_goal: [0.0:7.35[ AND rat...      278
# 98  0.008421  play_speed_towards_goal: [0.0:0.76[ AND shot_a...      260
# 99  0.008409  play_distance_towards_goal: [0.0:7.35[ AND sho...      306
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0           7979           420                884             6397
# 1           7979           421                884             6378
# 2           7979           383                884             6632
# 3           7979           366                884             6748
# 4           7979           329                884             6983
# ..           ...           ...                ...              ...
# 95          7979           103                884             7658
# 96          7979            93                884             7748
# 97          7979            98                884             7701
# 98          7979            96                884             7719
# 99          7979           101                884             7673
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.198270                  0.801730     0.475113
# 1           0.200652                  0.799348     0.476244
# 2           0.168818                  0.831182     0.433258
# 3           0.154280                  0.845720     0.414027
# 4           0.124828                  0.875172     0.372172
# ..               ...                       ...          ...
# 95          0.040231                  0.959769     0.116516
# 96          0.028951                  0.971049     0.105204
# 97          0.034841                  0.965159     0.110860
# 98          0.032586                  0.967414     0.108597
# 99          0.038351                  0.961649     0.114253
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.524887         0.265487                 0.072534
# 1              0.523756         0.262961                 0.072593
# 2              0.566742         0.284336                 0.075543
# 3              0.585973         0.297319                 0.076763
# 4              0.627828         0.330321                 0.079479
# ..                  ...              ...                      ...
# 95             0.883484         0.320872                 0.101985
# 96             0.894796         0.402597                 0.102091
# 97             0.889140         0.352518                 0.102065
# 98             0.891403         0.369231                 0.102086
# 99             0.885747         0.330065                 0.102046
#
#     target_share_dataset      lift
# 0               0.110791  2.396288
# 1               0.110791  2.373488
# 2               0.110791  2.566418
# 3               0.110791  2.683609
# 4               0.110791  2.981486
# ..                   ...       ...
# 95              0.110791  2.896199
# 96              0.110791  3.633851
# 97              0.110791  3.181834
# 98              0.110791  3.332684
# 99              0.110791  2.979176
#
# [100 rows x 15 columns]

# %%
show_coverage(result, Spain_shots_df_cp)
# Out:
# 0.19827045995738815
# 0.2301040230605339
# 0.2301040230605339
# 0.2301040230605339
# 0.2301040230605339
# 0.2301040230605339
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# 0.5109662865020679
# Total Coverage: 0.5110

# %% [markdown]
# ### xG

# %%
England_shots_df_cp = England_shots_df.copy()
England_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id"], inplace=True, axis=1)

X = England_shots_df_cp[["bodypart_name", "shot_distance_from_goal", "shot_angle_from_goal"]]
X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
England_shots_df_cp["xg"] = rfc.predict(X=X)

target = ps.BinaryTarget('xg', 1)

search_space = ps.create_selectors(England_shots_df_cp, ignore=['xg', 'result_id'])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(England_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.WRAccQF())

# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)
result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(10).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# /tmp/ipykernel_25122/1293186819.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
# Quality: 0.020278817516265642
# Subgroup: shot_angle_from_goal>=0.61 AND start_x>=96.60
# Size of Subgroup: 1096
# ----------------------------------------
# Quality: 0.020278817516265642
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.26 AND start_x>=96.60
# Size of Subgroup: 1096
# ----------------------------------------
# Quality: 0.019811633536383207
# Subgroup: shot_distance_from_goal<11.26 AND start_x>=96.60
# Size of Subgroup: 1332
# ----------------------------------------
# Quality: 0.01969935312114981
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.26
# Size of Subgroup: 1449
# ----------------------------------------
# Quality: 0.01923216914126737
# Subgroup: shot_distance_from_goal<11.26
# Size of Subgroup: 1685
# ----------------------------------------
# Quality: 0.018968669311578236
# Subgroup: shot_angle_from_goal>=0.61
# Size of Subgroup: 1694
# ----------------------------------------
# Quality: 0.018513330852494826
# Subgroup: start_x>=96.60
# Size of Subgroup: 1807
# ----------------------------------------
# Quality: 0.01507409730305635
# Subgroup: num_dribbles: [0:1[ AND shot_angle_from_goal>=0.61 AND start_x>=96.60
# Size of Subgroup: 778
# ----------------------------------------
# Quality: 0.014825677409419884
# Subgroup: num_dribbles: [0:1[ AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.26
# Size of Subgroup: 1020
# ----------------------------------------
# Quality: 0.014673491870927343
# Subgroup: num_dribbles: [0:1[ AND shot_distance_from_goal<11.26 AND start_x>=96.60
# Size of Subgroup: 952
# ----------------------------------------
#      quality                                           subgroup  size_sg  \
# 0   0.020279      shot_angle_from_goal>=0.61 AND start_x>=96.60     1096
# 1   0.020279  shot_angle_from_goal>=0.61 AND shot_distance_f...     1096
# 2   0.019812   shot_distance_from_goal<11.26 AND start_x>=96.60     1332
# 3   0.019699  shot_angle_from_goal>=0.61 AND shot_distance_f...     1449
# 4   0.019232                      shot_distance_from_goal<11.26     1685
# ..       ...                                                ...      ...
# 95  0.006950  shot_angle_from_goal>=0.61 AND start_x>=96.60 ...      209
# 96  0.006948  bodypart_name=='foot_right' AND shot_distance_...      170
# 97  0.006937  play_mean_distance_to_the_goal<8.40 AND shot_a...      253
# 98  0.006934  shot_angle_from_goal>=0.61 AND shot_distance_f...      254
# 99  0.006934  play_mean_distance_to_the_goal<8.40 AND shot_d...      254
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0           8451           199                213             7355
# 1           8451           199                213             7355
# 2           8451           201                213             7119
# 3           8451           203                213             7002
# 4           8451           205                213             6766
# ..           ...           ...                ...              ...
# 95          8451            64                213             8242
# 96          8451            63                213             8281
# 97          8451            65                213             8198
# 98          8451            65                213             8197
# 99          8451            65                213             8197
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.129689                  0.870311     0.934272
# 1           0.129689                  0.870311     0.934272
# 2           0.157614                  0.842386     0.943662
# 3           0.171459                  0.828541     0.953052
# 4           0.199385                  0.800615     0.962441
# ..               ...                       ...          ...
# 95          0.024731                  0.975269     0.300469
# 96          0.020116                  0.979884     0.295775
# 97          0.029937                  0.970063     0.305164
# 98          0.030056                  0.969944     0.305164
# 99          0.030056                  0.969944     0.305164
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.065728         0.181569                 0.001903
# 1              0.065728         0.181569                 0.001903
# 2              0.056338         0.150901                 0.001686
# 3              0.046948         0.140097                 0.001428
# 4              0.037559         0.121662                 0.001182
# ..                  ...              ...                      ...
# 95             0.699531         0.306220                 0.018078
# 96             0.704225         0.370588                 0.018114
# 97             0.694836         0.256917                 0.018053
# 98             0.694836         0.255906                 0.018055
# 99             0.694836         0.255906                 0.018055
#
#     target_share_dataset       lift
# 0               0.025204   7.203955
# 1               0.025204   7.203955
# 2               0.025204   5.987153
# 3               0.025204   5.558481
# 4               0.025204   4.827057
# ..                   ...        ...
# 95              0.025204  12.149606
# 96              0.025204  14.703480
# 97              0.025204  10.193453
# 98              0.025204  10.153322
# 99              0.025204  10.153322
#
# [100 rows x 15 columns]

# %%
show_coverage(result, England_shots_df_cp)
# Out:
# 0.12968879422553545
# 0.12968879422553545
# 0.15761448349307774
# 0.19938468820257957
# 0.19938468820257957
# 0.22837534019642647
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.2845817063069459
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.3807833392497929
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# 0.4933144006626435
# Total Coverage: 0.4933

# %%
Spain_shots_df_cp = Spain_shots_df.copy()
Spain_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id"], inplace=True, axis=1)

X = Spain_shots_df_cp[["bodypart_name", "shot_distance_from_goal", "shot_angle_from_goal"]]
X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
Spain_shots_df_cp["xg"] = rfc.predict(X=X)

target = ps.BinaryTarget('xg', 1)

search_space = ps.create_selectors(Spain_shots_df_cp, ignore=['xg', 'result_id'])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(Spain_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.WRAccQF())

# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)
result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(10).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# /tmp/ipykernel_25122/2189817498.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
# Quality: 0.019539824436689862
# Subgroup: shot_angle_from_goal>=0.61 AND start_x>=96.60
# Size of Subgroup: 996
# ----------------------------------------
# Quality: 0.019539824436689862
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 996
# ----------------------------------------
# Quality: 0.019353063981194782
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# Size of Subgroup: 1347
# ----------------------------------------
# Quality: 0.019328733287707654
# Subgroup: shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 1231
# ----------------------------------------
# Quality: 0.01914197283221257
# Subgroup: shot_distance_from_goal<11.04
# Size of Subgroup: 1582
# ----------------------------------------
# Quality: 0.01858305800564557
# Subgroup: shot_angle_from_goal>=0.61
# Size of Subgroup: 1601
# ----------------------------------------
# Quality: 0.017746280062366365
# Subgroup: start_x>=96.60
# Size of Subgroup: 1753
# ----------------------------------------
# Quality: 0.01362088453741391
# Subgroup: num_dribbles: [0:1[ AND shot_angle_from_goal>=0.61 AND start_x>=96.60
# Size of Subgroup: 716
# ----------------------------------------
# Quality: 0.013575568817136084
# Subgroup: num_dribbles: [0:1[ AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# Size of Subgroup: 979
# ----------------------------------------
# Quality: 0.013261170391804746
# Subgroup: num_dribbles: [0:1[ AND shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 876
# ----------------------------------------
#      quality                                           subgroup  size_sg  \
# 0   0.019540      shot_angle_from_goal>=0.61 AND start_x>=96.60      996
# 1   0.019540  shot_angle_from_goal>=0.61 AND shot_distance_f...      996
# 2   0.019353  shot_angle_from_goal>=0.61 AND shot_distance_f...     1347
# 3   0.019329   shot_distance_from_goal<11.04 AND start_x>=96.60     1231
# 4   0.019142                      shot_distance_from_goal<11.04     1582
# ..       ...                                                ...      ...
# 95  0.006467  play_distance_towards_goal: [0.0:7.35[ AND sho...      306
# 96  0.006458  play_speed_towards_goal: [0.0:0.76[ AND shot_a...      309
# 97  0.006437  player_rank>=0.02 AND shot_distance_from_goal<...      357
# 98  0.006415  num_dribbles: [0:1[ AND play_distance_towards_...      323
# 99  0.006410   player_rank>=0.02 AND shot_angle_from_goal>=0.61      366
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0           7979           180                193             6983
# 1           7979           180                193             6983
# 2           7979           187                193             6632
# 3           7979           184                193             6748
# 4           7979           191                193             6397
# ..           ...           ...                ...              ...
# 95          7979            59                193             7673
# 96          7979            59                193             7670
# 97          7979            60                193             7622
# 98          7979            59                193             7656
# 99          7979            60                193             7613
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.124828                  0.875172     0.932642
# 1           0.124828                  0.875172     0.932642
# 2           0.168818                  0.831182     0.968912
# 3           0.154280                  0.845720     0.953368
# 4           0.198270                  0.801730     0.989637
# ..               ...                       ...          ...
# 95          0.038351                  0.961649     0.305699
# 96          0.038727                  0.961273     0.305699
# 97          0.044742                  0.955258     0.310881
# 98          0.040481                  0.959519     0.305699
# 99          0.045870                  0.954130     0.310881
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.067358         0.180723                 0.001862
# 1              0.067358         0.180723                 0.001862
# 2              0.031088         0.138827                 0.000905
# 3              0.046632         0.149472                 0.001334
# 4              0.010363         0.120733                 0.000313
# ..                  ...              ...                      ...
# 95             0.694301         0.192810                 0.017464
# 96             0.694301         0.190939                 0.017471
# 97             0.689119         0.168067                 0.017449
# 98             0.694301         0.182663                 0.017503
# 99             0.689119         0.163934                 0.017470
#
#     target_share_dataset      lift
# 0               0.024188  7.471440
# 1               0.024188  7.471440
# 2               0.024188  5.739382
# 3               0.024188  6.179466
# 4               0.024188  4.991350
# ..                   ...       ...
# 95              0.024188  7.971164
# 96              0.024188  7.893774
# 97              0.024188  6.948230
# 98              0.024188  7.551629
# 99              0.024188  6.777372
#
# [100 rows x 15 columns]

# %%
show_coverage(result, Spain_shots_df_cp)
# Out:
# 0.12482767264068179
# 0.12482767264068179
# 0.16881814763754857
# 0.19827045995738815
# 0.19827045995738815
# 0.2301040230605339
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.2955257551071563
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# 0.3982955257551072
# Total Coverage: 0.3983

# %% [markdown]
# ### VAEP

# %%
England_shots_df_cp = England_shots_df.copy()
Spain_shots_df_cp = Spain_shots_df.copy()
all_action_values_cp = all_action_values.copy()
all_action_values_cp.drop(["original_event_id", "result_name", "action_id", "type_name", "end_x", "end_y"], inplace=True, axis=1)

England_shots_df_cp = England_shots_df_cp.merge(all_action_values_cp, on=['game_id', 'player_id', 'start_x', 'start_y'], how='left')
Spain_shots_df_cp = Spain_shots_df_cp.merge(all_action_values_cp, on=['game_id', 'player_id', 'start_x', 'start_y'], how='left')

# %%
England_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.NumericTarget('Pscores')

search_space = ps.create_selectors(England_shots_df_cp, ignore=["Pscores", "Pconcedes", "offensive_value", "defensive_value", "vaep_value"])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(England_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.StandardQFNumeric(1.0))
# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)

result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().tail(10).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    # print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()

# Cálculo WRAcc=(size_sg/size_dataset)*(mean_sg−mean_dataset)
# Out:
# Quality: 78.1030622124672
# Subgroup: play_duration<1.39 AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 78.09218579530716
# Subgroup: play_speed_towards_goal: [0.0:0.61[ AND ratio_distance: [0.0:0.10[ AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 77.74706348776817
# Subgroup: shot_distance_from_goal<11.26 AND total_time_per_play<0.65
# ----------------------------------------
# Quality: 77.69067320227623
# Subgroup: play_duration<1.39 AND shot_distance_from_goal<11.26 AND total_time_per_play<0.65
# ----------------------------------------
# Quality: 77.60794448852539
# Subgroup: play_distance_towards_goal: [0.0:6.30[ AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.26
# ----------------------------------------
# Quality: 77.53052169084549
# Subgroup: play_speed_towards_goal: [0.0:0.61[ AND ratio_distance: [0.0:0.10[ AND shot_distance_from_goal<11.26
# ----------------------------------------
# Quality: 77.31219002604485
# Subgroup: play_duration<1.39 AND play_std_distance_to_the_goal: [0.0:2.08[ AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 77.27101629972458
# Subgroup: player_rank>=0.02 AND shot_distance_from_goal<11.26 AND start_x>=96.60
# ----------------------------------------
# Quality: 77.2381083369255
# Subgroup: num_dribbles: [0:1[ AND shot_distance_from_goal<11.26 AND total_time_per_play<0.65
# ----------------------------------------
# Quality: 76.84995326399803
# Subgroup: play_duration<1.39 AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.26
# ----------------------------------------
#        quality                                           subgroup  size_sg  \
# 0   270.026178                      shot_distance_from_goal<11.26     1687
# 1   268.956481                         shot_angle_from_goal>=0.61     1707
# 2   254.301583  shot_angle_from_goal>=0.61 AND shot_distance_f...     1460
# 3   240.865721   shot_distance_from_goal<11.26 AND start_x>=96.60     1332
# 4   232.259416                                     start_x>=96.60     1813
# ..         ...                                                ...      ...
# 95   77.530522  play_speed_towards_goal: [0.0:0.61[ AND ratio_...      298
# 96   77.312190  play_duration<1.39 AND play_std_distance_to_th...      293
# 97   77.271016  player_rank>=0.02 AND shot_distance_from_goal<...      302
# 98   77.238108  num_dribbles: [0:1[ AND shot_distance_from_goa...      294
# 99   76.849953  play_duration<1.39 AND shot_angle_from_goal>=0...      257
#
#     size_dataset   mean_sg  mean_dataset    std_sg  std_dataset  median_sg  \
# 0           8528  0.287464      0.127401  0.419320     0.295678   0.036383
# 1           8528  0.284962      0.127401  0.418119     0.295678   0.035959
# 2           8528  0.301580      0.127401  0.426455     0.295678   0.036595
# 3           8528  0.308231      0.127401  0.429490     0.295678   0.036623
# 4           8528  0.255509      0.127401  0.401293     0.295678   0.035342
# ..           ...       ...           ...       ...          ...        ...
# 95          8528  0.387571      0.127401  0.457406     0.295678   0.040574
# 96          8528  0.391265      0.127401  0.457657     0.295678   0.041428
# 97          8528  0.383266      0.127401  0.456171     0.295678   0.041924
# 98          8528  0.390116      0.127401  0.457272     0.295678   0.041245
# 99          8528  0.426428      0.127401  0.465014     0.295678   0.043445
#
#     median_dataset    max_sg  max_dataset    min_sg  min_dataset  mean_lift  \
# 0         0.026265  0.995717     0.996881  0.014080     0.002416   2.256369
# 1         0.026265  0.995717     0.996881  0.014080     0.002416   2.236730
# 2         0.026265  0.995717     0.996881  0.014080     0.002416   2.367170
# 3         0.026265  0.995717     0.996881  0.014080     0.002416   2.419375
# 4         0.026265  0.995717     0.996881  0.011900     0.002416   2.005546
# ..             ...       ...          ...       ...          ...        ...
# 95        0.026265  0.990374     0.996881  0.019242     0.002416   3.042127
# 96        0.026265  0.990374     0.996881  0.021422     0.002416   3.071126
# 97        0.026265  0.994042     0.996881  0.018457     0.002416   3.008334
# 98        0.026265  0.990374     0.996881  0.021422     0.002416   3.062104
# 99        0.026265  0.990374     0.996881  0.021422     0.002416   3.347128
#
#     median_lift
# 0      1.385209
# 1      1.369085
# 2      1.393301
# 3      1.394351
# 4      1.345591
# ..          ...
# 95     1.544783
# 96     1.577291
# 97     1.596163
# 98     1.570315
# 99     1.654096
#
# [100 rows x 16 columns]

# %%
show_coverage(result, England_shots_df_cp)
# Out:
# 0.1978189493433396
# 0.22678236397748594
# 0.22678236397748594
# 0.22678236397748594
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.28318480300187615
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.37875234521575984
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# 0.4976547842401501
# Total Coverage: 0.4977

# %%
Spain_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.NumericTarget('Pscores')

search_space = ps.create_selectors(Spain_shots_df_cp, ignore=["Pscores", "Pconcedes", "offensive_value", "defensive_value", "vaep_value"])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(Spain_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.StandardQFNumeric(1.0))
# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)

result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().tail(10).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    # print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# Quality: 67.78081412613392
# Subgroup: play_distance_towards_goal>=53.55 AND shot_distance_from_goal<11.04
# ----------------------------------------
# Quality: 67.75137293338776
# Subgroup: bodypart_name=='foot_left' AND shot_angle_from_goal>=0.61 AND start_x>=96.60
# ----------------------------------------
# Quality: 66.89733941853046
# Subgroup: play_speed_towards_goal: [0.0:0.76[ AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 66.89585070312023
# Subgroup: shot_distance_from_goal<11.04 AND total_time_per_play<0.63
# ----------------------------------------
# Quality: 66.89585070312023
# Subgroup: num_dribbles: [0:1[ AND shot_distance_from_goal<11.04 AND total_time_per_play<0.63
# ----------------------------------------
# Quality: 66.35547921061516
# Subgroup: ratio_distance: [0.0:0.12[ AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# ----------------------------------------
# Quality: 66.21693554520607
# Subgroup: play_distance_towards_goal: [0.0:7.35[ AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 66.2113744020462
# Subgroup: play_duration<1.31 AND shot_distance_from_goal<11.04
# ----------------------------------------
# Quality: 66.2113744020462
# Subgroup: num_dribbles: [0:1[ AND play_duration<1.31 AND shot_distance_from_goal<11.04
# ----------------------------------------
# Quality: 66.11641636490822
# Subgroup: play_distance_towards_goal: [0.0:7.35[ AND ratio_distance: [0.0:0.12[ AND shot_distance_from_goal<11.04
# ----------------------------------------
#        quality                                           subgroup  size_sg  \
# 0   243.790569                      shot_distance_from_goal<11.04     1588
# 1   243.062725                         shot_angle_from_goal>=0.61     1611
# 2   231.454275  shot_angle_from_goal>=0.61 AND shot_distance_f...     1353
# 3   226.882050   shot_distance_from_goal<11.04 AND start_x>=96.60     1234
# 4   214.545707      shot_angle_from_goal>=0.61 AND start_x>=96.60      999
# ..         ...                                                ...      ...
# 95   66.355479  ratio_distance: [0.0:0.12[ AND shot_angle_from...      266
# 96   66.216936  play_distance_towards_goal: [0.0:7.35[ AND sho...      306
# 97   66.211374  play_duration<1.31 AND shot_distance_from_goal...      280
# 98   66.211374  num_dribbles: [0:1[ AND play_duration<1.31 AND...      280
# 99   66.116416  play_distance_towards_goal: [0.0:7.35[ AND rat...      278
#
#     size_dataset   mean_sg  mean_dataset    std_sg  std_dataset  median_sg  \
# 0           8043  0.284270       0.13075  0.417027     0.298985   0.036685
# 1           8043  0.281627       0.13075  0.415756     0.298985   0.036599
# 2           8043  0.301817       0.13075  0.425935     0.298985   0.037228
# 3           8043  0.314609       0.13075  0.431803     0.298985   0.037358
# 4           8043  0.345510       0.13075  0.444272     0.298985   0.038502
# ..           ...       ...           ...       ...          ...        ...
# 95          8043  0.380207       0.13075  0.454908     0.298985   0.040802
# 96          8043  0.347145       0.13075  0.444545     0.298985   0.039875
# 97          8043  0.367219       0.13075  0.450280     0.298985   0.041740
# 98          8043  0.367219       0.13075  0.450280     0.298985   0.041740
# 99          8043  0.368579       0.13075  0.451583     0.298985   0.040506
#
#     median_dataset    max_sg  max_dataset    min_sg  min_dataset  mean_lift  \
# 0         0.026685  0.995627     0.995627  0.015709     0.003558   2.174153
# 1         0.026685  0.995627     0.995627  0.009808     0.003558   2.153935
# 2         0.026685  0.995627     0.995627  0.016668     0.003558   2.308356
# 3         0.026685  0.995627     0.995627  0.015709     0.003558   2.406188
# 4         0.026685  0.995627     0.995627  0.016668     0.003558   2.642528
# ..             ...       ...          ...       ...          ...        ...
# 95        0.026685  0.989558     0.995627  0.019290     0.003558   2.907891
# 96        0.026685  0.989558     0.995627  0.017399     0.003558   2.655031
# 97        0.026685  0.990125     0.995627  0.015709     0.003558   2.808560
# 98        0.026685  0.990125     0.995627  0.015709     0.003558   2.808560
# 99        0.026685  0.989558     0.995627  0.015709     0.003558   2.818959
#
#     median_lift
# 0      1.374755
# 1      1.371526
# 2      1.395114
# 3      1.399988
# 4      1.442854
# ..          ...
# 95     1.529055
# 96     1.494289
# 97     1.564181
# 98     1.564181
# 99     1.517965
#
# [100 rows x 16 columns]

# %%
show_coverage(result, Spain_shots_df_cp)
# Out:
# 0.19743876662936716
# 0.22951634962078826
# 0.22951634962078826
# 0.22951634962078826
# 0.22951634962078826
# 0.22951634962078826
# 0.2950391644908616
# 0.2950391644908616
# 0.2950391644908616
# 0.2950391644908616
# 0.2950391644908616
# 0.2950391644908616
# 0.2950391644908616
# 0.2950391644908616
# 0.2950391644908616
# 0.2950391644908616
# 0.2950391644908616
# 0.2950391644908616
# 0.2950391644908616
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.3982344896183016
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# 0.5119980106925277
# Total Coverage: 0.5120

# %% [markdown]
# ## Avaliação Times (Topo VS Meio VS Baixo da tabela)

# %% [markdown]
# ### Pre-process

# %%
# 1º: Manchester City - 1625
# 10º: Newcastle - 1613
# 20º: West Bromwich - 1627

England_df = pd.read_csv(f"{PATH}England.csv", index_col=0)
England_df.drop(["original_event_id", "result_name","bodypart_id", "type_id"], inplace=True, axis=1)

MC_df = England_df[England_df["team_id"] == 1625]
MC_shots_df = generate_shots_with_counts_events(MC_df)

NC_df = England_df[England_df["team_id"] == 1613]
NC_shots_df = generate_shots_with_counts_events(NC_df)

WB_df = England_df[England_df["team_id"] == 1627]
WB_shots_df = generate_shots_with_counts_events(WB_df)

# %%
MC_shots_df
# Out:
#      game_id  period_id  team_id  player_id  time_seconds  start_x  start_y  \
# 0    2499720          1     1625     340386    189.560864    93.45    42.84
# 1    2499720          1     1625      70083    534.526010    84.00    48.28
# 2    2499720          1     1625     105339    794.071176    93.45    27.88
# 3    2499720          1     1625     340386   1995.689167    96.60    29.92
# 4    2499720          1     1625     340386   1998.335772    97.65    39.44
# ..       ...        ...      ...        ...           ...      ...      ...
# 598  2500095          2     1625     245364    896.992909    82.95    46.92
# 599  2500095          2     1625      11066    902.415248    92.40    27.88
# 600  2500095          2     1625       9380    926.967286    92.40    38.08
# 601  2500095          2     1625      38021    978.686885    84.00    26.52
# 602  2500095          2     1625     340386   2881.220554    94.50    44.88
#
#      num_events  num_passes  num_dribbles  ...  \
# 0            47          39             3  ...
# 1            65          51             4  ...
# 2            53          46             2  ...
# 3           145         119             3  ...
# 4             1           0             0  ...
# ..          ...         ...           ...  ...
# 598          34          24             1  ...
# 599           2           0             0  ...
# 600           2           0             0  ...
# 601           7           3             0  ...
# 602         206         126            19  ...
#
#      play_mean_distance_to_the_goal  play_std_distance_to_the_goal  \
# 0                         53.868916                      19.735366
# 1                         45.904966                      13.137510
# 2                         51.809342                      13.198073
# 3                         50.788555                      17.775042
# 4                          0.000000                       0.000000
# ..                              ...                            ...
# 598                       61.007314                      24.876650
# 599                       14.007655                       0.000000
# 600                       13.244108                       0.000000
# 601                       28.525122                       6.073473
# 602                       57.705975                      25.544781
#
#     play_distance_towards_goal  ratio_distance  total_time_per_play  \
# 0                        42.00        0.044038             3.961749
# 1                        21.00        0.017086             5.201843
# 2                        55.65        0.057894             4.195384
# 3                        52.50        0.017514             8.032031
# 4                         0.00        0.000000             0.000000
# ..                         ...             ...                  ...
# 598                      51.45        0.065115             7.045725
# 599                       7.35        0.803790             1.248029
# 600                     -12.60       -0.314133             1.021896
# 601                     -21.00       -0.198078             3.090426
# 602                      66.15        0.015208             8.891293
#
#      play_speed  play_speed_towards_goal  shot_distance_from_goal  \
# 0      5.122023                 0.225561                14.544693
# 1      3.635010                 0.062108                25.395244
# 2      4.322957                 0.250275                13.071224
# 3      2.573904                 0.045078                 9.338437
# 4      0.000000                 0.000000                 9.144184
# ..          ...                      ...                      ...
# 598    3.298353                 0.214774                25.556387
# 599    3.663450                 2.944643                14.007655
# 600   19.625494                -6.165011                13.244108
# 601    4.900801                -0.970740                22.292384
# 602    2.374823                 0.036116                15.120331
#
#      shot_angle_from_goal  result_id
# 0                0.441421          0
# 1                0.261031          0
# 2                0.537975          0
# 3                0.756460          0
# 4                0.715772          0
# ..                    ...        ...
# 598              0.270101          0
# 599              0.509981          0
# 600              0.563864          0
# 601              0.336059          0
# 602              0.376243          1
#
# [603 rows x 24 columns]

# %% [markdown]
# ### Binário

# %%
MC_shots_df_cp = MC_shots_df.copy()
MC_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.BinaryTarget('result_id', 1)

search_space = ps.create_selectors(MC_shots_df_cp, ignore=['result_id'])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(MC_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.WRAccQF())

# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)
result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(30).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe().head(30)
# Out:
# Quality: 0.04832113616549646
# Subgroup: shot_angle_from_goal>=0.62
# Size of Subgroup: 121
# ----------------------------------------
# Quality: 0.04717980027997106
# Subgroup: shot_distance_from_goal<10.90
# Size of Subgroup: 119
# ----------------------------------------
# Quality: 0.044657860504002916
# Subgroup: start_x>=96.60
# Size of Subgroup: 148
# ----------------------------------------
# Quality: 0.04405831538823297
# Subgroup: shot_angle_from_goal>=0.62 AND shot_distance_from_goal<10.90
# Size of Subgroup: 99
# ----------------------------------------
# Quality: 0.04162438223476317
# Subgroup: shot_distance_from_goal<10.90 AND start_x>=96.60
# Size of Subgroup: 102
# ----------------------------------------
# Quality: 0.03850289734302506
# Subgroup: shot_angle_from_goal>=0.62 AND start_x>=96.60
# Size of Subgroup: 82
# ----------------------------------------
# Quality: 0.03850289734302506
# Subgroup: shot_angle_from_goal>=0.62 AND shot_distance_from_goal<10.90 AND start_x>=96.60
# Size of Subgroup: 82
# ----------------------------------------
# Quality: 0.024182569738372812
# Subgroup: shot_distance_from_goal<10.90 AND start_y: [31.96:37.40[
# Size of Subgroup: 54
# ----------------------------------------
# Quality: 0.024182569738372812
# Subgroup: shot_angle_from_goal>=0.62 AND shot_distance_from_goal<10.90 AND start_y: [31.96:37.40[
# Size of Subgroup: 54
# ----------------------------------------
# Quality: 0.023602276071274363
# Subgroup: player_rank: [0.02:0.03[ AND shot_angle_from_goal>=0.62
# Size of Subgroup: 37
# ----------------------------------------
# Quality: 0.023255749995187137
# Subgroup: shot_angle_from_goal>=0.62 AND start_y: [31.96:37.40[
# Size of Subgroup: 64
# ----------------------------------------
# Quality: 0.022738711088009372
# Subgroup: num_dribbles: [0:2[ AND start_x>=96.60
# Size of Subgroup: 66
# ----------------------------------------
# Quality: 0.021578123753812475
# Subgroup: player_rank: [0.02:0.03[ AND shot_angle_from_goal>=0.62 AND shot_distance_from_goal<10.90
# Size of Subgroup: 32
# ----------------------------------------
# Quality: 0.021426862371393445
# Subgroup: player_rank: [0.02:0.03[ AND start_x>=96.60
# Size of Subgroup: 39
# ----------------------------------------
# Quality: 0.021319604300223588
# Subgroup: player_rank: [0.02:0.03[ AND shot_distance_from_goal<10.90
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.02123159767772525
# Subgroup: bodypart_name=='foot_left' AND start_x>=96.60
# Size of Subgroup: 59
# ----------------------------------------
# Quality: 0.0206513040106268
# Subgroup: start_x>=96.60 AND start_y: [31.96:37.40[
# Size of Subgroup: 42
# ----------------------------------------
# Quality: 0.0206513040106268
# Subgroup: shot_distance_from_goal<10.90 AND start_x>=96.60 AND start_y: [31.96:37.40[
# Size of Subgroup: 42
# ----------------------------------------
# Quality: 0.0206513040106268
# Subgroup: shot_angle_from_goal>=0.62 AND start_x>=96.60 AND start_y: [31.96:37.40[
# Size of Subgroup: 42
# ----------------------------------------
# Quality: 0.020392784557037916
# Subgroup: bodypart_name=='foot_left' AND shot_distance_from_goal<10.90
# Size of Subgroup: 43
# ----------------------------------------
# Quality: 0.020392784557037916
# Subgroup: bodypart_name=='foot_left' AND shot_angle_from_goal>=0.62
# Size of Subgroup: 43
# ----------------------------------------
# Quality: 0.020134265103449036
# Subgroup: num_dribbles: [0:2[ AND shot_distance_from_goal<10.90 AND start_x>=96.60
# Size of Subgroup: 44
# ----------------------------------------
# Quality: 0.02002700703227918
# Subgroup: bodypart_name=='foot_right' AND shot_angle_from_goal>=0.62
# Size of Subgroup: 38
# ----------------------------------------
# Quality: 0.019983003721030006
# Subgroup: num_dribbles: [0:2[ AND shot_distance_from_goal<10.90
# Size of Subgroup: 51
# ----------------------------------------
# Quality: 0.019724484267441125
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.62
# Size of Subgroup: 52
# ----------------------------------------
# Quality: 0.01966122950752044
# Subgroup: num_passes: [6:18[ AND shot_angle_from_goal>=0.62
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.0192954519827617
# Subgroup: player_rank: [0.02:0.03[ AND shot_angle_from_goal>=0.62 AND start_x>=96.60
# Size of Subgroup: 28
# ----------------------------------------
# Quality: 0.019144190600342673
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.62 AND start_x>=96.60
# Size of Subgroup: 35
# ----------------------------------------
# Quality: 0.01903693252917282
# Subgroup: player_rank: [0.02:0.03[ AND shot_distance_from_goal<10.90 AND start_x>=96.60
# Size of Subgroup: 29
# ----------------------------------------
# Quality: 0.018992929217923647
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.62 AND shot_distance_from_goal<10.90
# Size of Subgroup: 42
# ----------------------------------------
#      quality                                           subgroup  size_sg  \
# 0   0.048321                         shot_angle_from_goal>=0.62      121
# 1   0.047180                      shot_distance_from_goal<10.90      119
# 2   0.044658                                     start_x>=96.60      148
# 3   0.044058  shot_angle_from_goal>=0.62 AND shot_distance_f...       99
# 4   0.041624   shot_distance_from_goal<10.90 AND start_x>=96.60      102
# 5   0.038503      shot_angle_from_goal>=0.62 AND start_x>=96.60       82
# 6   0.038503  shot_angle_from_goal>=0.62 AND shot_distance_f...       82
# 7   0.024183  shot_distance_from_goal<10.90 AND start_y: [31...       54
# 8   0.024183  shot_angle_from_goal>=0.62 AND shot_distance_f...       54
# 9   0.023602  player_rank: [0.02:0.03[ AND shot_angle_from_g...       37
# 10  0.023256  shot_angle_from_goal>=0.62 AND start_y: [31.96...       64
# 11  0.022739             num_dribbles: [0:2[ AND start_x>=96.60       66
# 12  0.021578  player_rank: [0.02:0.03[ AND shot_angle_from_g...       32
# 13  0.021427        player_rank: [0.02:0.03[ AND start_x>=96.60       39
# 14  0.021320  player_rank: [0.02:0.03[ AND shot_distance_fro...       33
# 15  0.021232      bodypart_name=='foot_left' AND start_x>=96.60       59
# 16  0.020651          start_x>=96.60 AND start_y: [31.96:37.40[       42
# 17  0.020651  shot_distance_from_goal<10.90 AND start_x>=96....       42
# 18  0.020651  shot_angle_from_goal>=0.62 AND start_x>=96.60 ...       42
# 19  0.020393  bodypart_name=='foot_left' AND shot_distance_f...       43
# 20  0.020393  bodypart_name=='foot_left' AND shot_angle_from...       43
# 21  0.020134  num_dribbles: [0:2[ AND shot_distance_from_goa...       44
# 22  0.020027  bodypart_name=='foot_right' AND shot_angle_fro...       38
# 23  0.019983  num_dribbles: [0:2[ AND shot_distance_from_goa...       51
# 24  0.019724  num_dribbles: [0:2[ AND shot_angle_from_goal>=...       52
# 25  0.019661  num_passes: [6:18[ AND shot_angle_from_goal>=0.62       33
# 26  0.019295  player_rank: [0.02:0.03[ AND shot_angle_from_g...       28
# 27  0.019144  num_dribbles: [0:2[ AND shot_angle_from_goal>=...       35
# 28  0.019037  player_rank: [0.02:0.03[ AND shot_distance_fro...       29
# 29  0.018993  num_dribbles: [0:2[ AND shot_angle_from_goal>=...       42
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0            603            48                 94              482
# 1            603            47                 94              484
# 2            603            50                 94              455
# 3            603            42                 94              504
# 4            603            41                 94              501
# 5            603            36                 94              521
# 6            603            36                 94              521
# 7            603            23                 94              549
# 8            603            23                 94              549
# 9            603            20                 94              566
# 10           603            24                 94              539
# 11           603            24                 94              537
# 12           603            18                 94              571
# 13           603            19                 94              564
# 14           603            18                 94              570
# 15           603            22                 94              544
# 16           603            19                 94              561
# 17           603            19                 94              561
# 18           603            19                 94              561
# 19           603            19                 94              560
# 20           603            19                 94              560
# 21           603            19                 94              559
# 22           603            18                 94              565
# 23           603            20                 94              552
# 24           603            20                 94              551
# 25           603            17                 94              570
# 26           603            16                 94              575
# 27           603            17                 94              568
# 28           603            16                 94              574
# 29           603            18                 94              561
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.200663                  0.799337     0.510638
# 1           0.197347                  0.802653     0.500000
# 2           0.245439                  0.754561     0.531915
# 3           0.164179                  0.835821     0.446809
# 4           0.169154                  0.830846     0.436170
# 5           0.135987                  0.864013     0.382979
# 6           0.135987                  0.864013     0.382979
# 7           0.089552                  0.910448     0.244681
# 8           0.089552                  0.910448     0.244681
# 9           0.061360                  0.938640     0.212766
# 10          0.106136                  0.893864     0.255319
# 11          0.109453                  0.890547     0.255319
# 12          0.053068                  0.946932     0.191489
# 13          0.064677                  0.935323     0.202128
# 14          0.054726                  0.945274     0.191489
# 15          0.097844                  0.902156     0.234043
# 16          0.069652                  0.930348     0.202128
# 17          0.069652                  0.930348     0.202128
# 18          0.069652                  0.930348     0.202128
# 19          0.071310                  0.928690     0.202128
# 20          0.071310                  0.928690     0.202128
# 21          0.072968                  0.927032     0.202128
# 22          0.063018                  0.936982     0.191489
# 23          0.084577                  0.915423     0.212766
# 24          0.086235                  0.913765     0.212766
# 25          0.054726                  0.945274     0.180851
# 26          0.046434                  0.953566     0.170213
# 27          0.058043                  0.941957     0.180851
# 28          0.048093                  0.951907     0.170213
# 29          0.069652                  0.930348     0.191489
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.489362         0.396694                 0.095436
# 1              0.500000         0.394958                 0.097107
# 2              0.468085         0.337838                 0.096703
# 3              0.553191         0.424242                 0.103175
# 4              0.563830         0.401961                 0.105788
# 5              0.617021         0.439024                 0.111324
# 6              0.617021         0.439024                 0.111324
# 7              0.755319         0.425926                 0.129326
# 8              0.755319         0.425926                 0.129326
# 9              0.787234         0.540541                 0.130742
# 10             0.744681         0.375000                 0.129870
# 11             0.744681         0.363636                 0.130354
# 12             0.808511         0.562500                 0.133100
# 13             0.797872         0.487179                 0.132979
# 14             0.808511         0.545455                 0.133333
# 15             0.765957         0.372881                 0.132353
# 16             0.797872         0.452381                 0.133690
# 17             0.797872         0.452381                 0.133690
# 18             0.797872         0.452381                 0.133690
# 19             0.797872         0.441860                 0.133929
# 20             0.797872         0.441860                 0.133929
# 21             0.797872         0.431818                 0.134168
# 22             0.808511         0.473684                 0.134513
# 23             0.787234         0.392157                 0.134058
# 24             0.787234         0.384615                 0.134301
# 25             0.819149         0.515152                 0.135088
# 26             0.829787         0.571429                 0.135652
# 27             0.819149         0.485714                 0.135563
# 28             0.829787         0.551724                 0.135889
# 29             0.808511         0.428571                 0.135472
#
#     target_share_dataset      lift
# 0               0.155887  2.544751
# 1               0.155887  2.533613
# 2               0.155887  2.167194
# 3               0.155887  2.721470
# 4               0.155887  2.578536
# 5               0.155887  2.816295
# 6               0.155887  2.816295
# 7               0.155887  2.732270
# 8               0.155887  2.732270
# 9               0.155887  3.467510
# 10              0.155887  2.405585
# 11              0.155887  2.332689
# 12              0.155887  3.608378
# 13              0.155887  3.125205
# 14              0.155887  3.499033
# 15              0.155887  2.391994
# 16              0.155887  2.901976
# 17              0.155887  2.901976
# 18              0.155887  2.901976
# 19              0.155887  2.834488
# 20              0.155887  2.834488
# 21              0.155887  2.770068
# 22              0.155887  3.038634
# 23              0.155887  2.515645
# 24              0.155887  2.467267
# 25              0.155887  3.304642
# 26              0.155887  3.665653
# 27              0.155887  3.115805
# 28              0.155887  3.539252
# 29              0.155887  2.749240

# %%
show_coverage(result, MC_shots_df_cp)
# Out:
# 0.20066334991708126
# 0.23383084577114427
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.43781094527363185
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.494195688225539
# 0.560530679933665
# 0.560530679933665
# 0.560530679933665
# 0.560530679933665
# 0.560530679933665
# 0.560530679933665
# 0.560530679933665
# 0.560530679933665
# 0.5688225538971807
# 0.572139303482587
# 0.572139303482587
# 0.572139303482587
# 0.572139303482587
# 0.572139303482587
# 0.572139303482587
# 0.572139303482587
# Total Coverage: 0.5721

# %%
NC_shots_df_cp = NC_shots_df.copy()
NC_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.BinaryTarget('result_id', 1)

search_space = ps.create_selectors(NC_shots_df_cp, ignore=['result_id'])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(NC_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.WRAccQF())

# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)
result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(50).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# Quality: 0.04048780487804878
# Subgroup: shot_distance_from_goal<11.04
# Size of Subgroup: 82
# ----------------------------------------
# Quality: 0.038048780487804884
# Subgroup: start_x>=96.60
# Size of Subgroup: 82
# ----------------------------------------
# Quality: 0.038048780487804884
# Subgroup: shot_angle_from_goal>=0.61
# Size of Subgroup: 82
# ----------------------------------------
# Quality: 0.038030933967876254
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# Size of Subgroup: 71
# ----------------------------------------
# Quality: 0.036472337894110654
# Subgroup: shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 67
# ----------------------------------------
# Quality: 0.03509815585960738
# Subgroup: shot_angle_from_goal>=0.61 AND start_y: [33.32:38.08[
# Size of Subgroup: 40
# ----------------------------------------
# Quality: 0.03419988102320048
# Subgroup: shot_distance_from_goal<11.04 AND start_y: [33.32:38.08[
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.03419988102320048
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04 AND start_y: [33.32:38.08[
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.03401546698393814
# Subgroup: shot_angle_from_goal>=0.61 AND start_x>=96.60
# Size of Subgroup: 56
# ----------------------------------------
# Quality: 0.03401546698393814
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 56
# ----------------------------------------
# Quality: 0.03118976799524093
# Subgroup: start_y: [33.32:38.08[
# Size of Subgroup: 91
# ----------------------------------------
# Quality: 0.028643664485425345
# Subgroup: start_x>=96.60 AND start_y: [33.32:38.08[
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.028643664485425345
# Subgroup: shot_distance_from_goal<11.04 AND start_x>=96.60 AND start_y: [33.32:38.08[
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.028643664485425345
# Subgroup: shot_angle_from_goal>=0.61 AND start_x>=96.60 AND start_y: [33.32:38.08[
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.026002379535990487
# Subgroup: player_rank>=0.01 AND shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 37
# ----------------------------------------
# Quality: 0.02490184414039262
# Subgroup: player_rank>=0.01 AND shot_distance_from_goal<11.04
# Size of Subgroup: 42
# ----------------------------------------
# Quality: 0.024681737061273055
# Subgroup: player_rank>=0.01 AND start_x>=96.60
# Size of Subgroup: 43
# ----------------------------------------
# Quality: 0.023765615704937536
# Subgroup: bodypart_name=='foot_right' AND shot_distance_from_goal<11.04
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.023325401546698394
# Subgroup: bodypart_name=='foot_right' AND shot_angle_from_goal>=0.61
# Size of Subgroup: 27
# ----------------------------------------
# Quality: 0.022444973230220107
# Subgroup: player_rank>=0.01 AND shot_angle_from_goal>=0.61 AND start_x>=96.60
# Size of Subgroup: 31
# ----------------------------------------
# Quality: 0.021986912552052353
# Subgroup: bodypart_name=='foot_right' AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# Size of Subgroup: 22
# ----------------------------------------
# Quality: 0.021344437834622247
# Subgroup: player_rank>=0.01 AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# Size of Subgroup: 36
# ----------------------------------------
# Quality: 0.020684116597263536
# Subgroup: bodypart_name=='foot_right' AND start_y: [33.32:38.08[
# Size of Subgroup: 39
# ----------------------------------------
# Quality: 0.020446162998215348
# Subgroup: bodypart_name=='foot_right' AND start_x>=96.60
# Size of Subgroup: 29
# ----------------------------------------
# Quality: 0.020208209399167162
# Subgroup: bodypart_name=='foot_right' AND shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 19
# ----------------------------------------
# Quality: 0.019803688280785246
# Subgroup: player_rank>=0.01 AND shot_angle_from_goal>=0.61
# Size of Subgroup: 43
# ----------------------------------------
# Quality: 0.019547888161808444
# Subgroup: play_std_distance_to_the_goal>=24.10 AND shot_angle_from_goal>=0.61
# Size of Subgroup: 22
# ----------------------------------------
# Quality: 0.019547888161808444
# Subgroup: play_distance_towards_goal>=61.95 AND start_y: [33.32:38.08[
# Size of Subgroup: 22
# ----------------------------------------
# Quality: 0.019363474122546104
# Subgroup: bodypart_name=='foot_right' AND play_distance_towards_goal>=61.95
# Size of Subgroup: 45
# ----------------------------------------
# Quality: 0.01908982748364069
# Subgroup: bodypart_name=='foot_right' AND shot_angle_from_goal>=0.61 AND start_y: [33.32:38.08[
# Size of Subgroup: 13
# ----------------------------------------
# Quality: 0.018887566924449734
# Subgroup: play_mean_distance_to_the_goal<41.87 AND start_x>=96.60
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.018429506246281976
# Subgroup: num_passes<5 AND play_duration<54.62 AND start_x>=96.60
# Size of Subgroup: 16
# ----------------------------------------
# Quality: 0.018429506246281976
# Subgroup: num_events<10 AND play_duration<54.62 AND start_x>=96.60
# Size of Subgroup: 16
# ----------------------------------------
# Quality: 0.018429506246281976
# Subgroup: bodypart_name=='foot_right' AND shot_angle_from_goal>=0.61 AND start_x>=96.60
# Size of Subgroup: 16
# ----------------------------------------
# Quality: 0.018209399167162407
# Subgroup: play_duration<54.62 AND play_mean_distance_to_the_goal<41.87 AND start_x>=96.60
# Size of Subgroup: 17
# ----------------------------------------
# Quality: 0.018209399167162407
# Subgroup: play_distance_towards_goal>=61.95 AND shot_angle_from_goal>=0.61 AND start_y: [33.32:38.08[
# Size of Subgroup: 17
# ----------------------------------------
# Quality: 0.018209399167162407
# Subgroup: num_passes<5 AND start_x>=96.60
# Size of Subgroup: 17
# ----------------------------------------
# Quality: 0.018209399167162407
# Subgroup: num_passes<5 AND play_mean_distance_to_the_goal<41.87 AND start_x>=96.60
# Size of Subgroup: 17
# ----------------------------------------
# Quality: 0.018209399167162407
# Subgroup: num_events<10 AND start_x>=96.60
# Size of Subgroup: 17
# ----------------------------------------
# Quality: 0.018209399167162407
# Subgroup: num_events<10 AND play_mean_distance_to_the_goal<41.87 AND start_x>=96.60
# Size of Subgroup: 17
# ----------------------------------------
# Quality: 0.018209399167162407
# Subgroup: num_events<10 AND num_passes<5 AND start_x>=96.60
# Size of Subgroup: 17
# ----------------------------------------
# Quality: 0.01798929208804283
# Subgroup: play_duration<54.62 AND start_x>=96.60
# Size of Subgroup: 18
# ----------------------------------------
# Quality: 0.017656157049375374
# Subgroup: play_distance_towards_goal>=61.95
# Size of Subgroup: 86
# ----------------------------------------
# Quality: 0.0175669244497323
# Subgroup: play_distance_towards_goal>=61.95 AND shot_angle_from_goal>=0.61
# Size of Subgroup: 31
# ----------------------------------------
# Quality: 0.01754907792980369
# Subgroup: play_std_distance_to_the_goal>=24.10 AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# Size of Subgroup: 20
# ----------------------------------------
# Quality: 0.01754907792980369
# Subgroup: play_mean_distance_to_the_goal<41.87 AND shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 20
# ----------------------------------------
# Quality: 0.017311124330755503
# Subgroup: bodypart_name=='foot_right' AND shot_distance_from_goal<11.04 AND start_y: [33.32:38.08[
# Size of Subgroup: 10
# ----------------------------------------
# Quality: 0.01709101725163593
# Subgroup: play_std_distance_to_the_goal>=24.10 AND shot_angle_from_goal>=0.61 AND start_y: [33.32:38.08[
# Size of Subgroup: 11
# ----------------------------------------
# Quality: 0.016668649613325405
# Subgroup: play_std_distance_to_the_goal>=24.10 AND shot_distance_from_goal<11.04
# Size of Subgroup: 24
# ----------------------------------------
# Quality: 0.016668649613325405
# Subgroup: play_mean_distance_to_the_goal<41.87 AND shot_distance_from_goal<11.04
# Size of Subgroup: 24
# ----------------------------------------
#      quality                                           subgroup  size_sg  \
# 0   0.040488                      shot_distance_from_goal<11.04       82
# 1   0.038049                                     start_x>=96.60       82
# 2   0.038049                         shot_angle_from_goal>=0.61       82
# 3   0.038031  shot_angle_from_goal>=0.61 AND shot_distance_f...       71
# 4   0.036472   shot_distance_from_goal<11.04 AND start_x>=96.60       67
# 5   0.035098  shot_angle_from_goal>=0.61 AND start_y: [33.32...       40
# 6   0.034200  shot_distance_from_goal<11.04 AND start_y: [33...       33
# 7   0.034200  shot_angle_from_goal>=0.61 AND shot_distance_f...       33
# 8   0.034015      shot_angle_from_goal>=0.61 AND start_x>=96.60       56
# 9   0.034015  shot_angle_from_goal>=0.61 AND shot_distance_f...       56
# 10  0.031190                             start_y: [33.32:38.08[       91
# 11  0.028644          start_x>=96.60 AND start_y: [33.32:38.08[       25
# 12  0.028644  shot_distance_from_goal<11.04 AND start_x>=96....       25
# 13  0.028644  shot_angle_from_goal>=0.61 AND start_x>=96.60 ...       25
# 14  0.026002  player_rank>=0.01 AND shot_distance_from_goal<...       37
# 15  0.024902  player_rank>=0.01 AND shot_distance_from_goal<...       42
# 16  0.024682               player_rank>=0.01 AND start_x>=96.60       43
# 17  0.023766  bodypart_name=='foot_right' AND shot_distance_...       25
# 18  0.023325  bodypart_name=='foot_right' AND shot_angle_fro...       27
# 19  0.022445  player_rank>=0.01 AND shot_angle_from_goal>=0....       31
# 20  0.021987  bodypart_name=='foot_right' AND shot_angle_fro...       22
# 21  0.021344  player_rank>=0.01 AND shot_angle_from_goal>=0....       36
# 22  0.020684  bodypart_name=='foot_right' AND start_y: [33.3...       39
# 23  0.020446     bodypart_name=='foot_right' AND start_x>=96.60       29
# 24  0.020208  bodypart_name=='foot_right' AND shot_distance_...       19
# 25  0.019804   player_rank>=0.01 AND shot_angle_from_goal>=0.61       43
# 26  0.019548  play_std_distance_to_the_goal>=24.10 AND shot_...       22
# 27  0.019548  play_distance_towards_goal>=61.95 AND start_y:...       22
# 28  0.019363  bodypart_name=='foot_right' AND play_distance_...       45
# 29  0.019090  bodypart_name=='foot_right' AND shot_angle_fro...       13
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0            410            24                 37              328
# 1            410            23                 37              328
# 2            410            23                 37              328
# 3            410            22                 37              339
# 4            410            21                 37              343
# 5            410            18                 37              370
# 6            410            17                 37              377
# 7            410            17                 37              377
# 8            410            19                 37              354
# 9            410            19                 37              354
# 10           410            21                 37              319
# 11           410            14                 37              385
# 12           410            14                 37              385
# 13           410            14                 37              385
# 14           410            14                 37              373
# 15           410            14                 37              368
# 16           410            14                 37              367
# 17           410            12                 37              385
# 18           410            12                 37              383
# 19           410            12                 37              379
# 20           410            11                 37              388
# 21           410            12                 37              374
# 22           410            12                 37              371
# 23           410            11                 37              381
# 24           410            10                 37              391
# 25           410            12                 37              367
# 26           410            10                 37              388
# 27           410            10                 37              388
# 28           410            12                 37              365
# 29           410             9                 37              397
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.200000                  0.800000     0.648649
# 1           0.200000                  0.800000     0.621622
# 2           0.200000                  0.800000     0.621622
# 3           0.173171                  0.826829     0.594595
# 4           0.163415                  0.836585     0.567568
# 5           0.097561                  0.902439     0.486486
# 6           0.080488                  0.919512     0.459459
# 7           0.080488                  0.919512     0.459459
# 8           0.136585                  0.863415     0.513514
# 9           0.136585                  0.863415     0.513514
# 10          0.221951                  0.778049     0.567568
# 11          0.060976                  0.939024     0.378378
# 12          0.060976                  0.939024     0.378378
# 13          0.060976                  0.939024     0.378378
# 14          0.090244                  0.909756     0.378378
# 15          0.102439                  0.897561     0.378378
# 16          0.104878                  0.895122     0.378378
# 17          0.060976                  0.939024     0.324324
# 18          0.065854                  0.934146     0.324324
# 19          0.075610                  0.924390     0.324324
# 20          0.053659                  0.946341     0.297297
# 21          0.087805                  0.912195     0.324324
# 22          0.095122                  0.904878     0.324324
# 23          0.070732                  0.929268     0.297297
# 24          0.046341                  0.953659     0.270270
# 25          0.104878                  0.895122     0.324324
# 26          0.053659                  0.946341     0.270270
# 27          0.053659                  0.946341     0.270270
# 28          0.109756                  0.890244     0.324324
# 29          0.031707                  0.968293     0.243243
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.351351         0.292683                 0.039634
# 1              0.378378         0.280488                 0.042683
# 2              0.378378         0.280488                 0.042683
# 3              0.405405         0.309859                 0.044248
# 4              0.432432         0.313433                 0.046647
# 5              0.513514         0.450000                 0.051351
# 6              0.540541         0.515152                 0.053050
# 7              0.540541         0.515152                 0.053050
# 8              0.486486         0.339286                 0.050847
# 9              0.486486         0.339286                 0.050847
# 10             0.432432         0.230769                 0.050157
# 11             0.621622         0.560000                 0.059740
# 12             0.621622         0.560000                 0.059740
# 13             0.621622         0.560000                 0.059740
# 14             0.621622         0.378378                 0.061662
# 15             0.621622         0.333333                 0.062500
# 16             0.621622         0.325581                 0.062670
# 17             0.675676         0.480000                 0.064935
# 18             0.675676         0.444444                 0.065274
# 19             0.675676         0.387097                 0.065963
# 20             0.702703         0.500000                 0.067010
# 21             0.675676         0.333333                 0.066845
# 22             0.675676         0.307692                 0.067385
# 23             0.702703         0.379310                 0.068241
# 24             0.729730         0.526316                 0.069054
# 25             0.675676         0.279070                 0.068120
# 26             0.729730         0.454545                 0.069588
# 27             0.729730         0.454545                 0.069588
# 28             0.675676         0.266667                 0.068493
# 29             0.756757         0.692308                 0.070529
#
#     target_share_dataset      lift
# 0               0.090244  3.243243
# 1               0.090244  3.108108
# 2               0.090244  3.108108
# 3               0.090244  3.433574
# 4               0.090244  3.473175
# 5               0.090244  4.986486
# 6               0.090244  5.708436
# 7               0.090244  5.708436
# 8               0.090244  3.759653
# 9               0.090244  3.759653
# 10              0.090244  2.557173
# 11              0.090244  6.205405
# 12              0.090244  6.205405
# 13              0.090244  6.205405
# 14              0.090244  4.192841
# 15              0.090244  3.693694
# 16              0.090244  3.607794
# 17              0.090244  5.318919
# 18              0.090244  4.924925
# 19              0.090244  4.289451
# 20              0.090244  5.540541
# 21              0.090244  3.693694
# 22              0.090244  3.409563
# 23              0.090244  4.203169
# 24              0.090244  5.832148
# 25              0.090244  3.092395
# 26              0.090244  5.036855
# 27              0.090244  5.036855
# 28              0.090244  2.954955
# 29              0.090244  7.671518

# %%
show_coverage(result, NC_shots_df_cp)
# Out:
# 0.2
# 0.23658536585365852
# 0.2634146341463415
# 0.2634146341463415
# 0.2634146341463415
# 0.2634146341463415
# 0.2634146341463415
# 0.2634146341463415
# 0.2634146341463415
# 0.2634146341463415
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# Total Coverage: 0.6561

# %%
WB_shots_df_cp = WB_shots_df.copy()
WB_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.BinaryTarget('result_id', 1)

search_space = ps.create_selectors(WB_shots_df_cp, ignore=['result_id'])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(WB_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.WRAccQF())

# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)
result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(50).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe().head(30)
# Out:
# Quality: 0.029317943847858376
# Subgroup: shot_distance_from_goal<10.52 AND start_x>=96.60
# Size of Subgroup: 57
# ----------------------------------------
# Quality: 0.029106906599784092
# Subgroup: shot_distance_from_goal<10.52
# Size of Subgroup: 70
# ----------------------------------------
# Quality: 0.028871518900008934
# Subgroup: shot_angle_from_goal>=0.63
# Size of Subgroup: 71
# ----------------------------------------
# Quality: 0.026517641902257288
# Subgroup: start_x>=96.60
# Size of Subgroup: 81
# ----------------------------------------
# Quality: 0.025973815147604325
# Subgroup: shot_angle_from_goal>=0.63 AND start_x>=96.60
# Size of Subgroup: 47
# ----------------------------------------
# Quality: 0.025973815147604325
# Subgroup: shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52 AND start_x>=96.60
# Size of Subgroup: 47
# ----------------------------------------
# Quality: 0.025762777899530038
# Subgroup: shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52
# Size of Subgroup: 60
# ----------------------------------------
# Quality: 0.020722234397448074
# Subgroup: shot_distance_from_goal<10.52 AND start_y: [32.64:38.08[
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.020722234397448074
# Subgroup: shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52 AND start_y: [32.64:38.08[
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.01975633314664654
# Subgroup: start_x>=96.60 AND start_y: [32.64:38.08[
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.01975633314664654
# Subgroup: shot_distance_from_goal<10.52 AND start_x>=96.60 AND start_y: [32.64:38.08[
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.01975633314664654
# Subgroup: shot_angle_from_goal>=0.63 AND start_x>=96.60 AND start_y: [32.64:38.08[
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.019545295898572252
# Subgroup: shot_angle_from_goal>=0.63 AND start_y: [32.64:38.08[
# Size of Subgroup: 38
# ----------------------------------------
# Quality: 0.017004732104447202
# Subgroup: start_y: [32.64:38.08[
# Size of Subgroup: 73
# ----------------------------------------
# Quality: 0.015730391798767868
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.63
# Size of Subgroup: 30
# ----------------------------------------
# Quality: 0.015210915495815783
# Subgroup: play_distance_towards_goal: [39.90:56.70[ AND shot_distance_from_goal<10.52 AND start_x>=96.60
# Size of Subgroup: 8
# ----------------------------------------
# Quality: 0.014529102848191169
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.63 AND start_x>=96.60
# Size of Subgroup: 23
# ----------------------------------------
# Quality: 0.01450475239649029
# Subgroup: play_distance_towards_goal: [39.90:56.70[ AND start_x>=96.60
# Size of Subgroup: 11
# ----------------------------------------
# Quality: 0.014082677900341721
# Subgroup: bodypart_name=='head/other' AND shot_distance_from_goal<10.52 AND start_x>=96.60
# Size of Subgroup: 37
# ----------------------------------------
# Quality: 0.014033976996939961
# Subgroup: play_distance_towards_goal: [39.90:56.70[ AND shot_distance_from_goal<10.52
# Size of Subgroup: 13
# ----------------------------------------
# Quality: 0.01358755204909051
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52
# Size of Subgroup: 27
# ----------------------------------------
# Quality: 0.013141127101241063
# Subgroup: bodypart_name=='head/other' AND start_x>=96.60
# Size of Subgroup: 41
# ----------------------------------------
# Quality: 0.013116776649540182
# Subgroup: num_dribbles: [0:2[ AND shot_distance_from_goal<10.52 AND start_x>=96.60
# Size of Subgroup: 29
# ----------------------------------------
# Quality: 0.012881388949765019
# Subgroup: bodypart_name=='head/other' AND shot_angle_from_goal>=0.63 AND start_x>=96.60
# Size of Subgroup: 30
# ----------------------------------------
# Quality: 0.012832688046363262
# Subgroup: num_events: [42:84[ AND play_speed_towards_goal: [0.07:0.16[ AND start_x>=96.60
# Size of Subgroup: 6
# ----------------------------------------
# Quality: 0.012832688046363262
# Subgroup: bodypart_name=='head/other' AND play_distance_towards_goal: [39.90:56.70[ AND start_x>=96.60
# Size of Subgroup: 6
# ----------------------------------------
# Quality: 0.012621650798288975
# Subgroup: ratio_distance: [0.06:0.14[ AND shot_angle_from_goal>=0.63
# Size of Subgroup: 19
# ----------------------------------------
# Quality: 0.012597300346588097
# Subgroup: play_distance: [919.49:1748.27[ AND play_speed_towards_goal: [0.07:0.16[ AND start_x>=96.60
# Size of Subgroup: 7
# ----------------------------------------
# Quality: 0.012597300346588097
# Subgroup: num_passes: [26:51[ AND play_speed_towards_goal: [0.07:0.16[ AND start_x>=96.60
# Size of Subgroup: 7
# ----------------------------------------
# Quality: 0.012434964001915572
# Subgroup: bodypart_name=='head/other' AND shot_distance_from_goal<10.52
# Size of Subgroup: 44
# ----------------------------------------
# Quality: 0.012361912646812932
# Subgroup: play_speed: [1.85:2.28[ AND shot_distance_from_goal<10.52 AND start_x>=96.60
# Size of Subgroup: 8
# ----------------------------------------
# Quality: 0.012361912646812932
# Subgroup: num_passes: [26:51[ AND play_duration: [414.29:754.74[ AND start_x>=96.60
# Size of Subgroup: 8
# ----------------------------------------
# Quality: 0.012361912646812932
# Subgroup: num_events: [42:84[ AND play_duration: [414.29:754.74[ AND start_x>=96.60
# Size of Subgroup: 8
# ----------------------------------------
# Quality: 0.012175225850439527
# Subgroup: num_dribbles: [0:2[ AND shot_distance_from_goal<10.52
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.012126524947037769
# Subgroup: play_duration: [414.29:754.74[ AND ratio_distance: [0.03:0.06[ AND start_x>=96.60
# Size of Subgroup: 9
# ----------------------------------------
# Quality: 0.012126524947037769
# Subgroup: play_duration: [414.29:754.74[ AND play_speed_towards_goal: [0.07:0.16[ AND start_x>=96.60
# Size of Subgroup: 9
# ----------------------------------------
# Quality: 0.012126524947037769
# Subgroup: play_distance: [919.49:1748.27[ AND ratio_distance: [0.03:0.06[ AND start_x>=96.60
# Size of Subgroup: 9
# ----------------------------------------
# Quality: 0.012126524947037769
# Subgroup: play_distance: [919.49:1748.27[ AND play_duration: [414.29:754.74[ AND start_x>=96.60
# Size of Subgroup: 9
# ----------------------------------------
# Quality: 0.012126524947037769
# Subgroup: num_events: [42:84[ AND ratio_distance: [0.03:0.06[ AND start_x>=96.60
# Size of Subgroup: 9
# ----------------------------------------
# Quality: 0.012126524947037769
# Subgroup: num_dribbles: [0:2[ AND play_mean_distance_to_the_goal: [44.96:54.80[ AND ratio_distance: [0.06:0.14[
# Size of Subgroup: 9
# ----------------------------------------
# Quality: 0.012126524947037769
# Subgroup: bodypart_name=='head/other' AND play_distance_towards_goal: [39.90:56.70[ AND shot_distance_from_goal<10.52
# Size of Subgroup: 9
# ----------------------------------------
# Quality: 0.01196418860236524
# Subgroup: bodypart_name=='head/other' AND shot_angle_from_goal>=0.63
# Size of Subgroup: 46
# ----------------------------------------
# Quality: 0.011891137247262604
# Subgroup: play_speed_towards_goal: [0.07:0.16[ AND ratio_distance: [0.03:0.06[ AND start_x>=96.60
# Size of Subgroup: 10
# ----------------------------------------
# Quality: 0.011891137247262604
# Subgroup: play_mean_distance_to_the_goal: [44.96:54.80[ AND ratio_distance: [0.06:0.14[ AND shot_angle_from_goal>=0.63
# Size of Subgroup: 10
# ----------------------------------------
# Quality: 0.011891137247262604
# Subgroup: play_duration: [414.29:754.74[ AND shot_distance_from_goal<10.52 AND start_y: [32.64:38.08[
# Size of Subgroup: 10
# ----------------------------------------
# Quality: 0.011891137247262604
# Subgroup: play_duration: [414.29:754.74[ AND shot_angle_from_goal>=0.63 AND start_y: [32.64:38.08[
# Size of Subgroup: 10
# ----------------------------------------
# Quality: 0.011891137247262604
# Subgroup: num_passes: [26:51[ AND ratio_distance: [0.03:0.06[ AND start_x>=96.60
# Size of Subgroup: 10
# ----------------------------------------
# Quality: 0.011891137247262604
# Subgroup: num_passes: [26:51[ AND play_duration: [414.29:754.74[ AND start_y: [32.64:38.08[
# Size of Subgroup: 10
# ----------------------------------------
# Quality: 0.011891137247262604
# Subgroup: num_passes: [26:51[ AND play_distance: [919.49:1748.27[ AND start_x>=96.60
# Size of Subgroup: 10
# ----------------------------------------
# Quality: 0.011891137247262604
# Subgroup: num_events: [42:84[ AND play_distance: [919.49:1748.27[ AND start_x>=96.60
# Size of Subgroup: 10
# ----------------------------------------
#      quality                                           subgroup  size_sg  \
# 0   0.029318   shot_distance_from_goal<10.52 AND start_x>=96.60       57
# 1   0.029107                      shot_distance_from_goal<10.52       70
# 2   0.028872                         shot_angle_from_goal>=0.63       71
# 3   0.026518                                     start_x>=96.60       81
# 4   0.025974      shot_angle_from_goal>=0.63 AND start_x>=96.60       47
# 5   0.025974  shot_angle_from_goal>=0.63 AND shot_distance_f...       47
# 6   0.025763  shot_angle_from_goal>=0.63 AND shot_distance_f...       60
# 7   0.020722  shot_distance_from_goal<10.52 AND start_y: [32...       33
# 8   0.020722  shot_angle_from_goal>=0.63 AND shot_distance_f...       33
# 9   0.019756          start_x>=96.60 AND start_y: [32.64:38.08[       25
# 10  0.019756  shot_distance_from_goal<10.52 AND start_x>=96....       25
# 11  0.019756  shot_angle_from_goal>=0.63 AND start_x>=96.60 ...       25
# 12  0.019545  shot_angle_from_goal>=0.63 AND start_y: [32.64...       38
# 13  0.017005                             start_y: [32.64:38.08[       73
# 14  0.015730  num_dribbles: [0:2[ AND shot_angle_from_goal>=...       30
# 15  0.015211  play_distance_towards_goal: [39.90:56.70[ AND ...        8
# 16  0.014529  num_dribbles: [0:2[ AND shot_angle_from_goal>=...       23
# 17  0.014505  play_distance_towards_goal: [39.90:56.70[ AND ...       11
# 18  0.014083  bodypart_name=='head/other' AND shot_distance_...       37
# 19  0.014034  play_distance_towards_goal: [39.90:56.70[ AND ...       13
# 20  0.013588  num_dribbles: [0:2[ AND shot_angle_from_goal>=...       27
# 21  0.013141     bodypart_name=='head/other' AND start_x>=96.60       41
# 22  0.013117  num_dribbles: [0:2[ AND shot_distance_from_goa...       29
# 23  0.012881  bodypart_name=='head/other' AND shot_angle_fro...       30
# 24  0.012833  num_events: [42:84[ AND play_speed_towards_goa...        6
# 25  0.012833  bodypart_name=='head/other' AND play_distance_...        6
# 26  0.012622  ratio_distance: [0.06:0.14[ AND shot_angle_fro...       19
# 27  0.012597  play_distance: [919.49:1748.27[ AND play_speed...        7
# 28  0.012597  num_passes: [26:51[ AND play_speed_towards_goa...        7
# 29  0.012435  bodypart_name=='head/other' AND shot_distance_...       44
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0            351            15                 29              294
# 1            351            16                 29              281
# 2            351            16                 29              280
# 3            351            16                 29              270
# 4            351            13                 29              304
# 5            351            13                 29              304
# 6            351            14                 29              291
# 7            351            10                 29              318
# 8            351            10                 29              318
# 9            351             9                 29              326
# 10           351             9                 29              326
# 11           351             9                 29              326
# 12           351            10                 29              313
# 13           351            12                 29              278
# 14           351             8                 29              321
# 15           351             6                 29              343
# 16           351             7                 29              328
# 17           351             6                 29              340
# 18           351             8                 29              314
# 19           351             6                 29              338
# 20           351             7                 29              324
# 21           351             8                 29              310
# 22           351             7                 29              322
# 23           351             7                 29              321
# 24           351             5                 29              345
# 25           351             5                 29              345
# 26           351             6                 29              332
# 27           351             5                 29              344
# 28           351             5                 29              344
# 29           351             8                 29              307
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.162393                  0.837607     0.517241
# 1           0.199430                  0.800570     0.551724
# 2           0.202279                  0.797721     0.551724
# 3           0.230769                  0.769231     0.551724
# 4           0.133903                  0.866097     0.448276
# 5           0.133903                  0.866097     0.448276
# 6           0.170940                  0.829060     0.482759
# 7           0.094017                  0.905983     0.344828
# 8           0.094017                  0.905983     0.344828
# 9           0.071225                  0.928775     0.310345
# 10          0.071225                  0.928775     0.310345
# 11          0.071225                  0.928775     0.310345
# 12          0.108262                  0.891738     0.344828
# 13          0.207977                  0.792023     0.413793
# 14          0.085470                  0.914530     0.275862
# 15          0.022792                  0.977208     0.206897
# 16          0.065527                  0.934473     0.241379
# 17          0.031339                  0.968661     0.206897
# 18          0.105413                  0.894587     0.275862
# 19          0.037037                  0.962963     0.206897
# 20          0.076923                  0.923077     0.241379
# 21          0.116809                  0.883191     0.275862
# 22          0.082621                  0.917379     0.241379
# 23          0.085470                  0.914530     0.241379
# 24          0.017094                  0.982906     0.172414
# 25          0.017094                  0.982906     0.172414
# 26          0.054131                  0.945869     0.206897
# 27          0.019943                  0.980057     0.172414
# 28          0.019943                  0.980057     0.172414
# 29          0.125356                  0.874644     0.275862
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.482759         0.263158                 0.047619
# 1              0.448276         0.228571                 0.046263
# 2              0.448276         0.225352                 0.046429
# 3              0.448276         0.197531                 0.048148
# 4              0.551724         0.276596                 0.052632
# 5              0.551724         0.276596                 0.052632
# 6              0.517241         0.233333                 0.051546
# 7              0.655172         0.303030                 0.059748
# 8              0.655172         0.303030                 0.059748
# 9              0.689655         0.360000                 0.061350
# 10             0.689655         0.360000                 0.061350
# 11             0.689655         0.360000                 0.061350
# 12             0.655172         0.263158                 0.060703
# 13             0.586207         0.164384                 0.061151
# 14             0.724138         0.266667                 0.065421
# 15             0.793103         0.750000                 0.067055
# 16             0.758621         0.304348                 0.067073
# 17             0.793103         0.545455                 0.067647
# 18             0.724138         0.216216                 0.066879
# 19             0.793103         0.461538                 0.068047
# 20             0.758621         0.259259                 0.067901
# 21             0.724138         0.195122                 0.067742
# 22             0.758621         0.241379                 0.068323
# 23             0.758621         0.233333                 0.068536
# 24             0.827586         0.833333                 0.069565
# 25             0.827586         0.833333                 0.069565
# 26             0.793103         0.315789                 0.069277
# 27             0.827586         0.714286                 0.069767
# 28             0.827586         0.714286                 0.069767
# 29             0.724138         0.181818                 0.068404
#
#     target_share_dataset       lift
# 0               0.082621   3.185118
# 1               0.082621   2.766502
# 2               0.082621   2.727538
# 3               0.082621   2.390805
# 4               0.082621   3.347762
# 5               0.082621   3.347762
# 6               0.082621   2.824138
# 7               0.082621   3.667712
# 8               0.082621   3.667712
# 9               0.082621   4.357241
# 10              0.082621   4.357241
# 11              0.082621   4.357241
# 12              0.082621   3.185118
# 13              0.082621   1.989608
# 14              0.082621   3.227586
# 15              0.082621   9.077586
# 16              0.082621   3.683658
# 17              0.082621   6.601881
# 18              0.082621   2.616962
# 19              0.082621   5.586207
# 20              0.082621   3.137931
# 21              0.082621   2.361648
# 22              0.082621   2.921522
# 23              0.082621   2.824138
# 24              0.082621  10.086207
# 25              0.082621  10.086207
# 26              0.082621   3.822142
# 27              0.082621   8.645320
# 28              0.082621   8.645320
# 29              0.082621   2.200627

# %%
show_coverage(result, WB_shots_df_cp)
# Out:
# 0.1623931623931624
# 0.19943019943019943
# 0.23076923076923078
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.4045584045584046
# 0.4045584045584046
# 0.4045584045584046
# 0.4045584045584046
# 0.4045584045584046
# 0.4045584045584046
# 0.4045584045584046
# 0.4045584045584046
# 0.4045584045584046
# 0.4045584045584046
# 0.4045584045584046
# 0.4045584045584046
# 0.42735042735042733
# 0.42735042735042733
# 0.42735042735042733
# 0.42735042735042733
# 0.42735042735042733
# 0.42735042735042733
# 0.42735042735042733
# 0.42735042735042733
# 0.42735042735042733
# 0.4672364672364672
# 0.4672364672364672
# 0.4843304843304843
# 0.4843304843304843
# 0.4843304843304843
# 0.4843304843304843
# 0.4843304843304843
# 0.4843304843304843
# 0.4843304843304843
# 0.4843304843304843
# 0.5185185185185185
# 0.5185185185185185
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5384615384615384
# 0.5498575498575499
# 0.5498575498575499
# 0.5498575498575499
# Total Coverage: 0.5499

# %% [markdown]
# ### xG

# %%
MC_shots_df_cp = MC_shots_df.copy()
MC_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id"], inplace=True, axis=1)

X = MC_shots_df_cp[["bodypart_name", "shot_distance_from_goal", "shot_angle_from_goal"]]
X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
MC_shots_df_cp["xg"] = rfc.predict(X=X)

target = ps.BinaryTarget('xg', 1)

search_space = ps.create_selectors(MC_shots_df_cp, ignore=['xg', 'result_id'])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(MC_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.WRAccQF())

# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)
result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(30).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe().head(30)
# Out:
# /tmp/ipykernel_25122/2597288402.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
# Quality: 0.03031278103677302
# Subgroup: shot_distance_from_goal<10.90 AND start_x>=96.60
# Size of Subgroup: 102
# ----------------------------------------
# Quality: 0.029864497303422083
# Subgroup: shot_angle_from_goal>=0.62 AND start_x>=96.60
# Size of Subgroup: 82
# ----------------------------------------
# Quality: 0.029864497303422083
# Subgroup: shot_angle_from_goal>=0.62 AND shot_distance_from_goal<10.90 AND start_x>=96.60
# Size of Subgroup: 82
# ----------------------------------------
# Quality: 0.029284203636323634
# Subgroup: shot_distance_from_goal<10.90
# Size of Subgroup: 119
# ----------------------------------------
# Quality: 0.0288359199029727
# Subgroup: shot_angle_from_goal>=0.62 AND shot_distance_from_goal<10.90
# Size of Subgroup: 99
# ----------------------------------------
# Quality: 0.027529571600262922
# Subgroup: start_x>=96.60
# Size of Subgroup: 148
# ----------------------------------------
# Quality: 0.027504819737685263
# Subgroup: shot_angle_from_goal>=0.62
# Size of Subgroup: 121
# ----------------------------------------
# Quality: 0.02233443066590761
# Subgroup: start_x>=96.60 AND start_y: [31.96:37.40[
# Size of Subgroup: 42
# ----------------------------------------
# Quality: 0.02233443066590761
# Subgroup: shot_distance_from_goal<10.90 AND start_x>=96.60 AND start_y: [31.96:37.40[
# Size of Subgroup: 42
# ----------------------------------------
# Quality: 0.02233443066590761
# Subgroup: shot_angle_from_goal>=0.62 AND start_x>=96.60 AND start_y: [31.96:37.40[
# Size of Subgroup: 42
# ----------------------------------------
# Quality: 0.021608376030296278
# Subgroup: shot_distance_from_goal<10.90 AND start_y: [31.96:37.40[
# Size of Subgroup: 54
# ----------------------------------------
# Quality: 0.021608376030296278
# Subgroup: shot_angle_from_goal>=0.62 AND shot_distance_from_goal<10.90 AND start_y: [31.96:37.40[
# Size of Subgroup: 54
# ----------------------------------------
# Quality: 0.02100333050062017
# Subgroup: shot_angle_from_goal>=0.62 AND start_y: [31.96:37.40[
# Size of Subgroup: 64
# ----------------------------------------
# Quality: 0.018145865476377098
# Subgroup: bodypart_name=='foot_left' AND shot_angle_from_goal>=0.62 AND start_x>=96.60
# Size of Subgroup: 29
# ----------------------------------------
# Quality: 0.017903847264506653
# Subgroup: bodypart_name=='foot_left' AND shot_angle_from_goal>=0.62 AND shot_distance_from_goal<10.90
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.0176013244996686
# Subgroup: play_distance_towards_goal>=61.95 AND shot_distance_from_goal<10.90 AND start_x>=96.60
# Size of Subgroup: 38
# ----------------------------------------
# Quality: 0.01754081994670099
# Subgroup: bodypart_name=='foot_left' AND shot_distance_from_goal<10.90 AND start_x>=96.60
# Size of Subgroup: 39
# ----------------------------------------
# Quality: 0.01743356187553113
# Subgroup: start_y: [31.96:37.40[
# Size of Subgroup: 123
# ----------------------------------------
# Quality: 0.017359306287798155
# Subgroup: play_distance_towards_goal>=61.95 AND shot_distance_from_goal<10.90
# Size of Subgroup: 42
# ----------------------------------------
# Quality: 0.017298801734830543
# Subgroup: bodypart_name=='foot_left' AND shot_distance_from_goal<10.90
# Size of Subgroup: 43
# ----------------------------------------
# Quality: 0.017298801734830543
# Subgroup: bodypart_name=='foot_left' AND shot_angle_from_goal>=0.62
# Size of Subgroup: 43
# ----------------------------------------
# Quality: 0.01669375620515444
# Subgroup: play_distance_towards_goal>=61.95 AND start_x>=96.60
# Size of Subgroup: 53
# ----------------------------------------
# Quality: 0.016366481577738727
# Subgroup: play_distance_towards_goal>=61.95 AND shot_angle_from_goal>=0.62 AND start_x>=96.60
# Size of Subgroup: 31
# ----------------------------------------
# Quality: 0.016330728887348774
# Subgroup: bodypart_name=='foot_left' AND start_x>=96.60
# Size of Subgroup: 59
# ----------------------------------------
# Quality: 0.016124463365868282
# Subgroup: play_distance_towards_goal>=61.95 AND shot_angle_from_goal>=0.62 AND shot_distance_from_goal<10.90
# Size of Subgroup: 35
# ----------------------------------------
# Quality: 0.01582194060103023
# Subgroup: play_distance_towards_goal>=61.95 AND shot_angle_from_goal>=0.62
# Size of Subgroup: 40
# ----------------------------------------
# Quality: 0.01446608857316513
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.62 AND start_x>=96.60
# Size of Subgroup: 35
# ----------------------------------------
# Quality: 0.01446608857316513
# Subgroup: bodypart_name=='foot_right' AND shot_distance_from_goal<10.90 AND start_x>=96.60
# Size of Subgroup: 35
# ----------------------------------------
# Quality: 0.014199318498717027
# Subgroup: bodypart_name=='foot_left' AND start_x>=96.60 AND start_y: [31.96:37.40[
# Size of Subgroup: 12
# ----------------------------------------
# Quality: 0.014042556702391854
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.62 AND shot_distance_from_goal<10.90
# Size of Subgroup: 42
# ----------------------------------------
#      quality                                           subgroup  size_sg  \
# 0   0.030313   shot_distance_from_goal<10.90 AND start_x>=96.60      102
# 1   0.029864      shot_angle_from_goal>=0.62 AND start_x>=96.60       82
# 2   0.029864  shot_angle_from_goal>=0.62 AND shot_distance_f...       82
# 3   0.029284                      shot_distance_from_goal<10.90      119
# 4   0.028836  shot_angle_from_goal>=0.62 AND shot_distance_f...       99
# 5   0.027530                                     start_x>=96.60      148
# 6   0.027505                         shot_angle_from_goal>=0.62      121
# 7   0.022334          start_x>=96.60 AND start_y: [31.96:37.40[       42
# 8   0.022334  shot_distance_from_goal<10.90 AND start_x>=96....       42
# 9   0.022334  shot_angle_from_goal>=0.62 AND start_x>=96.60 ...       42
# 10  0.021608  shot_distance_from_goal<10.90 AND start_y: [31...       54
# 11  0.021608  shot_angle_from_goal>=0.62 AND shot_distance_f...       54
# 12  0.021003  shot_angle_from_goal>=0.62 AND start_y: [31.96...       64
# 13  0.018146  bodypart_name=='foot_left' AND shot_angle_from...       29
# 14  0.017904  bodypart_name=='foot_left' AND shot_angle_from...       33
# 15  0.017601  play_distance_towards_goal>=61.95 AND shot_dis...       38
# 16  0.017541  bodypart_name=='foot_left' AND shot_distance_f...       39
# 17  0.017434                             start_y: [31.96:37.40[      123
# 18  0.017359  play_distance_towards_goal>=61.95 AND shot_dis...       42
# 19  0.017299  bodypart_name=='foot_left' AND shot_distance_f...       43
# 20  0.017299  bodypart_name=='foot_left' AND shot_angle_from...       43
# 21  0.016694  play_distance_towards_goal>=61.95 AND start_x>...       53
# 22  0.016366  play_distance_towards_goal>=61.95 AND shot_ang...       31
# 23  0.016331      bodypart_name=='foot_left' AND start_x>=96.60       59
# 24  0.016124  play_distance_towards_goal>=61.95 AND shot_ang...       35
# 25  0.015822  play_distance_towards_goal>=61.95 AND shot_ang...       40
# 26  0.014466  num_dribbles: [0:2[ AND shot_angle_from_goal>=...       35
# 27  0.014466  bodypart_name=='foot_right' AND shot_distance_...       35
# 28  0.014199  bodypart_name=='foot_left' AND start_x>=96.60 ...       12
# 29  0.014043  num_dribbles: [0:2[ AND shot_angle_from_goal>=...       42
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0            603            22                 22              501
# 1            603            21                 22              521
# 2            603            21                 22              521
# 3            603            22                 22              484
# 4            603            21                 22              504
# 5            603            22                 22              455
# 6            603            21                 22              482
# 7            603            15                 22              561
# 8            603            15                 22              561
# 9            603            15                 22              561
# 10           603            15                 22              549
# 11           603            15                 22              549
# 12           603            15                 22              539
# 13           603            12                 22              574
# 14           603            12                 22              570
# 15           603            12                 22              565
# 16           603            12                 22              564
# 17           603            15                 22              480
# 18           603            12                 22              561
# 19           603            12                 22              560
# 20           603            12                 22              560
# 21           603            12                 22              550
# 22           603            11                 22              572
# 23           603            12                 22              544
# 24           603            11                 22              568
# 25           603            11                 22              563
# 26           603            10                 22              568
# 27           603            10                 22              568
# 28           603             9                 22              591
# 29           603            10                 22              561
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.169154                  0.830846     1.000000
# 1           0.135987                  0.864013     0.954545
# 2           0.135987                  0.864013     0.954545
# 3           0.197347                  0.802653     1.000000
# 4           0.164179                  0.835821     0.954545
# 5           0.245439                  0.754561     1.000000
# 6           0.200663                  0.799337     0.954545
# 7           0.069652                  0.930348     0.681818
# 8           0.069652                  0.930348     0.681818
# 9           0.069652                  0.930348     0.681818
# 10          0.089552                  0.910448     0.681818
# 11          0.089552                  0.910448     0.681818
# 12          0.106136                  0.893864     0.681818
# 13          0.048093                  0.951907     0.545455
# 14          0.054726                  0.945274     0.545455
# 15          0.063018                  0.936982     0.545455
# 16          0.064677                  0.935323     0.545455
# 17          0.203980                  0.796020     0.681818
# 18          0.069652                  0.930348     0.545455
# 19          0.071310                  0.928690     0.545455
# 20          0.071310                  0.928690     0.545455
# 21          0.087894                  0.912106     0.545455
# 22          0.051410                  0.948590     0.500000
# 23          0.097844                  0.902156     0.545455
# 24          0.058043                  0.941957     0.500000
# 25          0.066335                  0.933665     0.500000
# 26          0.058043                  0.941957     0.454545
# 27          0.058043                  0.941957     0.454545
# 28          0.019900                  0.980100     0.409091
# 29          0.069652                  0.930348     0.454545
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.000000         0.215686                 0.000000
# 1              0.045455         0.256098                 0.001919
# 2              0.045455         0.256098                 0.001919
# 3              0.000000         0.184874                 0.000000
# 4              0.045455         0.212121                 0.001984
# 5              0.000000         0.148649                 0.000000
# 6              0.045455         0.173554                 0.002075
# 7              0.318182         0.357143                 0.012478
# 8              0.318182         0.357143                 0.012478
# 9              0.318182         0.357143                 0.012478
# 10             0.318182         0.277778                 0.012750
# 11             0.318182         0.277778                 0.012750
# 12             0.318182         0.234375                 0.012987
# 13             0.454545         0.413793                 0.017422
# 14             0.454545         0.363636                 0.017544
# 15             0.454545         0.315789                 0.017699
# 16             0.454545         0.307692                 0.017730
# 17             0.318182         0.121951                 0.014583
# 18             0.454545         0.285714                 0.017825
# 19             0.454545         0.279070                 0.017857
# 20             0.454545         0.279070                 0.017857
# 21             0.454545         0.226415                 0.018182
# 22             0.500000         0.354839                 0.019231
# 23             0.454545         0.203390                 0.018382
# 24             0.500000         0.314286                 0.019366
# 25             0.500000         0.275000                 0.019538
# 26             0.545455         0.285714                 0.021127
# 27             0.545455         0.285714                 0.021127
# 28             0.590909         0.750000                 0.021997
# 29             0.545455         0.238095                 0.021390
#
#     target_share_dataset       lift
# 0               0.036484   5.911765
# 1               0.036484   7.019401
# 2               0.036484   7.019401
# 3               0.036484   5.067227
# 4               0.036484   5.814050
# 5               0.036484   4.074324
# 6               0.036484   4.756950
# 7               0.036484   9.788961
# 8               0.036484   9.788961
# 9               0.036484   9.788961
# 10              0.036484   7.613636
# 11              0.036484   7.613636
# 12              0.036484   6.424006
# 13              0.036484  11.341693
# 14              0.036484   9.966942
# 15              0.036484   8.655502
# 16              0.036484   8.433566
# 17              0.036484   3.342572
# 18              0.036484   7.831169
# 19              0.036484   7.649049
# 20              0.036484   7.649049
# 21              0.036484   6.205832
# 22              0.036484   9.725806
# 23              0.036484   5.574730
# 24              0.036484   8.614286
# 25              0.036484   7.537500
# 26              0.036484   7.831169
# 27              0.036484   7.831169
# 28              0.036484  20.556818
# 29              0.036484   6.525974

# %%
show_coverage(result, MC_shots_df_cp)
# Out:
# 0.1691542288557214
# 0.1691542288557214
# 0.1691542288557214
# 0.19734660033167495
# 0.19734660033167495
# 0.2736318407960199
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.3101160862354892
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.4079601990049751
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# 0.49585406301824214
# Total Coverage: 0.4959

# %%
NC_shots_df_cp = NC_shots_df.copy()
NC_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id"], inplace=True, axis=1)

X = NC_shots_df_cp[["bodypart_name", "shot_distance_from_goal", "shot_angle_from_goal"]]
X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
NC_shots_df_cp["xg"] = rfc.predict(X=X)

target = ps.BinaryTarget('xg', 1)

search_space = ps.create_selectors(NC_shots_df_cp, ignore=['xg', 'result_id'])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(NC_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.WRAccQF())

# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)
result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(30).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# /tmp/ipykernel_25122/1565793560.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
# Quality: 0.02466983938132064
# Subgroup: shot_distance_from_goal<11.04 AND start_y: [33.32:38.08[
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.02466983938132064
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04 AND start_y: [33.32:38.08[
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.02421177870315289
# Subgroup: shot_angle_from_goal>=0.61 AND start_y: [33.32:38.08[
# Size of Subgroup: 40
# ----------------------------------------
# Quality: 0.02275431290898275
# Subgroup: start_x>=96.60 AND start_y: [33.32:38.08[
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.02275431290898275
# Subgroup: shot_distance_from_goal<11.04 AND start_x>=96.60 AND start_y: [33.32:38.08[
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.02275431290898275
# Subgroup: shot_angle_from_goal>=0.61 AND start_x>=96.60 AND start_y: [33.32:38.08[
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.0221832242712671
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# Size of Subgroup: 71
# ----------------------------------------
# Quality: 0.021463414634146347
# Subgroup: shot_distance_from_goal<11.04
# Size of Subgroup: 82
# ----------------------------------------
# Quality: 0.021463414634146347
# Subgroup: shot_angle_from_goal>=0.61
# Size of Subgroup: 82
# ----------------------------------------
# Quality: 0.020874479476502082
# Subgroup: start_y: [33.32:38.08[
# Size of Subgroup: 91
# ----------------------------------------
# Quality: 0.02072575847709697
# Subgroup: shot_angle_from_goal>=0.61 AND start_x>=96.60
# Size of Subgroup: 56
# ----------------------------------------
# Quality: 0.02072575847709697
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 56
# ----------------------------------------
# Quality: 0.020005948839976202
# Subgroup: shot_distance_from_goal<11.04 AND start_x>=96.60
# Size of Subgroup: 67
# ----------------------------------------
# Quality: 0.019024390243902442
# Subgroup: start_x>=96.60
# Size of Subgroup: 82
# ----------------------------------------
# Quality: 0.013783462224866152
# Subgroup: play_distance_towards_goal>=61.95 AND shot_distance_from_goal<11.04 AND start_y: [33.32:38.08[
# Size of Subgroup: 13
# ----------------------------------------
# Quality: 0.013521713265913147
# Subgroup: play_distance_towards_goal>=61.95 AND shot_angle_from_goal>=0.61 AND start_y: [33.32:38.08[
# Size of Subgroup: 17
# ----------------------------------------
# Quality: 0.01319452706722189
# Subgroup: play_distance_towards_goal>=61.95 AND start_y: [33.32:38.08[
# Size of Subgroup: 22
# ----------------------------------------
# Quality: 0.012998215348007137
# Subgroup: play_distance_towards_goal>=61.95 AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.012605591909577631
# Subgroup: play_distance_towards_goal>=61.95 AND shot_distance_from_goal<11.04
# Size of Subgroup: 31
# ----------------------------------------
# Quality: 0.012605591909577631
# Subgroup: play_distance_towards_goal>=61.95 AND shot_angle_from_goal>=0.61
# Size of Subgroup: 31
# ----------------------------------------
# Quality: 0.011802498512790006
# Subgroup: bodypart_name=='foot_left' AND start_x>=96.60 AND start_y: [33.32:38.08[
# Size of Subgroup: 6
# ----------------------------------------
# Quality: 0.011671624033313503
# Subgroup: num_dribbles: [1:3[ AND start_x>=96.60 AND start_y: [33.32:38.08[
# Size of Subgroup: 8
# ----------------------------------------
# Quality: 0.011671624033313503
# Subgroup: bodypart_name=='foot_left' AND shot_distance_from_goal<11.04 AND start_y: [33.32:38.08[
# Size of Subgroup: 8
# ----------------------------------------
# Quality: 0.011606186793575252
# Subgroup: play_mean_distance_to_the_goal<41.87 AND start_x>=96.60 AND start_y: [33.32:38.08[
# Size of Subgroup: 9
# ----------------------------------------
# Quality: 0.011606186793575252
# Subgroup: play_distance_towards_goal>=61.95 AND start_x>=96.60 AND start_y: [33.32:38.08[
# Size of Subgroup: 9
# ----------------------------------------
# Quality: 0.011606186793575252
# Subgroup: bodypart_name=='foot_left' AND shot_angle_from_goal>=0.61 AND start_y: [33.32:38.08[
# Size of Subgroup: 9
# ----------------------------------------
# Quality: 0.011540749553837002
# Subgroup: play_mean_distance_to_the_goal<41.87 AND shot_distance_from_goal<11.04 AND start_y: [33.32:38.08[
# Size of Subgroup: 10
# ----------------------------------------
# Quality: 0.011540749553837002
# Subgroup: bodypart_name=='foot_right' AND shot_distance_from_goal<11.04 AND start_y: [33.32:38.08[
# Size of Subgroup: 10
# ----------------------------------------
# Quality: 0.01147531231409875
# Subgroup: play_mean_distance_to_the_goal<41.87 AND shot_angle_from_goal>=0.61 AND start_y: [33.32:38.08[
# Size of Subgroup: 11
# ----------------------------------------
# Quality: 0.01147531231409875
# Subgroup: num_dribbles: [1:3[ AND shot_distance_from_goal<11.04 AND start_y: [33.32:38.08[
# Size of Subgroup: 11
# ----------------------------------------
#      quality                                           subgroup  size_sg  \
# 0   0.024670  shot_distance_from_goal<11.04 AND start_y: [33...       33
# 1   0.024670  shot_angle_from_goal>=0.61 AND shot_distance_f...       33
# 2   0.024212  shot_angle_from_goal>=0.61 AND start_y: [33.32...       40
# 3   0.022754          start_x>=96.60 AND start_y: [33.32:38.08[       25
# 4   0.022754  shot_distance_from_goal<11.04 AND start_x>=96....       25
# ..       ...                                                ...      ...
# 95  0.009167  play_distance_towards_goal>=61.95 AND play_spe...        9
# 96  0.009167  play_distance: [452.59:864.79[ AND shot_angle_...        9
# 97  0.009167  num_passes<5 AND shot_angle_from_goal>=0.61 AN...        9
# 98  0.009167  num_events<10 AND shot_angle_from_goal>=0.61 A...        9
# 99  0.009102  ratio_distance: [0.06:0.13[ AND shot_angle_fro...       10
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0            410            11                 11              377
# 1            410            11                 11              377
# 2            410            11                 11              370
# 3            410            10                 11              385
# 4            410            10                 11              385
# ..           ...           ...                ...              ...
# 95           410             4                 11              401
# 96           410             4                 11              401
# 97           410             4                 11              401
# 98           410             4                 11              401
# 99           410             4                 11              400
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.080488                  0.919512     1.000000
# 1           0.080488                  0.919512     1.000000
# 2           0.097561                  0.902439     1.000000
# 3           0.060976                  0.939024     0.909091
# 4           0.060976                  0.939024     0.909091
# ..               ...                       ...          ...
# 95          0.021951                  0.978049     0.363636
# 96          0.021951                  0.978049     0.363636
# 97          0.021951                  0.978049     0.363636
# 98          0.021951                  0.978049     0.363636
# 99          0.024390                  0.975610     0.363636
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.000000         0.333333                 0.000000
# 1              0.000000         0.333333                 0.000000
# 2              0.000000         0.275000                 0.000000
# 3              0.090909         0.400000                 0.002597
# 4              0.090909         0.400000                 0.002597
# ..                  ...              ...                      ...
# 95             0.636364         0.444444                 0.017456
# 96             0.636364         0.444444                 0.017456
# 97             0.636364         0.444444                 0.017456
# 98             0.636364         0.444444                 0.017456
# 99             0.636364         0.400000                 0.017500
#
#     target_share_dataset       lift
# 0               0.026829  12.424242
# 1               0.026829  12.424242
# 2               0.026829  10.250000
# 3               0.026829  14.909091
# 4               0.026829  14.909091
# ..                   ...        ...
# 95              0.026829  16.565657
# 96              0.026829  16.565657
# 97              0.026829  16.565657
# 98              0.026829  16.565657
# 99              0.026829  14.909091
#
# [100 rows x 15 columns]

# %%
show_coverage(result, NC_shots_df_cp)
# Out:
# 0.08048780487804878
# 0.08048780487804878
# 0.0975609756097561
# 0.0975609756097561
# 0.0975609756097561
# 0.0975609756097561
# 0.1902439024390244
# 0.21707317073170732
# 0.22682926829268293
# 0.35121951219512193
# 0.35121951219512193
# 0.35121951219512193
# 0.35121951219512193
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# Total Coverage: 0.3878

# %%
WB_shots_df_cp = WB_shots_df.copy()
WB_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id"], inplace=True, axis=1)

X = WB_shots_df_cp[["bodypart_name", "shot_distance_from_goal", "shot_angle_from_goal"]]
X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
WB_shots_df_cp["xg"] = rfc.predict(X=X)

target = ps.BinaryTarget('xg', 1)

search_space = ps.create_selectors(WB_shots_df_cp, ignore=['xg', 'result_id'])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(WB_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.WRAccQF())

# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)
result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(30).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# /tmp/ipykernel_25122/4256686019.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
# Quality: 0.030705919594808485
# Subgroup: shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52
# Size of Subgroup: 60
# ----------------------------------------
# Quality: 0.02965073335443706
# Subgroup: shot_distance_from_goal<10.52
# Size of Subgroup: 70
# ----------------------------------------
# Quality: 0.029545214730399918
# Subgroup: shot_angle_from_goal>=0.63
# Size of Subgroup: 71
# ----------------------------------------
# Quality: 0.029228658858288487
# Subgroup: shot_angle_from_goal>=0.63 AND start_x>=96.60
# Size of Subgroup: 47
# ----------------------------------------
# Quality: 0.029228658858288487
# Subgroup: shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52 AND start_x>=96.60
# Size of Subgroup: 47
# ----------------------------------------
# Quality: 0.028173472617917063
# Subgroup: shot_distance_from_goal<10.52 AND start_x>=96.60
# Size of Subgroup: 57
# ----------------------------------------
# Quality: 0.02564102564102564
# Subgroup: start_x>=96.60
# Size of Subgroup: 81
# ----------------------------------------
# Quality: 0.02321409728817136
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.63 AND start_x>=96.60
# Size of Subgroup: 23
# ----------------------------------------
# Quality: 0.022792022792022793
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52
# Size of Subgroup: 27
# ----------------------------------------
# Quality: 0.022580985543948506
# Subgroup: num_dribbles: [0:2[ AND shot_distance_from_goal<10.52 AND start_x>=96.60
# Size of Subgroup: 29
# ----------------------------------------
# Quality: 0.022475466919911365
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.63
# Size of Subgroup: 30
# ----------------------------------------
# Quality: 0.022158911047799934
# Subgroup: shot_distance_from_goal<10.52 AND start_y: [32.64:38.08[
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.022158911047799934
# Subgroup: shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52 AND start_y: [32.64:38.08[
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.022158911047799934
# Subgroup: num_dribbles: [0:2[ AND shot_distance_from_goal<10.52
# Size of Subgroup: 33
# ----------------------------------------
# Quality: 0.021631317927614222
# Subgroup: shot_angle_from_goal>=0.63 AND start_y: [32.64:38.08[
# Size of Subgroup: 38
# ----------------------------------------
# Quality: 0.021525799303577082
# Subgroup: num_dribbles: [0:2[ AND start_x>=96.60
# Size of Subgroup: 39
# ----------------------------------------
# Quality: 0.02015405719109423
# Subgroup: start_x>=96.60 AND start_y: [32.64:38.08[
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.02015405719109423
# Subgroup: shot_distance_from_goal<10.52 AND start_x>=96.60 AND start_y: [32.64:38.08[
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.02015405719109423
# Subgroup: shot_angle_from_goal>=0.63 AND start_x>=96.60 AND start_y: [32.64:38.08[
# Size of Subgroup: 25
# ----------------------------------------
# Quality: 0.018360240582462807
# Subgroup: play_mean_distance_to_the_goal<44.96 AND shot_angle_from_goal>=0.63 AND start_x>=96.60
# Size of Subgroup: 15
# ----------------------------------------
# Quality: 0.018254721958425663
# Subgroup: play_mean_distance_to_the_goal<44.96 AND shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52
# Size of Subgroup: 16
# ----------------------------------------
# Quality: 0.018149203334388516
# Subgroup: play_mean_distance_to_the_goal<44.96 AND shot_angle_from_goal>=0.63
# Size of Subgroup: 17
# ----------------------------------------
# Quality: 0.018043684710351376
# Subgroup: play_mean_distance_to_the_goal<44.96 AND shot_distance_from_goal<10.52 AND start_x>=96.60
# Size of Subgroup: 18
# ----------------------------------------
# Quality: 0.017938166086314232
# Subgroup: start_y: [32.64:38.08[
# Size of Subgroup: 73
# ----------------------------------------
# Quality: 0.017938166086314232
# Subgroup: play_mean_distance_to_the_goal<44.96 AND shot_distance_from_goal<10.52
# Size of Subgroup: 19
# ----------------------------------------
# Quality: 0.017199535718054236
# Subgroup: play_mean_distance_to_the_goal<44.96 AND start_x>=96.60
# Size of Subgroup: 26
# ----------------------------------------
# Quality: 0.015827793605571384
# Subgroup: play_std_distance_to_the_goal<17.39 AND shot_angle_from_goal>=0.63 AND start_x>=96.60
# Size of Subgroup: 12
# ----------------------------------------
# Quality: 0.015827793605571384
# Subgroup: play_std_distance_to_the_goal<17.39 AND shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52
# Size of Subgroup: 12
# ----------------------------------------
# Quality: 0.015827793605571384
# Subgroup: play_mean_distance_to_the_goal<44.96 AND play_std_distance_to_the_goal<17.39 AND shot_angle_from_goal>=0.63
# Size of Subgroup: 12
# ----------------------------------------
# Quality: 0.015827793605571384
# Subgroup: play_distance<201.68 AND play_mean_distance_to_the_goal<44.96 AND shot_angle_from_goal>=0.63
# Size of Subgroup: 12
# ----------------------------------------
#      quality                                           subgroup  size_sg  \
# 0   0.030706  shot_angle_from_goal>=0.63 AND shot_distance_f...       60
# 1   0.029651                      shot_distance_from_goal<10.52       70
# 2   0.029545                         shot_angle_from_goal>=0.63       71
# 3   0.029229      shot_angle_from_goal>=0.63 AND start_x>=96.60       47
# 4   0.029229  shot_angle_from_goal>=0.63 AND shot_distance_f...       47
# ..       ...                                                ...      ...
# 95  0.014878  num_dribbles: [0:2[ AND play_duration<71.54 AN...       21
# 96  0.014773  num_events<10 AND play_mean_distance_to_the_go...       22
# 97  0.014773  num_events<10 AND num_passes<5 AND start_x>=96.60       22
# 98  0.014773  num_dribbles: [0:2[ AND play_mean_distance_to_...       22
# 99  0.014667  num_passes<5 AND play_distance<201.68 AND star...       23
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0            351            13                 13              291
# 1            351            13                 13              281
# 2            351            13                 13              280
# 3            351            12                 13              304
# 4            351            12                 13              304
# ..           ...           ...                ...              ...
# 95           351             6                 13              330
# 96           351             6                 13              329
# 97           351             6                 13              329
# 98           351             6                 13              329
# 99           351             6                 13              328
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.170940                  0.829060     1.000000
# 1           0.199430                  0.800570     1.000000
# 2           0.202279                  0.797721     1.000000
# 3           0.133903                  0.866097     0.923077
# 4           0.133903                  0.866097     0.923077
# ..               ...                       ...          ...
# 95          0.059829                  0.940171     0.461538
# 96          0.062678                  0.937322     0.461538
# 97          0.062678                  0.937322     0.461538
# 98          0.062678                  0.937322     0.461538
# 99          0.065527                  0.934473     0.461538
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.000000         0.216667                 0.000000
# 1              0.000000         0.185714                 0.000000
# 2              0.000000         0.183099                 0.000000
# 3              0.076923         0.255319                 0.003289
# 4              0.076923         0.255319                 0.003289
# ..                  ...              ...                      ...
# 95             0.538462         0.285714                 0.021212
# 96             0.538462         0.272727                 0.021277
# 97             0.538462         0.272727                 0.021277
# 98             0.538462         0.272727                 0.021277
# 99             0.538462         0.260870                 0.021341
#
#     target_share_dataset      lift
# 0               0.037037  5.850000
# 1               0.037037  5.014286
# 2               0.037037  4.943662
# 3               0.037037  6.893617
# 4               0.037037  6.893617
# ..                   ...       ...
# 95              0.037037  7.714286
# 96              0.037037  7.363636
# 97              0.037037  7.363636
# 98              0.037037  7.363636
# 99              0.037037  7.043478
#
# [100 rows x 15 columns]

# %%
show_coverage(result, WB_shots_df_cp)
# Out:
# 0.17094017094017094
# 0.19943019943019943
# 0.23076923076923078
# 0.23076923076923078
# 0.23076923076923078
# 0.23076923076923078
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.29914529914529914
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# 0.39886039886039887
# Total Coverage: 0.3989

# %% [markdown]
# ### VAEP

# %%
all_action_values_cp = all_action_values.copy()
all_action_values_cp.drop(["original_event_id", "result_name", "action_id", "type_name", "end_x", "end_y"], inplace=True, axis=1)

MC_shots_df_cp = MC_shots_df.copy()
NC_shots_df_cp = NC_shots_df.copy()
WB_shots_df_cp = WB_shots_df.copy()

MC_shots_df_cp = MC_shots_df_cp.merge(all_action_values_cp, on=['game_id', 'player_id', 'start_x', 'start_y'], how='left')
NC_shots_df_cp = NC_shots_df_cp.merge(all_action_values_cp, on=['game_id', 'player_id', 'start_x', 'start_y'], how='left')
WB_shots_df_cp = WB_shots_df_cp.merge(all_action_values_cp, on=['game_id', 'player_id', 'start_x', 'start_y'], how='left')

# %%
MC_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.NumericTarget('Pscores')

search_space = ps.create_selectors(MC_shots_df_cp, ignore=["Pscores", "Pconcedes", "offensive_value", "defensive_value", "vaep_value"])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(MC_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.StandardQFNumeric(1.0))
# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)

result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(30).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    # print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# Quality: 29.6915140748024
# Subgroup: shot_distance_from_goal<11.03
# ----------------------------------------
# Quality: 29.60809600353241
# Subgroup: shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 26.88896682858467
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.03
# ----------------------------------------
# Quality: 26.594013959169388
# Subgroup: start_x>=96.60
# ----------------------------------------
# Quality: 25.6968614757061
# Subgroup: shot_distance_from_goal<11.03 AND start_x>=96.60
# ----------------------------------------
# Quality: 22.89431345462799
# Subgroup: shot_angle_from_goal>=0.61 AND start_x>=96.60
# ----------------------------------------
# Quality: 22.89431345462799
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.03 AND start_x>=96.60
# ----------------------------------------
# Quality: 14.21689122915268
# Subgroup: player_rank: [0.02:0.03[ AND shot_distance_from_goal<11.03
# ----------------------------------------
# Quality: 13.961477041244507
# Subgroup: player_rank: [0.02:0.03[ AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 13.551230192184448
# Subgroup: player_rank: [0.02:0.03[ AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.03
# ----------------------------------------
# Quality: 13.468286246061325
# Subgroup: num_dribbles: [0:2[ AND start_x>=96.60
# ----------------------------------------
# Quality: 12.961565136909485
# Subgroup: bodypart_name=='foot_left' AND shot_distance_from_goal<11.03
# ----------------------------------------
# Quality: 12.943377524614334
# Subgroup: shot_angle_from_goal>=0.61 AND start_y: [31.96:36.72[
# ----------------------------------------
# Quality: 12.808806478977203
# Subgroup: bodypart_name=='foot_left' AND start_x>=96.60
# ----------------------------------------
# Quality: 12.76588261127472
# Subgroup: num_dribbles: [0:2[ AND shot_distance_from_goal<11.03 AND start_x>=96.60
# ----------------------------------------
# Quality: 12.722537219524384
# Subgroup: bodypart_name=='foot_right' AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 12.601834803819656
# Subgroup: num_dribbles: [0:2[ AND shot_distance_from_goal<11.03
# ----------------------------------------
# Quality: 12.58206233382225
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 12.455913096666336
# Subgroup: player_rank: [0.02:0.03[ AND start_x>=96.60
# ----------------------------------------
# Quality: 12.413530588150024
# Subgroup: num_passes: [6:18[ AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 12.335032939910889
# Subgroup: shot_distance_from_goal<11.03 AND start_y: [31.96:36.72[
# ----------------------------------------
# Quality: 12.335032939910889
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.03 AND start_y: [31.96:36.72[
# ----------------------------------------
# Quality: 12.108084857463837
# Subgroup: bodypart_name=='foot_left' AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 12.072778344154358
# Subgroup: player_rank: [0.02:0.03[ AND shot_distance_from_goal<11.03 AND start_x>=96.60
# ----------------------------------------
# Quality: 11.756235122680664
# Subgroup: num_passes: [6:18[ AND shot_distance_from_goal<11.03
# ----------------------------------------
# Quality: 11.47312867641449
# Subgroup: bodypart_name=='foot_left' AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.03
# ----------------------------------------
# Quality: 11.407116889953613
# Subgroup: player_rank: [0.02:0.03[ AND shot_angle_from_goal>=0.61 AND start_x>=96.60
# ----------------------------------------
# Quality: 11.387495249509811
# Subgroup: start_x>=96.60 AND total_time_per_play<2.87
# ----------------------------------------
# Quality: 11.318173557519913
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.61 AND start_x>=96.60
# ----------------------------------------
# Quality: 11.246068596839905
# Subgroup: bodypart_name=='foot_right' AND shot_distance_from_goal<11.03
# ----------------------------------------
#       quality                                           subgroup  size_sg  \
# 0   29.691514                      shot_distance_from_goal<11.03      122
# 1   29.608096                         shot_angle_from_goal>=0.61      122
# 2   26.888967  shot_angle_from_goal>=0.61 AND shot_distance_f...      101
# 3   26.594014                                     start_x>=96.60      151
# 4   25.696861   shot_distance_from_goal<11.03 AND start_x>=96.60      103
# ..        ...                                                ...      ...
# 95   8.121586  num_dribbles: [2:3[ AND shot_distance_from_goa...       17
# 96   8.118326  num_passes: [6:18[ AND play_distance: [183.48:...       24
# 97   8.113190  shot_angle_from_goal>=0.61 AND total_time_per_...       30
# 98   8.112234                      play_speed_towards_goal>=0.56      122
# 99   8.080756  ratio_distance: [0.06:0.14[ AND shot_angle_fro...       31
#
#     size_dataset   mean_sg  mean_dataset    std_sg  std_dataset  median_sg  \
# 0            610  0.417650      0.174277  0.463023     0.344937   0.046805
# 1            610  0.416966      0.174277  0.463104     0.344937   0.046295
# 2            610  0.440504      0.174277  0.466797     0.344937   0.048291
# 3            610  0.350396      0.174277  0.445330     0.344937   0.041428
# 4            610  0.423761      0.174277  0.464014     0.344937   0.048291
# ..           ...       ...           ...       ...          ...        ...
# 95           610  0.652017      0.174277  0.449189     0.344937   0.979673
# 96           610  0.512540      0.174277  0.471692     0.344937   0.524886
# 97           610  0.444716      0.174277  0.470419     0.344937   0.042437
# 98           610  0.240770      0.174277  0.395328     0.344937   0.033571
# 99           610  0.434946      0.174277  0.464428     0.344937   0.048291
#
#     median_dataset    max_sg  max_dataset    min_sg  min_dataset  mean_lift  \
# 0         0.028802  0.994042     0.994042  0.020629      0.00368   2.396475
# 1         0.028802  0.994042     0.994042  0.020629      0.00368   2.392551
# 2         0.028802  0.994042     0.994042  0.020629      0.00368   2.527613
# 3         0.028802  0.994042     0.994042  0.018457      0.00368   2.010572
# 4         0.028802  0.994042     0.994042  0.020629      0.00368   2.431540
# ..             ...       ...          ...       ...          ...        ...
# 95        0.028802  0.988301     0.994042  0.022437      0.00368   3.741274
# 96        0.028802  0.993361     0.994042  0.021840      0.00368   2.940956
# 97        0.028802  0.994042     0.994042  0.021840      0.00368   2.551783
# 98        0.028802  0.993361     0.994042  0.004829      0.00368   1.381541
# 99        0.028802  0.988301     0.994042  0.020629      0.00368   2.495722
#
#     median_lift
# 0      1.625026
# 1      1.607331
# 2      1.676618
# 3      1.438346
# 4      1.676618
# ..          ...
# 95    34.013573
# 96    18.223688
# 97     1.473369
# 98     1.165554
# 99     1.676618
#
# [100 rows x 16 columns]

# %%
show_coverage(result, MC_shots_df_cp)
# Out:
# 0.2
# 0.23442622950819672
# 0.23442622950819672
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.31311475409836065
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.44098360655737706
# 0.5295081967213114
# 0.5295081967213114
# 0.5295081967213114
# 0.5295081967213114
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5622950819672131
# 0.5655737704918032
# 0.5655737704918032
# Total Coverage: 0.5656

# %%
NC_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.NumericTarget('Pscores')

search_space = ps.create_selectors(NC_shots_df_cp, ignore=["Pscores", "Pconcedes", "offensive_value", "defensive_value", "vaep_value"])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(NC_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.StandardQFNumeric(1.0))
# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)

result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(30).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    # print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# Quality: 16.405627071857452
# Subgroup: shot_distance_from_goal<11.04
# ----------------------------------------
# Quality: 15.50608491897583
# Subgroup: start_x>=96.60
# ----------------------------------------
# Quality: 15.489017486572266
# Subgroup: shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 15.372848868370056
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# ----------------------------------------
# Quality: 14.712131202220917
# Subgroup: shot_distance_from_goal<11.04 AND start_x>=96.60
# ----------------------------------------
# Quality: 13.986570835113525
# Subgroup: shot_angle_from_goal>=0.61 AND start_y: [33.32:38.08[
# ----------------------------------------
# Quality: 13.679353475570679
# Subgroup: shot_angle_from_goal>=0.61 AND start_x>=96.60
# ----------------------------------------
# Quality: 13.679353475570679
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04 AND start_x>=96.60
# ----------------------------------------
# Quality: 13.573959320783615
# Subgroup: shot_distance_from_goal<11.04 AND start_y: [33.32:38.08[
# ----------------------------------------
# Quality: 13.573959320783615
# Subgroup: shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04 AND start_y: [33.32:38.08[
# ----------------------------------------
# Quality: 12.258760422468185
# Subgroup: start_y: [33.32:38.08[
# ----------------------------------------
# Quality: 11.32296547293663
# Subgroup: start_x>=96.60 AND start_y: [33.32:38.08[
# ----------------------------------------
# Quality: 11.32296547293663
# Subgroup: shot_distance_from_goal<11.04 AND start_x>=96.60 AND start_y: [33.32:38.08[
# ----------------------------------------
# Quality: 11.32296547293663
# Subgroup: shot_angle_from_goal>=0.61 AND start_x>=96.60 AND start_y: [33.32:38.08[
# ----------------------------------------
# Quality: 10.459806352853775
# Subgroup: player_rank>=0.01 AND shot_distance_from_goal<11.04 AND start_x>=96.60
# ----------------------------------------
# Quality: 10.075236439704895
# Subgroup: player_rank>=0.01 AND shot_distance_from_goal<11.04
# ----------------------------------------
# Quality: 10.057242959737778
# Subgroup: player_rank>=0.01 AND start_x>=96.60
# ----------------------------------------
# Quality: 9.46284607052803
# Subgroup: bodypart_name=='foot_right' AND shot_distance_from_goal<11.04
# ----------------------------------------
# Quality: 9.334203243255615
# Subgroup: bodypart_name=='foot_right' AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 9.031535178422928
# Subgroup: player_rank>=0.01 AND shot_angle_from_goal>=0.61 AND start_x>=96.60
# ----------------------------------------
# Quality: 8.754357635974884
# Subgroup: bodypart_name=='foot_right' AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# ----------------------------------------
# Quality: 8.646965503692627
# Subgroup: player_rank>=0.01 AND shot_angle_from_goal>=0.61 AND shot_distance_from_goal<11.04
# ----------------------------------------
# Quality: 8.251828461885452
# Subgroup: bodypart_name=='foot_right' AND start_x>=96.60
# ----------------------------------------
# Quality: 8.105630159378052
# Subgroup: player_rank>=0.01 AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 8.064331144094467
# Subgroup: bodypart_name=='foot_right' AND start_y: [33.32:38.08[
# ----------------------------------------
# Quality: 8.027688831090927
# Subgroup: bodypart_name=='foot_right' AND shot_distance_from_goal<11.04 AND start_x>=96.60
# ----------------------------------------
# Quality: 7.77498471736908
# Subgroup: play_std_distance_to_the_goal>=24.10 AND shot_angle_from_goal>=0.61
# ----------------------------------------
# Quality: 7.742676198482513
# Subgroup: play_distance_towards_goal>=61.95 AND start_y: [33.32:38.08[
# ----------------------------------------
# Quality: 7.731395065784454
# Subgroup: bodypart_name=='foot_right' AND play_distance_towards_goal>=61.95
# ----------------------------------------
# Quality: 7.60735422372818
# Subgroup: play_mean_distance_to_the_goal<41.87 AND start_x>=96.60
# ----------------------------------------
#       quality                                           subgroup  size_sg  \
# 0   16.405627                      shot_distance_from_goal<11.04       82
# 1   15.506085                                     start_x>=96.60       82
# 2   15.489017                         shot_angle_from_goal>=0.61       82
# 3   15.372849  shot_angle_from_goal>=0.61 AND shot_distance_f...       71
# 4   14.712131   shot_distance_from_goal<11.04 AND start_x>=96.60       67
# ..        ...                                                ...      ...
# 95   5.951542  play_std_distance_to_the_goal>=24.10 AND shot_...        9
# 96   5.893279  play_mean_distance_to_the_goal<41.87 AND shot_...       10
# 97   5.857538  play_std_distance_to_the_goal>=24.10 AND shot_...       10
# 98   5.822192  play_mean_distance_to_the_goal<41.87 AND shot_...       11
# 99   5.737012  shot_angle_from_goal>=0.61 AND shot_distance_f...       12
#
#     size_dataset   mean_sg  mean_dataset    std_sg  std_dataset  median_sg  \
# 0            410  0.310007      0.109939  0.431152     0.274172   0.034518
# 1            410  0.299037      0.109939  0.425354     0.274172   0.035051
# 2            410  0.298829      0.109939  0.425491     0.274172   0.034890
# 3            410  0.326458      0.109939  0.438107     0.274172   0.034755
# 4            410  0.329523      0.109939  0.439657     0.274172   0.034755
# ..           ...       ...           ...       ...          ...        ...
# 95           410  0.771221      0.109939  0.389843     0.274172   0.977037
# 96           410  0.699267      0.109939  0.431853     0.274172   0.979014
# 97           410  0.695692      0.109939  0.432935     0.274172   0.976806
# 98           410  0.639229      0.109939  0.453418     0.274172   0.978259
# 99           410  0.588023      0.109939  0.463666     0.274172   0.976806
#
#     median_dataset    max_sg  max_dataset    min_sg  min_dataset  mean_lift  \
# 0         0.024189  0.988178     0.988178  0.023678     0.003785   2.819821
# 1         0.024189  0.988178     0.988178  0.023678     0.003785   2.720038
# 2         0.024189  0.988178     0.988178  0.023678     0.003785   2.718144
# 3         0.024189  0.988178     0.988178  0.023678     0.003785   2.969453
# 4         0.024189  0.988178     0.988178  0.023678     0.003785   2.997333
# ..             ...       ...          ...       ...          ...        ...
# 95        0.024189  0.983566     0.988178  0.031373     0.003785   7.015013
# 96        0.024189  0.988178     0.988178  0.027732     0.003785   6.360517
# 97        0.024189  0.985690     0.988178  0.030586     0.003785   6.328006
# 98        0.024189  0.988178     0.988178  0.027732     0.003785   5.814414
# 99        0.024189  0.983566     0.988178  0.024891     0.003785   5.348647
#
#     median_lift
# 0      1.427021
# 1      1.449084
# 2      1.442411
# 3      1.436836
# 4      1.436836
# ..          ...
# 95    40.392460
# 96    40.474224
# 97    40.382912
# 98    40.442997
# 99    40.382912
#
# [100 rows x 16 columns]

# %%
show_coverage(result, NC_shots_df_cp)
# Out:
# 0.2
# 0.23658536585365852
# 0.2634146341463415
# 0.2634146341463415
# 0.2634146341463415
# 0.2634146341463415
# 0.2634146341463415
# 0.2634146341463415
# 0.2634146341463415
# 0.2634146341463415
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.3878048780487805
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.43414634146341463
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.47560975609756095
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.5902439024390244
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# 0.6560975609756098
# Total Coverage: 0.6561

# %%
WB_shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id"], inplace=True, axis=1)

# Definir o alvo (target) da descoberta de subgrupos
# Aqui, vamos assumir que queremos encontrar subgrupos de chutes bem-sucedidos (result_name == 'Goal')
target = ps.NumericTarget('Pscores')

search_space = ps.create_selectors(WB_shots_df_cp, ignore=["Pscores", "Pconcedes", "offensive_value", "defensive_value", "vaep_value"])

# Configurar a tarefa de descoberta de subgrupos
task = ps.SubgroupDiscoveryTask(WB_shots_df_cp, target, search_space, result_set_size=100, depth=3, qf=ps.StandardQFNumeric(1.0))
# Configurar e executar o Beam Search
search_algorithm = ps.BeamSearch(250)

result = search_algorithm.execute(task)

# Exibir os resultados
for sg_result in result.to_dataframe().head(30).itertuples(index=False):
    print(f"Quality: {sg_result.quality}")
    print(f"Subgroup: {sg_result.subgroup}")
    # print(f"Size of Subgroup: {sg_result.size_sg}")
    # print(f"Size of Dataset: {sg_result.size_dataset}")
    # print(f"Positives in Subgroup: {sg_result.positives_sg}")
    # print(f"Positives in Dataset: {sg_result.positives_dataset}")
    # print(f"Size of Complement: {sg_result.size_complement}")
    # print(f"Relative Size of Subgroup: {sg_result.relative_size_sg}")
    # print(f"Relative Size of Complement: {sg_result.relative_size_complement}")
    # print(f"Coverage of Subgroup: {sg_result.coverage_sg}")
    # print(f"Coverage of Complement: {sg_result.coverage_complement}")
    # print(f"Target Share in Subgroup: {sg_result.target_share_sg}")
    # print(f"Target Share in Complement: {sg_result.target_share_complement}")
    # print(f"Target Share in Dataset: {sg_result.target_share_dataset}")
    # print(f"Lift: {sg_result.lift}")
    print("-" * 40)

result.to_dataframe()
# Out:
# Quality: 10.211431980133057
# Subgroup: shot_distance_from_goal<10.52
# ----------------------------------------
# Quality: 10.207541853189468
# Subgroup: shot_distance_from_goal<10.52 AND start_x>=96.60
# ----------------------------------------
# Quality: 10.141963601112366
# Subgroup: shot_angle_from_goal>=0.63
# ----------------------------------------
# Quality: 9.412968255579472
# Subgroup: start_x>=96.60
# ----------------------------------------
# Quality: 9.115802884101868
# Subgroup: shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52
# ----------------------------------------
# Quality: 9.111915946006775
# Subgroup: shot_angle_from_goal>=0.63 AND start_x>=96.60
# ----------------------------------------
# Quality: 9.111915946006775
# Subgroup: shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52 AND start_x>=96.60
# ----------------------------------------
# Quality: 7.19771146774292
# Subgroup: shot_distance_from_goal<10.52 AND start_y: [32.64:38.08[
# ----------------------------------------
# Quality: 7.19771146774292
# Subgroup: shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52 AND start_y: [32.64:38.08[
# ----------------------------------------
# Quality: 6.822448223829269
# Subgroup: start_x>=96.60 AND start_y: [32.64:38.08[
# ----------------------------------------
# Quality: 6.822448223829269
# Subgroup: shot_distance_from_goal<10.52 AND start_x>=96.60 AND start_y: [32.64:38.08[
# ----------------------------------------
# Quality: 6.822448223829269
# Subgroup: shot_angle_from_goal>=0.63 AND start_x>=96.60 AND start_y: [32.64:38.08[
# ----------------------------------------
# Quality: 6.76505184173584
# Subgroup: shot_angle_from_goal>=0.63 AND start_y: [32.64:38.08[
# ----------------------------------------
# Quality: 5.753090791404247
# Subgroup: start_y: [32.64:38.08[
# ----------------------------------------
# Quality: 5.467287003993988
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.63
# ----------------------------------------
# Quality: 5.093257427215576
# Subgroup: play_distance_towards_goal: [39.90:56.70[ AND shot_distance_from_goal<10.52 AND start_x>=96.60
# ----------------------------------------
# Quality: 5.035157084465027
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.63 AND start_x>=96.60
# ----------------------------------------
# Quality: 4.916595369577408
# Subgroup: bodypart_name=='head/other' AND shot_distance_from_goal<10.52 AND start_x>=96.60
# ----------------------------------------
# Quality: 4.8782568871974945
# Subgroup: play_distance_towards_goal: [39.90:56.70[ AND start_x>=96.60
# ----------------------------------------
# Quality: 4.730637788772583
# Subgroup: num_dribbles: [0:2[ AND shot_angle_from_goal>=0.63 AND shot_distance_from_goal<10.52
# ----------------------------------------
# Quality: 4.720129042863846
# Subgroup: play_distance_towards_goal: [39.90:56.70[ AND shot_distance_from_goal<10.52
# ----------------------------------------
# Quality: 4.638569317758083
# Subgroup: bodypart_name=='head/other' AND start_x>=96.60
# ----------------------------------------
# Quality: 4.590429842472076
# Subgroup: num_dribbles: [0:2[ AND shot_distance_from_goal<10.52 AND start_x>=96.60
# ----------------------------------------
# Quality: 4.55965068936348
# Subgroup: bodypart_name=='head/other' AND shot_angle_from_goal>=0.63 AND start_x>=96.60
# ----------------------------------------
# Quality: 4.3880206644535065
# Subgroup: bodypart_name=='head/other' AND shot_distance_from_goal<10.52
# ----------------------------------------
# Quality: 4.3312183022499084
# Subgroup: ratio_distance: [0.06:0.14[ AND shot_angle_from_goal>=0.63
# ----------------------------------------
# Quality: 4.310832381248474
# Subgroup: num_events: [43:84[ AND play_speed_towards_goal: [0.07:0.16[ AND start_x>=96.60
# ----------------------------------------
# Quality: 4.2921963930130005
# Subgroup: bodypart_name=='head/other' AND play_distance_towards_goal: [39.90:56.70[ AND start_x>=96.60
# ----------------------------------------
# Quality: 4.285910546779633
# Subgroup: num_dribbles: [0:2[ AND shot_distance_from_goal<10.52
# ----------------------------------------
# Quality: 4.248000547289848
# Subgroup: bodypart_name=='head/other' AND shot_angle_from_goal>=0.63
# ----------------------------------------
#       quality                                           subgroup  size_sg  \
# 0   10.211432                      shot_distance_from_goal<10.52       70
# 1   10.207542   shot_distance_from_goal<10.52 AND start_x>=96.60       57
# 2   10.141964                         shot_angle_from_goal>=0.63       71
# 3    9.412968                                     start_x>=96.60       81
# 4    9.115803  shot_angle_from_goal>=0.63 AND shot_distance_f...       59
# ..        ...                                                ...      ...
# 95   3.737160  num_passes: [26:51[ AND play_speed_towards_goa...       25
# 96   3.735970  play_speed: [1.83:2.28[ AND shot_distance_from...       14
# 97   3.729418  play_duration: [415.49:762.68[ AND shot_angle_...       14
# 98   3.727112  play_duration: [415.49:762.68[ AND shot_distan...       14
# 99   3.708429  num_events: [43:84[ AND shot_angle_from_goal>=...       15
#
#     size_dataset   mean_sg  mean_dataset    std_sg  std_dataset  median_sg  \
# 0            354  0.248672      0.102794  0.397485     0.261647   0.033162
# 1            354  0.281874      0.102794  0.416593     0.261647   0.033802
# 2            354  0.245639      0.102794  0.395517     0.261647   0.033536
# 3            354  0.219004      0.102794  0.377130     0.261647   0.032830
# 4            354  0.257299      0.102794  0.402549     0.261647   0.033802
# ..           ...       ...           ...       ...          ...        ...
# 95           354  0.252281      0.102794  0.408153     0.261647   0.028045
# 96           354  0.369649      0.102794  0.454085     0.261647   0.036641
# 97           354  0.369181      0.102794  0.453762     0.261647   0.032905
# 98           354  0.369016      0.102794  0.453884     0.261647   0.031752
# 99           354  0.350023      0.102794  0.444120     0.261647   0.038490
#
#     median_dataset    max_sg  max_dataset    min_sg  min_dataset  mean_lift  \
# 0         0.025747  0.983416     0.983416  0.019465     0.004961   2.419124
# 1         0.025747  0.983416     0.983416  0.019465     0.004961   2.742119
# 2         0.025747  0.983416     0.983416  0.019465     0.004961   2.389617
# 3         0.025747  0.983416     0.983416  0.015445     0.004961   2.130507
# 4         0.025747  0.983416     0.983416  0.019465     0.004961   2.503054
# ..             ...       ...          ...       ...          ...        ...
# 95        0.025747  0.981349     0.983416  0.008776     0.004961   2.454231
# 96        0.025747  0.981349     0.983416  0.021926     0.004961   3.596013
# 97        0.025747  0.981349     0.983416  0.027506     0.004961   3.591461
# 98        0.025747  0.981349     0.983416  0.027506     0.004961   3.589859
# 99        0.025747  0.981349     0.983416  0.027506     0.004961   3.405085
#
#     median_lift
# 0      1.287981
# 1      1.312838
# 2      1.302480
# 3      1.275088
# 4      1.312838
# ..          ...
# 95     1.089232
# 96     1.423091
# 97     1.278003
# 98     1.233219
# 99     1.494900
#
# [100 rows x 16 columns]

# %%
show_coverage(result, WB_shots_df_cp)
# Out:
# 0.1977401129943503
# 0.1977401129943503
# 0.23163841807909605
# 0.2994350282485876
# 0.2994350282485876
# 0.2994350282485876
# 0.2994350282485876
# 0.2994350282485876
# 0.2994350282485876
# 0.2994350282485876
# 0.2994350282485876
# 0.2994350282485876
# 0.2994350282485876
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4011299435028249
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4067796610169492
# 0.4322033898305085
# 0.4322033898305085
# 0.4322033898305085
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4661016949152542
# 0.4915254237288136
# 0.4915254237288136
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# 0.5254237288135594
# Total Coverage: 0.5254
