# %%
import pandas as pd
import numpy as np

# %%
# constants

PATH: str = "../data/spadl_format/"
RANDOM_STATE: int = 42

# %%
df: pd.DataFrame = pd.read_csv(f"{PATH}England.csv", index_col=0)
df.head(10)
# Out:
#    game_id  period_id  time_seconds  team_id  player_id  start_x  start_y  \
# 0  2499719          1      2.758649     1609      25413    51.45    34.68
# 1  2499719          1      4.946850     1609     370224    32.55    14.96
# 2  2499719          1      6.542188     1609       3319    53.55    17.00
# 3  2499719          1      8.143395     1609     120339    36.75    19.72
# 4  2499719          1     10.302366     1609     167145    43.05     3.40
# 5  2499719          1     12.548934     1609       3319    75.60     8.16
# 6  2499719          1     13.961228     1631       8653    24.15    51.00
# 7  2499719          1     15.320341     1609     167145    70.35    13.60
# 8  2499719          1     15.320341     1609     167145    70.35    13.60
# 9  2499719          1     18.051875     1609      49876    61.95    26.52
#
#    end_x  end_y  original_event_id  bodypart_id  type_id  result_id  \
# 0  32.55  14.96        177959171.0            0        0          1
# 1  53.55  17.00        177959172.0            0        0          1
# 2  36.75  19.72        177959173.0            1        0          1
# 3  43.05   3.40        177959174.0            1        0          1
# 4  75.60   8.16        177959175.0            0        0          1
# 5  80.85  17.00        177959177.0            0        0          0
# 6  40.95  57.80        177959186.0            1        0          1
# 7  70.35  13.60        177959178.0            0       10          1
# 8  61.95  26.52        177959178.0            1        0          1
# 9  47.25  37.40        177959179.0            1        0          1
#
#    action_id     type_name result_name bodypart_name     player_name
# 0          0          pass     success          foot    A. Lacazette
# 1          1          pass     success          foot      R. Holding
# 2          2          pass     success          head         M. Özil
# 3          3          pass     success          head  Mohamed Elneny
# 4          4          pass     success          foot        Bellerín
# 5          5          pass        fail          foot         M. Özil
# 6          6          pass     success          head      H. Maguire
# 7          7  interception     success          foot        Bellerín
# 8          8          pass     success          head        Bellerín
# 9          9          pass     success          head        G. Xhaka

# %%
df = pd.DataFrame()

for country in ["England", "Spain", "Italy", "France", "Germany"]:
    c_df = pd.read_csv(f"{PATH}{country}.csv", index_col=0)
    df = pd.concat([df, c_df])

df.head()
# Out:
#    game_id  period_id  time_seconds  team_id  player_id  start_x  start_y  \
# 0  2499719          1      2.758649     1609      25413    51.45    34.68
# 1  2499719          1      4.946850     1609     370224    32.55    14.96
# 2  2499719          1      6.542188     1609       3319    53.55    17.00
# 3  2499719          1      8.143395     1609     120339    36.75    19.72
# 4  2499719          1     10.302366     1609     167145    43.05     3.40
#
#    end_x  end_y  original_event_id  bodypart_id  type_id  result_id  \
# 0  32.55  14.96        177959171.0            0        0          1
# 1  53.55  17.00        177959172.0            0        0          1
# 2  36.75  19.72        177959173.0            1        0          1
# 3  43.05   3.40        177959174.0            1        0          1
# 4  75.60   8.16        177959175.0            0        0          1
#
#    action_id type_name result_name bodypart_name     player_name
# 0          0      pass     success          foot    A. Lacazette
# 1          1      pass     success          foot      R. Holding
# 2          2      pass     success          head         M. Özil
# 3          3      pass     success          head  Mohamed Elneny
# 4          4      pass     success          foot        Bellerín

# %%
sorted_df = (
    df.groupby(["game_id", "period_id"])
    .apply(lambda x: x.sort_values(by="time_seconds"))
    .reset_index(drop=True)
)
# Out:
# /tmp/ipykernel_802767/2646718250.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sort_values(by="time_seconds"))

# %%
type_id_list = (
    sorted_df.groupby(["game_id", "period_id"])["type_id"].apply(list).reset_index(name="type_id_list")
)
type_id_list
# Out:
#       game_id  period_id                                       type_id_list
# 0     2499719          1  [0, 0, 0, 0, 0, 0, 0, 10, 0, 0, 0, 21, 0, 0, 0...
# 1     2499719          2  [0, 0, 10, 0, 0, 2, 0, 0, 0, 0, 0, 0, 10, 18, ...
# 2     2499720          1  [0, 0, 0, 0, 0, 0, 0, 0, 18, 2, 0, 10, 0, 9, 0...
# 3     2499720          2  [0, 0, 10, 0, 0, 0, 0, 0, 0, 0, 0, 0, 22, 18, ...
# 4     2499721          1  [0, 0, 10, 0, 0, 0, 0, 0, 2, 0, 0, 2, 0, 21, 0...
# ...       ...        ...                                                ...
# 3647  2576336          2  [0, 0, 0, 21, 0, 0, 0, 0, 0, 0, 0, 21, 0, 8, 4...
# 3648  2576337          1  [0, 0, 0, 8, 4, 18, 2, 0, 0, 0, 0, 11, 10, 5, ...
# 3649  2576337          2  [0, 0, 0, 0, 0, 21, 0, 4, 0, 21, 0, 0, 10, 21,...
# 3650  2576338          1  [0, 0, 0, 2, 0, 0, 1, 0, 0, 0, 8, 4, 0, 0, 2, ...
# 3651  2576338          2  [0, 0, 10, 0, 21, 0, 0, 0, 0, 21, 0, 0, 0, 0, ...
#
# [3652 rows x 3 columns]

# %%
# sequencias de jogadas de todos os jogos
# a ideia é filtrar depois para sequencias que precedem um gol
sequences = type_id_list["type_id_list"].to_list()
sequences = [sequences]

# %%
from sequence_mining.spam import SpamAlgo

algo = SpamAlgo(0.7)
algo.spam(sequences)
# print mined sequences

with open("saida1.txt", "w") as f:
    f.write(algo.frequent_items)
# Out:
# Min support 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 4
#       1 from sequence_mining.spam import SpamAlgo
#       3 algo = SpamAlgo(0.7)
# ----> 4 algo.spam(sequences)
#       5 # print mined sequences
#       7 with open("saida1.txt", "w") as f:
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:41, in SpamAlgo.spam(self, sequences)
#      39 self.min_sup = self.calculate_min_support()
#      40 self.remove_not_frequent_items()
# ---> 41 self.recursive_dfs()
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:81, in SpamAlgo.recursive_dfs(self)
#      79 for k in keys:
#      80     prefix = Prefix([k])
# ---> 81     self.dfs_pruning(prefix=prefix,
#      82                      prefix_bitmap=self.vertical_db[k],
#      83                      search_s_items=list(self.vertical_db.keys()),
#      84                      search_i_items=list(self.vertical_db.keys()),
#      85                      has_to_be_greater_than_for_i_step=k,
#      86                      m=2)
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:98, in SpamAlgo.dfs_pruning(self, prefix, prefix_bitmap, search_s_items, search_i_items, has_to_be_greater_than_for_i_step, m)
#      96     self.frequent_items.append(prefix_s_step.itemsets)
#      97     if self.maximum_patter_length > m:
# ---> 98         self.dfs_pruning(prefix_s_step, new_bitmap, s_temp, s_temp, item, m + 1)
#     100 i_temp, i_temp_bitmaps = self.perform_i_step(prefix,
#     101                                              prefix_bitmap,
#     102                                              search_i_items,
#     103                                              has_to_be_greater_than_for_i_step)
#     104 for idx, item in enumerate(i_temp):
#     105     # create the new prefix
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:98, in SpamAlgo.dfs_pruning(self, prefix, prefix_bitmap, search_s_items, search_i_items, has_to_be_greater_than_for_i_step, m)
#      96     self.frequent_items.append(prefix_s_step.itemsets)
#      97     if self.maximum_patter_length > m:
# ---> 98         self.dfs_pruning(prefix_s_step, new_bitmap, s_temp, s_temp, item, m + 1)
#     100 i_temp, i_temp_bitmaps = self.perform_i_step(prefix,
#     101                                              prefix_bitmap,
#     102                                              search_i_items,
#     103                                              has_to_be_greater_than_for_i_step)
#     104 for idx, item in enumerate(i_temp):
#     105     # create the new prefix
#
#     [... skipping similar frames: SpamAlgo.dfs_pruning at line 98 (2369 times)]
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:98, in SpamAlgo.dfs_pruning(self, prefix, prefix_bitmap, search_s_items, search_i_items, has_to_be_greater_than_for_i_step, m)
#      96     self.frequent_items.append(prefix_s_step.itemsets)
#      97     if self.maximum_patter_length > m:
# ---> 98         self.dfs_pruning(prefix_s_step, new_bitmap, s_temp, s_temp, item, m + 1)
#     100 i_temp, i_temp_bitmaps = self.perform_i_step(prefix,
#     101                                              prefix_bitmap,
#     102                                              search_i_items,
#     103                                              has_to_be_greater_than_for_i_step)
#     104 for idx, item in enumerate(i_temp):
#     105     # create the new prefix
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:90, in SpamAlgo.dfs_pruning(self, prefix, prefix_bitmap, search_s_items, search_i_items, has_to_be_greater_than_for_i_step, m)
#      88 def dfs_pruning(self, prefix: Prefix, prefix_bitmap: Bitmap, search_s_items: List[int],
#      89                 search_i_items: List[int], has_to_be_greater_than_for_i_step: int, m: int):
# ---> 90     s_temp, s_temp_bitmaps = self.perform_s_step(prefix, prefix_bitmap, search_s_items)
#      91     for idx, item in enumerate(s_temp):
#      92         prefix_s_step = prefix.clone_sequence()
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:118, in SpamAlgo.perform_s_step(self, prefix, prefix_bitmap, frequent_items)
#     115 s_temp_bitmaps: List[Bitmap] = []
#     116 for i, k in enumerate(frequent_items):
#     117     # print(f'searching combination {prefix.itemsets} + {k}')
# --> 118     new_bitmap = prefix_bitmap.create_new_bitmap_s_step(bitmap=self.vertical_db[k],
#     119                                                         sequences_size=self.sequences_size,
#     120                                                         last_bit_index=self.last_bit_index)
#     121     # print(f'new bitmap support {new_bitmap.support}')
#     122     if new_bitmap.support >= self.min_sup:
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/bitmap.py:62, in Bitmap.create_new_bitmap_s_step(self, bitmap, sequences_size, last_bit_index)
#      60 match = False
#      61 for next_bit in sequence_bits:
# ---> 62     new_bitmap.set_bit(next_bit)
#      63     match = True
#      65 if match:
#
# KeyboardInterrupt:

# %%
grouped = sorted_df.groupby(["game_id", "period_id"])

result_list = []

# Iterate over each group
for (game_id, period_id), group in grouped:
    # Sort the group by time_seconds
    group = group.sort_values(by="time_seconds")

    # Find rows where type_name is 'shot' and result_name is 'success'
    success_shots = group[
        (group["type_name"] == "shot") & (group["result_name"] == "success")
    ]

    for idx, success_row in success_shots.iterrows():
        # Find rows of the same team before the successful shot
        team_id = success_row["team_id"]
        time_seconds = success_row["time_seconds"]

        prior_events = group[group["time_seconds"] <= time_seconds][::-1]

        type_ids = []
        for _, event in prior_events.iterrows():
            if event["team_id"] != team_id:
                break
            type_ids.append(
                event["type_id"]
            )  # Filter rows of the same team before the successful shot
        prior_events = group[
            (group["team_id"] == team_id) & (group["time_seconds"] < time_seconds)
        ]

        # Extract the type_ids
        type_ids = prior_events["type_id"].tolist()
        result_list.append(type_ids)

# %%
algo = SpamAlgo(0.7)
algo.spam([result_list])
# print mined sequences

with open("saida2.txt", "w") as f:
    f.write(algo.frequent_items)
# Out:
# Min support 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 algo = SpamAlgo(0.7)
# ----> 2 algo.spam([result_list])
#       3 # print mined sequences
#       5 with open("saida2.txt", "w") as f:
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:41, in SpamAlgo.spam(self, sequences)
#      39 self.min_sup = self.calculate_min_support()
#      40 self.remove_not_frequent_items()
# ---> 41 self.recursive_dfs()
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:81, in SpamAlgo.recursive_dfs(self)
#      79 for k in keys:
#      80     prefix = Prefix([k])
# ---> 81     self.dfs_pruning(prefix=prefix,
#      82                      prefix_bitmap=self.vertical_db[k],
#      83                      search_s_items=list(self.vertical_db.keys()),
#      84                      search_i_items=list(self.vertical_db.keys()),
#      85                      has_to_be_greater_than_for_i_step=k,
#      86                      m=2)
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:98, in SpamAlgo.dfs_pruning(self, prefix, prefix_bitmap, search_s_items, search_i_items, has_to_be_greater_than_for_i_step, m)
#      96     self.frequent_items.append(prefix_s_step.itemsets)
#      97     if self.maximum_patter_length > m:
# ---> 98         self.dfs_pruning(prefix_s_step, new_bitmap, s_temp, s_temp, item, m + 1)
#     100 i_temp, i_temp_bitmaps = self.perform_i_step(prefix,
#     101                                              prefix_bitmap,
#     102                                              search_i_items,
#     103                                              has_to_be_greater_than_for_i_step)
#     104 for idx, item in enumerate(i_temp):
#     105     # create the new prefix
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:98, in SpamAlgo.dfs_pruning(self, prefix, prefix_bitmap, search_s_items, search_i_items, has_to_be_greater_than_for_i_step, m)
#      96     self.frequent_items.append(prefix_s_step.itemsets)
#      97     if self.maximum_patter_length > m:
# ---> 98         self.dfs_pruning(prefix_s_step, new_bitmap, s_temp, s_temp, item, m + 1)
#     100 i_temp, i_temp_bitmaps = self.perform_i_step(prefix,
#     101                                              prefix_bitmap,
#     102                                              search_i_items,
#     103                                              has_to_be_greater_than_for_i_step)
#     104 for idx, item in enumerate(i_temp):
#     105     # create the new prefix
#
#     [... skipping similar frames: SpamAlgo.dfs_pruning at line 98 (1161 times)]
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:98, in SpamAlgo.dfs_pruning(self, prefix, prefix_bitmap, search_s_items, search_i_items, has_to_be_greater_than_for_i_step, m)
#      96     self.frequent_items.append(prefix_s_step.itemsets)
#      97     if self.maximum_patter_length > m:
# ---> 98         self.dfs_pruning(prefix_s_step, new_bitmap, s_temp, s_temp, item, m + 1)
#     100 i_temp, i_temp_bitmaps = self.perform_i_step(prefix,
#     101                                              prefix_bitmap,
#     102                                              search_i_items,
#     103                                              has_to_be_greater_than_for_i_step)
#     104 for idx, item in enumerate(i_temp):
#     105     # create the new prefix
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:90, in SpamAlgo.dfs_pruning(self, prefix, prefix_bitmap, search_s_items, search_i_items, has_to_be_greater_than_for_i_step, m)
#      88 def dfs_pruning(self, prefix: Prefix, prefix_bitmap: Bitmap, search_s_items: List[int],
#      89                 search_i_items: List[int], has_to_be_greater_than_for_i_step: int, m: int):
# ---> 90     s_temp, s_temp_bitmaps = self.perform_s_step(prefix, prefix_bitmap, search_s_items)
#      91     for idx, item in enumerate(s_temp):
#      92         prefix_s_step = prefix.clone_sequence()
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/spam.py:118, in SpamAlgo.perform_s_step(self, prefix, prefix_bitmap, frequent_items)
#     115 s_temp_bitmaps: List[Bitmap] = []
#     116 for i, k in enumerate(frequent_items):
#     117     # print(f'searching combination {prefix.itemsets} + {k}')
# --> 118     new_bitmap = prefix_bitmap.create_new_bitmap_s_step(bitmap=self.vertical_db[k],
#     119                                                         sequences_size=self.sequences_size,
#     120                                                         last_bit_index=self.last_bit_index)
#     121     # print(f'new bitmap support {new_bitmap.support}')
#     122     if new_bitmap.support >= self.min_sup:
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/bitmap.py:53, in Bitmap.create_new_bitmap_s_step(self, bitmap, sequences_size, last_bit_index)
#      51 set_bits_candidate = bitmap.bitmap.search(1)
#      52 # must be only on first bits of every sequence
# ---> 53 first_bits = self.get_first_set_bits_of_every_sequence(set_bits, sequences_size, last_bit_index)
#      54 for set_bit in first_bits:
#      55     idx = bisect(set_bits_candidate, set_bit) - 1
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/bitmap.py:103, in Bitmap.get_first_set_bits_of_every_sequence(self, set_bits, sequences_size, last_bit_index)
#     101 first_bits = []
#     102 for idx, bit in enumerate(set_bits):
# --> 103     bit_sid = self.bit_to_sid(bit, sequences_size)
#     104     if bit_sid != sid:
#     105         first_bits.append(bit)
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/sequence_mining/bitmap.py:87, in Bitmap.bit_to_sid(self, bit, sequences_size)
#      83     new_bitmap.bitmap = new_bitmap.bitmap & bitmap.bitmap
#      85     return new_bitmap
# ---> 87 def bit_to_sid(self, bit, sequences_size):
#      88     # Bisect starts from index 1
#      89     index = bisect(sequences_size, bit) - 1
#      90     if index < 0:
#
# KeyboardInterrupt:
