# %%
import pandas as pd
import numpy as np

# %%
# constants

PATH: str = "../data/spadl_format/"
RANDOM_STATE: int = 42

# %%
df: pd.DataFrame = pd.read_csv(f"{PATH}England.csv", index_col=0)
df.head(10)
# Out:
#    game_id  period_id  time_seconds  team_id  player_id  start_x  start_y  \
# 0  2499719          1      2.758649     1609      25413    51.45    34.68
# 1  2499719          1      4.946850     1609     370224    32.55    14.96
# 2  2499719          1      6.542188     1609       3319    53.55    17.00
# 3  2499719          1      8.143395     1609     120339    36.75    19.72
# 4  2499719          1     10.302366     1609     167145    43.05     3.40
# 5  2499719          1     12.548934     1609       3319    75.60     8.16
# 6  2499719          1     13.961228     1631       8653    24.15    51.00
# 7  2499719          1     15.320341     1609     167145    70.35    13.60
# 8  2499719          1     15.320341     1609     167145    70.35    13.60
# 9  2499719          1     18.051875     1609      49876    61.95    26.52
#
#    end_x  end_y  original_event_id  bodypart_id  type_id  result_id  \
# 0  32.55  14.96        177959171.0            0        0          1
# 1  53.55  17.00        177959172.0            0        0          1
# 2  36.75  19.72        177959173.0            1        0          1
# 3  43.05   3.40        177959174.0            1        0          1
# 4  75.60   8.16        177959175.0            0        0          1
# 5  80.85  17.00        177959177.0            0        0          0
# 6  40.95  57.80        177959186.0            1        0          1
# 7  70.35  13.60        177959178.0            0       10          1
# 8  61.95  26.52        177959178.0            1        0          1
# 9  47.25  37.40        177959179.0            1        0          1
#
#    action_id     type_name result_name bodypart_name     player_name
# 0          0          pass     success          foot    A. Lacazette
# 1          1          pass     success          foot      R. Holding
# 2          2          pass     success          head         M. Özil
# 3          3          pass     success          head  Mohamed Elneny
# 4          4          pass     success          foot        Bellerín
# 5          5          pass        fail          foot         M. Özil
# 6          6          pass     success          head      H. Maguire
# 7          7  interception     success          foot        Bellerín
# 8          8          pass     success          head        Bellerín
# 9          9          pass     success          head        G. Xhaka

# %%
df = pd.DataFrame()

for country in ["England", "Spain", "Italy", "France", "Germany"]:
    c_df = pd.read_csv(f"{PATH}{country}.csv", index_col=0)
    df = pd.concat([df, c_df])

df.head()
# Out:
#    game_id  period_id  time_seconds  team_id  player_id  start_x  start_y  \
# 0  2499719          1      2.758649     1609      25413    51.45    34.68
# 1  2499719          1      4.946850     1609     370224    32.55    14.96
# 2  2499719          1      6.542188     1609       3319    53.55    17.00
# 3  2499719          1      8.143395     1609     120339    36.75    19.72
# 4  2499719          1     10.302366     1609     167145    43.05     3.40
#
#    end_x  end_y  original_event_id  bodypart_id  type_id  result_id  \
# 0  32.55  14.96        177959171.0            0        0          1
# 1  53.55  17.00        177959172.0            0        0          1
# 2  36.75  19.72        177959173.0            1        0          1
# 3  43.05   3.40        177959174.0            1        0          1
# 4  75.60   8.16        177959175.0            0        0          1
#
#    action_id type_name result_name bodypart_name     player_name
# 0          0      pass     success          foot    A. Lacazette
# 1          1      pass     success          foot      R. Holding
# 2          2      pass     success          head         M. Özil
# 3          3      pass     success          head  Mohamed Elneny
# 4          4      pass     success          foot        Bellerín

# %%
sorted_df = (
    df.groupby(["game_id", "period_id"])
    .apply(lambda x: x.sort_values(by="time_seconds"))
    .reset_index(drop=True)
)
# Out:
# /tmp/ipykernel_113084/2646718250.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sort_values(by="time_seconds"))

# %%
type_id_list = (
    sorted_df.groupby(["game_id", "period_id"])["type_id"].apply(list).reset_index(name="type_id_list")
)
type_id_list
# Out:
#       game_id  period_id                                       type_id_list
# 0     2499719          1  [0, 0, 0, 0, 0, 0, 0, 10, 0, 0, 0, 21, 0, 0, 0...
# 1     2499719          2  [0, 0, 10, 0, 0, 2, 0, 0, 0, 0, 0, 0, 10, 18, ...
# 2     2499720          1  [0, 0, 0, 0, 0, 0, 0, 0, 18, 2, 0, 10, 0, 9, 0...
# 3     2499720          2  [0, 0, 10, 0, 0, 0, 0, 0, 0, 0, 0, 0, 22, 18, ...
# 4     2499721          1  [0, 0, 10, 0, 0, 0, 0, 0, 2, 0, 0, 2, 0, 21, 0...
# ...       ...        ...                                                ...
# 3647  2576336          2  [0, 0, 0, 21, 0, 0, 0, 0, 0, 0, 0, 21, 0, 8, 4...
# 3648  2576337          1  [0, 0, 0, 8, 4, 18, 2, 0, 0, 0, 0, 11, 10, 5, ...
# 3649  2576337          2  [0, 0, 0, 0, 0, 21, 0, 4, 0, 21, 0, 0, 10, 21,...
# 3650  2576338          1  [0, 0, 0, 2, 0, 0, 1, 0, 0, 0, 8, 4, 0, 0, 2, ...
# 3651  2576338          2  [0, 0, 10, 0, 21, 0, 0, 0, 0, 21, 0, 0, 0, 0, ...
#
# [3652 rows x 3 columns]

# %%
# sequencias de jogadas de todos os jogos
# a ideia é filtrar depois para sequencias que precedem um gol
sequences = type_id_list["type_id_list"].to_list()
len(sequences)
# Out:
# 3652

# %%
from prefixspan import PrefixSpan

ps = PrefixSpan(sequences)

with open("saida1.txt", "w") as f:
    print(ps.topk(5))
# Out:
# [(3652, [0]), (3652, [0, 0]), (3652, [0, 0, 0]), (3652, [0, 0, 0, 0]), (3652, [0, 0, 0, 0, 0])]

# %%
grouped = sorted_df.groupby(["game_id", "period_id"])

result_list = []

# Iterate over each group
for (game_id, period_id), group in grouped:
    # Sort the group by time_seconds
    group = group.sort_values(by="time_seconds")

    # Find rows where type_name is 'shot' and result_name is 'success'
    success_shots = group[
        (group["type_name"] == "shot") & (group["end_y"] <= 39.5) & (group["end_y"] >= 29.5)
    ]

    for idx, success_row in success_shots.iterrows():
        # Find rows of the same team before the successful shot
        team_id = success_row["team_id"]
        time_seconds = success_row["time_seconds"]

        prior_events = group[group["time_seconds"] <= time_seconds][::-1]

        type_ids = []
        for _, event in prior_events.iterrows():
            if event["team_id"] != team_id:
                break
            type_ids.append(
                event["type_id"]
            )  # Filter rows of the same team before the successful shot
        prior_events = group[
            (group["team_id"] == team_id) & (group["time_seconds"] < time_seconds)
        ]

        # Extract the type_ids
        type_ids = prior_events["type_id"].tolist()
        result_list.append(type_ids)

# %%
sorted_df = sorted_df[sorted_df["team_id"] == 1609] # arsenal id
grouped = sorted_df.groupby(["game_id", "period_id"])

result_list = []

# Iterate over each group
for (game_id, period_id), group in grouped:
    # Sort the group by time_seconds
    group = group.sort_values(by="time_seconds")

    # Find rows where type_name is 'shot' and result_name is 'success'
    success_shots = group[
        (group["type_name"] == "shot") & (group["end_y"] <= 39.5) & (group["end_y"] >= 29.5)
    ]

    for idx, success_row in success_shots.iterrows():
        # Find rows of the same team before the successful shot
        team_id = success_row["team_id"]
        time_seconds = success_row["time_seconds"]

        prior_events = group[group["time_seconds"] <= time_seconds][::-1]

        type_ids = []
        for _, event in prior_events.iterrows():
            if event["team_id"] != team_id:
                break
            type_ids.append(
                event["player_name"]
            )  # Filter rows of the same team before the successful shot
        prior_events = group[
            (group["team_id"] == team_id) & (group["time_seconds"] < time_seconds)
        ]

        # Extract the type_ids
        type_ids = prior_events["player_name"].tolist()
        result_list.append(type_ids)

# %%
result_list[:5]
# Out:
# [['A. Lacazette',
#   'R. Holding',
#   'M. Özil',
#   'Mohamed Elneny',
#   'Bellerín',
#   'M. Özil',
#   'Bellerín',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'Nacho Monreal',
#   'R. Holding',
#   'Nacho Monreal',
#   'P. Čech',
#   'D. Welbeck',
#   'D. Welbeck',
#   nan,
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'Bellerín',
#   'Mohamed Elneny'],
#  ['A. Lacazette',
#   'R. Holding',
#   'M. Özil',
#   'Mohamed Elneny',
#   'Bellerín',
#   'M. Özil',
#   'Bellerín',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'Nacho Monreal',
#   'R. Holding',
#   'Nacho Monreal',
#   'P. Čech',
#   'D. Welbeck',
#   'D. Welbeck',
#   nan,
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'Bellerín',
#   'Mohamed Elneny',
#   'A. Lacazette',
#   'M. Özil',
#   'R. Holding',
#   'P. Čech',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'Bellerín',
#   'R. Holding',
#   'P. Čech',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'R. Holding',
#   'A. Lacazette',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'M. Özil',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'R. Holding',
#   'R. Holding',
#   'R. Holding',
#   'P. Čech',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'R. Holding',
#   'G. Xhaka',
#   'D. Welbeck',
#   'G. Xhaka',
#   'Bellerín',
#   'M. Özil',
#   'Mohamed Elneny',
#   'M. Özil',
#   'Bellerín',
#   'M. Özil',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'R. Holding',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'M. Özil',
#   'R. Holding',
#   'S. Kolašinac',
#   'R. Holding',
#   'Nacho Monreal',
#   'Nacho Monreal',
#   'D. Welbeck',
#   'A. Lacazette',
#   'Bellerín',
#   'Bellerín',
#   'Bellerín',
#   'M. Özil',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'Mohamed Elneny',
#   'G. Xhaka'],
#  ['A. Lacazette',
#   'R. Holding',
#   'M. Özil',
#   'Mohamed Elneny',
#   'Bellerín',
#   'M. Özil',
#   'Bellerín',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'Nacho Monreal',
#   'R. Holding',
#   'Nacho Monreal',
#   'P. Čech',
#   'D. Welbeck',
#   'D. Welbeck',
#   nan,
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'Bellerín',
#   'Mohamed Elneny',
#   'A. Lacazette',
#   'M. Özil',
#   'R. Holding',
#   'P. Čech',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'Bellerín',
#   'R. Holding',
#   'P. Čech',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'R. Holding',
#   'A. Lacazette',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'M. Özil',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'R. Holding',
#   'R. Holding',
#   'R. Holding',
#   'P. Čech',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'R. Holding',
#   'G. Xhaka',
#   'D. Welbeck',
#   'G. Xhaka',
#   'Bellerín',
#   'M. Özil',
#   'Mohamed Elneny',
#   'M. Özil',
#   'Bellerín',
#   'M. Özil',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'R. Holding',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'M. Özil',
#   'R. Holding',
#   'S. Kolašinac',
#   'R. Holding',
#   'Nacho Monreal',
#   'Nacho Monreal',
#   'D. Welbeck',
#   'A. Lacazette',
#   'Bellerín',
#   'Bellerín',
#   'Bellerín',
#   'M. Özil',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'R. Holding',
#   'Mohamed Elneny',
#   'Bellerín',
#   'P. Čech',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'R. Holding',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'Bellerín',
#   nan,
#   'Mohamed Elneny',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'R. Holding',
#   'R. Holding',
#   'M. Özil',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'Bellerín',
#   'Mohamed Elneny',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'G. Xhaka',
#   'A. Lacazette',
#   'G. Xhaka',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'M. Özil',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'M. Özil',
#   'A. Oxlade-Chamberlain',
#   'M. Özil',
#   'S. Kolašinac',
#   'M. Özil',
#   'G. Xhaka',
#   'R. Holding',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'M. Özil',
#   'A. Lacazette',
#   'S. Kolašinac',
#   'M. Özil',
#   'Nacho Monreal',
#   'R. Holding',
#   'Bellerín',
#   'Mohamed Elneny',
#   'Bellerín',
#   'G. Xhaka',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'M. Özil',
#   'S. Kolašinac',
#   'M. Özil',
#   'D. Welbeck',
#   'M. Özil',
#   'D. Welbeck',
#   'Bellerín',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'R. Holding',
#   'Mohamed Elneny',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'M. Özil',
#   'S. Kolašinac',
#   'M. Özil',
#   'D. Welbeck',
#   'S. Kolašinac',
#   'R. Holding',
#   'Mohamed Elneny',
#   'R. Holding',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'M. Özil',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'R. Holding',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'D. Welbeck',
#   'D. Welbeck',
#   'A. Oxlade-Chamberlain',
#   nan,
#   'S. Kolašinac',
#   'G. Xhaka',
#   'M. Özil',
#   'Bellerín',
#   'M. Özil',
#   'A. Lacazette',
#   'G. Xhaka',
#   'A. Lacazette',
#   'R. Holding',
#   'Bellerín',
#   'R. Holding',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'R. Holding',
#   'Bellerín',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'D. Welbeck',
#   'M. Özil',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   nan,
#   'D. Welbeck',
#   'M. Özil',
#   'D. Welbeck',
#   'D. Welbeck',
#   'R. Holding',
#   'Mohamed Elneny',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'Bellerín',
#   'M. Özil',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'G. Xhaka'],
#  ['A. Lacazette',
#   'R. Holding',
#   'M. Özil',
#   'Mohamed Elneny',
#   'Bellerín',
#   'M. Özil',
#   'Bellerín',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'Nacho Monreal',
#   'R. Holding',
#   'Nacho Monreal',
#   'P. Čech',
#   'D. Welbeck',
#   'D. Welbeck',
#   nan,
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'Bellerín',
#   'Mohamed Elneny',
#   'A. Lacazette',
#   'M. Özil',
#   'R. Holding',
#   'P. Čech',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'Bellerín',
#   'R. Holding',
#   'P. Čech',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'R. Holding',
#   'A. Lacazette',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'M. Özil',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'R. Holding',
#   'R. Holding',
#   'R. Holding',
#   'P. Čech',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'R. Holding',
#   'G. Xhaka',
#   'D. Welbeck',
#   'G. Xhaka',
#   'Bellerín',
#   'M. Özil',
#   'Mohamed Elneny',
#   'M. Özil',
#   'Bellerín',
#   'M. Özil',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'R. Holding',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'M. Özil',
#   'R. Holding',
#   'S. Kolašinac',
#   'R. Holding',
#   'Nacho Monreal',
#   'Nacho Monreal',
#   'D. Welbeck',
#   'A. Lacazette',
#   'Bellerín',
#   'Bellerín',
#   'Bellerín',
#   'M. Özil',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'R. Holding',
#   'Mohamed Elneny',
#   'Bellerín',
#   'P. Čech',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'R. Holding',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'Bellerín',
#   nan,
#   'Mohamed Elneny',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'R. Holding',
#   'R. Holding',
#   'M. Özil',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'Bellerín',
#   'Mohamed Elneny',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'G. Xhaka',
#   'A. Lacazette',
#   'G. Xhaka',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'M. Özil',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'M. Özil',
#   'A. Oxlade-Chamberlain',
#   'M. Özil',
#   'S. Kolašinac',
#   'M. Özil',
#   'G. Xhaka',
#   'R. Holding',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'M. Özil',
#   'A. Lacazette',
#   'S. Kolašinac',
#   'M. Özil',
#   'Nacho Monreal',
#   'R. Holding',
#   'Bellerín',
#   'Mohamed Elneny',
#   'Bellerín',
#   'G. Xhaka',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'M. Özil',
#   'S. Kolašinac',
#   'M. Özil',
#   'D. Welbeck',
#   'M. Özil',
#   'D. Welbeck',
#   'Bellerín',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'R. Holding',
#   'Mohamed Elneny',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'M. Özil',
#   'S. Kolašinac',
#   'M. Özil',
#   'D. Welbeck',
#   'S. Kolašinac',
#   'R. Holding',
#   'Mohamed Elneny',
#   'R. Holding',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'M. Özil',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'R. Holding',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'D. Welbeck',
#   'D. Welbeck',
#   'A. Oxlade-Chamberlain',
#   nan,
#   'S. Kolašinac',
#   'G. Xhaka',
#   'M. Özil',
#   'Bellerín',
#   'M. Özil',
#   'A. Lacazette',
#   'G. Xhaka',
#   'A. Lacazette',
#   'R. Holding',
#   'Bellerín',
#   'R. Holding',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'R. Holding',
#   'Bellerín',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'D. Welbeck',
#   'M. Özil',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   nan,
#   'D. Welbeck',
#   'M. Özil',
#   'D. Welbeck',
#   'D. Welbeck',
#   'R. Holding',
#   'Mohamed Elneny',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'Bellerín',
#   'M. Özil',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'M. Özil',
#   'R. Holding',
#   'R. Holding',
#   'Bellerín',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'A. Lacazette',
#   'G. Xhaka',
#   'M. Özil',
#   'M. Özil',
#   'R. Holding',
#   'Mohamed Elneny',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'A. Lacazette',
#   'Bellerín',
#   'G. Xhaka',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'M. Özil',
#   'R. Holding',
#   'R. Holding',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'G. Xhaka',
#   'M. Özil',
#   'M. Özil',
#   'G. Xhaka',
#   'R. Holding',
#   'R. Holding',
#   'P. Čech',
#   'R. Holding',
#   'P. Čech',
#   'R. Holding',
#   'D. Welbeck',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'M. Özil',
#   'Mohamed Elneny',
#   'Bellerín',
#   'A. Lacazette',
#   'Bellerín',
#   'Mohamed Elneny',
#   'Mohamed Elneny',
#   'M. Özil',
#   nan,
#   'R. Holding',
#   'P. Čech',
#   'R. Holding',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'M. Özil',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   nan,
#   'Bellerín',
#   'R. Holding',
#   'P. Čech',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'Mohamed Elneny',
#   'P. Čech',
#   'P. Čech',
#   'R. Holding',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'Bellerín',
#   'Bellerín',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'D. Welbeck',
#   'A. Oxlade-Chamberlain',
#   'A. Lacazette',
#   'Mohamed Elneny',
#   'Bellerín',
#   'Mohamed Elneny',
#   'Bellerín',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'M. Özil',
#   'G. Xhaka',
#   'Bellerín',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'A. Oxlade-Chamberlain',
#   'R. Holding',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'Bellerín',
#   'R. Holding',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'S. Kolašinac',
#   'P. Čech',
#   'R. Holding',
#   'Nacho Monreal',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'R. Holding',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'D. Welbeck',
#   'G. Xhaka',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'M. Özil',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'M. Özil'],
#  ['A. Lacazette',
#   'R. Holding',
#   'M. Özil',
#   'Mohamed Elneny',
#   'Bellerín',
#   'M. Özil',
#   'Bellerín',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'Nacho Monreal',
#   'R. Holding',
#   'Nacho Monreal',
#   'P. Čech',
#   'D. Welbeck',
#   'D. Welbeck',
#   nan,
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'Bellerín',
#   'Mohamed Elneny',
#   'A. Lacazette',
#   'M. Özil',
#   'R. Holding',
#   'P. Čech',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'Bellerín',
#   'R. Holding',
#   'P. Čech',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'R. Holding',
#   'A. Lacazette',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'M. Özil',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'R. Holding',
#   'R. Holding',
#   'R. Holding',
#   'P. Čech',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'R. Holding',
#   'G. Xhaka',
#   'D. Welbeck',
#   'G. Xhaka',
#   'Bellerín',
#   'M. Özil',
#   'Mohamed Elneny',
#   'M. Özil',
#   'Bellerín',
#   'M. Özil',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'R. Holding',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'Bellerín',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'M. Özil',
#   'R. Holding',
#   'S. Kolašinac',
#   'R. Holding',
#   'Nacho Monreal',
#   'Nacho Monreal',
#   'D. Welbeck',
#   'A. Lacazette',
#   'Bellerín',
#   'Bellerín',
#   'Bellerín',
#   'M. Özil',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'R. Holding',
#   'Mohamed Elneny',
#   'Bellerín',
#   'P. Čech',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'R. Holding',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'Bellerín',
#   nan,
#   'Mohamed Elneny',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'R. Holding',
#   'R. Holding',
#   'M. Özil',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'Bellerín',
#   'Mohamed Elneny',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'G. Xhaka',
#   'A. Lacazette',
#   'G. Xhaka',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'M. Özil',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'M. Özil',
#   'A. Oxlade-Chamberlain',
#   'M. Özil',
#   'S. Kolašinac',
#   'M. Özil',
#   'G. Xhaka',
#   'R. Holding',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'M. Özil',
#   'A. Lacazette',
#   'S. Kolašinac',
#   'M. Özil',
#   'Nacho Monreal',
#   'R. Holding',
#   'Bellerín',
#   'Mohamed Elneny',
#   'Bellerín',
#   'G. Xhaka',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'M. Özil',
#   'S. Kolašinac',
#   'M. Özil',
#   'D. Welbeck',
#   'M. Özil',
#   'D. Welbeck',
#   'Bellerín',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'R. Holding',
#   'Mohamed Elneny',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'M. Özil',
#   'S. Kolašinac',
#   'M. Özil',
#   'D. Welbeck',
#   'S. Kolašinac',
#   'R. Holding',
#   'Mohamed Elneny',
#   'R. Holding',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'M. Özil',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'R. Holding',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'D. Welbeck',
#   'D. Welbeck',
#   'A. Oxlade-Chamberlain',
#   nan,
#   'S. Kolašinac',
#   'G. Xhaka',
#   'M. Özil',
#   'Bellerín',
#   'M. Özil',
#   'A. Lacazette',
#   'G. Xhaka',
#   'A. Lacazette',
#   'R. Holding',
#   'Bellerín',
#   'R. Holding',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'S. Kolašinac',
#   'Nacho Monreal',
#   'R. Holding',
#   'Bellerín',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'D. Welbeck',
#   'M. Özil',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   nan,
#   'D. Welbeck',
#   'M. Özil',
#   'D. Welbeck',
#   'D. Welbeck',
#   'R. Holding',
#   'Mohamed Elneny',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'Bellerín',
#   'M. Özil',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'M. Özil',
#   'R. Holding',
#   'R. Holding',
#   'Bellerín',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'A. Lacazette',
#   'G. Xhaka',
#   'M. Özil',
#   'M. Özil',
#   'R. Holding',
#   'Mohamed Elneny',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'A. Lacazette',
#   'Bellerín',
#   'G. Xhaka',
#   'Bellerín',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'M. Özil',
#   'R. Holding',
#   'R. Holding',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'G. Xhaka',
#   'M. Özil',
#   'M. Özil',
#   'G. Xhaka',
#   'R. Holding',
#   'R. Holding',
#   'P. Čech',
#   'R. Holding',
#   'P. Čech',
#   'R. Holding',
#   'D. Welbeck',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'M. Özil',
#   'Mohamed Elneny',
#   'Bellerín',
#   'A. Lacazette',
#   'Bellerín',
#   'Mohamed Elneny',
#   'Mohamed Elneny',
#   'M. Özil',
#   nan,
#   'R. Holding',
#   'P. Čech',
#   'R. Holding',
#   'Nacho Monreal',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'M. Özil',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   nan,
#   'Bellerín',
#   'R. Holding',
#   'P. Čech',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'Mohamed Elneny',
#   'Mohamed Elneny',
#   'P. Čech',
#   'P. Čech',
#   'R. Holding',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'Bellerín',
#   'Bellerín',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'D. Welbeck',
#   'A. Oxlade-Chamberlain',
#   'A. Lacazette',
#   'Mohamed Elneny',
#   'Bellerín',
#   'Mohamed Elneny',
#   'Bellerín',
#   'Mohamed Elneny',
#   'Nacho Monreal',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'M. Özil',
#   'G. Xhaka',
#   'Bellerín',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'M. Özil',
#   'G. Xhaka',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'S. Kolašinac',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'A. Oxlade-Chamberlain',
#   'R. Holding',
#   'A. Oxlade-Chamberlain',
#   'A. Oxlade-Chamberlain',
#   'Bellerín',
#   'Bellerín',
#   'R. Holding',
#   'Mohamed Elneny',
#   'A. Oxlade-Chamberlain',
#   'S. Kolašinac',
#   'P. Čech',
#   'R. Holding',
#   'Nacho Monreal',
#   'R. Holding',
#   'Nacho Monreal',
#   'S. Kolašinac',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'A. Oxlade-Chamberlain',
#   'Mohamed Elneny',
#   'R. Holding',
#   'Mohamed Elneny',
#   'G. Xhaka',
#   'D. Welbeck',
#   'G. Xhaka',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'Mohamed Elneny',
#   'M. Özil',
#   'S. Kolašinac',
#   'G. Xhaka',
#   'Nacho Monreal',
#   'A. Oxlade-Chamberlain',
#   'G. Xhaka',
#   'M. Özil',
#   'A. Lacazette',
#   'S. Kolašinac']]

# %%
ps = PrefixSpan(result_list)

with open("saida1.txt", "w") as f:
    print(ps.frequent(minsup=2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 4
#       1 ps = PrefixSpan(result_list)
#       3 with open("saida1.txt", "w") as f:
# ----> 4     print(ps.frequent(minsup=2))
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/prefixspan/frequent.py:70, in PrefixSpan_frequent(self, minsup, closed, generator, key, bound, filter, callback)
#      67 if key is None:
#      68     key = bound = PrefixSpan.defaultkey
# ---> 70 results = self._mine(frequent_rec)
#      72 return None if callback else results
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/prefixspan/prefixspan.py:19, in PrefixSpan._mine(self, func)
#      15 def _mine(self, func):
#      16     # type: (Callable[[Pattern, Matches], None]) -> Any
#      17     self._results.clear()
# ---> 19     func([], [(i, -1) for i in range(len(self._db))])
#      21     return self._results
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/prefixspan/frequent.py:61, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      55     if canpass(bound(newpatt, newmatches)) or (
#      56             closed and canclosedprune(self._db, newpatt, newmatches) or
#      57             generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)
#      58         ):
#      59         continue
# ---> 61     frequent_rec(newpatt, newmatches)
#      63 if generator:
#      64     occursstack.pop()
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/prefixspan/frequent.py:61, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      55     if canpass(bound(newpatt, newmatches)) or (
#      56             closed and canclosedprune(self._db, newpatt, newmatches) or
#      57             generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)
#      58         ):
#      59         continue
# ---> 61     frequent_rec(newpatt, newmatches)
#      63 if generator:
#      64     occursstack.pop()
#
#     [... skipping similar frames: PrefixSpan_frequent.<locals>.frequent_rec at line 61 (421 times)]
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/prefixspan/frequent.py:61, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      55     if canpass(bound(newpatt, newmatches)) or (
#      56             closed and canclosedprune(self._db, newpatt, newmatches) or
#      57             generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)
#      58         ):
#      59         continue
# ---> 61     frequent_rec(newpatt, newmatches)
#      63 if generator:
#      64     occursstack.pop()
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/prefixspan/frequent.py:49, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      46     if len(patt) == self.maxlen:
#      47         return
# ---> 49 occurs = nextentries(self._db, matches)
#      50 if generator:
#      51     occursstack.append(occurs)
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/extratools/dicttools.py:66, in nextentries(data, entries)
#      65 def nextentries(data: Sequence[Sequence[T]], entries: Entries) -> Mapping[T, Entries]:
# ---> 66     return invertedindex(
#      67         (data[i][lastpos + 1:] for i, lastpos in entries),
#      68         entries
#      69     )
#
# File /scratch/luisfeliperamos/anaconda3/envs/projeto-ad/lib/python3.10/site-packages/extratools/dicttools.py:57, in invertedindex(seqs, entries)
#      55 for p, item in enumerate(seq, start=(lastpos + 1)):
#      56     l = index[item]
# ---> 57     if len(l) and l[-1][0] == i:
#      58         continue
#      60     l.append((i, p))
#
# KeyboardInterrupt:

# %%
df
# Out:
#         game_id  period_id  time_seconds  team_id  player_id  start_x  \
# 0       2499719          1      2.758649     1609      25413    51.45
# 1       2499719          1      4.946850     1609     370224    32.55
# 2       2499719          1      6.542188     1609       3319    53.55
# 3       2499719          1      8.143395     1609     120339    36.75
# 4       2499719          1     10.302366     1609     167145    43.05
# ...         ...        ...           ...      ...        ...      ...
# 389146  2517044          2   2817.761761     2463      94831    87.15
# 389147  2517044          2   2818.280436     2451      14917    17.85
# 389148  2517044          2   2823.180681     2451      14804    23.10
# 389149  2517044          2   2828.080925     2451      14804     0.00
# 389150  2517044          2   2829.509819     2463      15317    99.75
#
#         start_y   end_x  end_y  original_event_id  bodypart_id  type_id  \
# 0         34.68   32.55  14.96        177959171.0            0        0
# 1         14.96   53.55  17.00        177959172.0            0        0
# 2         17.00   36.75  19.72        177959173.0            1        0
# 3         19.72   43.05   3.40        177959174.0            1        0
# 4          3.40   75.60   8.16        177959175.0            0        0
# ...         ...     ...    ...                ...          ...      ...
# 389146    36.72   87.15  36.72        251206865.0            5       11
# 389147    31.96   23.10  27.20        251206783.0            0       10
# 389148    27.20    0.00   3.40                NaN            0       21
# 389149     3.40    5.25   4.76        251206790.0            0        0
# 389150    63.24  105.00   0.00        251206869.0            0       10
#
#         result_id  action_id     type_name result_name bodypart_name  \
# 0               1          0          pass     success          foot
# 1               1          1          pass     success          foot
# 2               1          2          pass     success          head
# 3               1          3          pass     success          head
# 4               1          4          pass     success          foot
# ...           ...        ...           ...         ...           ...
# 389146          0       1148          shot        fail    foot_right
# 389147          1       1149  interception     success          foot
# 389148          1       1150       dribble     success          foot
# 389149          0       1151          pass        fail          foot
# 389150          1       1152  interception     success          foot
#
#               player_name
# 0            A. Lacazette
# 1              R. Holding
# 2                 M. Özil
# 3          Mohamed Elneny
# 4                Bellerín
# ...                   ...
# 389146           Y. Ōsako
# 389147          R. Knoche
# 389148  J. Błaszczykowski
# 389149  J. Błaszczykowski
# 389150     L. Bittencourt
#
# [2320430 rows x 18 columns]
