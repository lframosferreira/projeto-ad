# %% [markdown]
# # Subgrupo Discovery - SSD++

# %%
import pandas as pd
import numpy as np
from math import sqrt
import os
import pysubgroup as ps

# %% [markdown]
# ## Tem que clonar o Repositório (dentro de projeto-ad)
#
# https://github.com/HMProenca/SSDpp-numeric

# %%
PATH: str = "../data/spadl_format/"
LEAGUES: list[str] = ["England", "Spain", "France", "Italy", "Germany"]

teams_df = pd.read_json("../data/wyscout/teams/teams.json")
players_df = pd.read_json("../data/wyscout/players/players.json")
ranking_df = pd.read_json('../data/wyscout/playeranks/playeranks.json')

df_dict = {}
if not os.path.exists("../data/processed/"):
    os.mkdir("../data/processed")
for league in LEAGUES:

    df = pd.read_csv(f"{PATH}{league}.csv", index_col=0)

    # remove not used columns
    df.drop(["original_event_id", "result_name","bodypart_id", "type_id"], inplace=True, axis=1)

    df_dict[league] = df
all_df = pd.concat([df for df in df_dict.values()])
all_df
# Out:
#         game_id  period_id  time_seconds  team_id  player_id  start_x  \
# 0       2499719          1      2.758649     1609      25413    51.45
# 1       2499719          1      4.946850     1609     370224    32.55
# 2       2499719          1      6.542188     1609       3319    53.55
# 3       2499719          1      8.143395     1609     120339    36.75
# 4       2499719          1     10.302366     1609     167145    43.05
# ...         ...        ...           ...      ...        ...      ...
# 389146  2517044          2   2817.761761     2463      94831    87.15
# 389147  2517044          2   2818.280436     2451      14917    17.85
# 389148  2517044          2   2823.180681     2451      14804    23.10
# 389149  2517044          2   2828.080925     2451      14804     0.00
# 389150  2517044          2   2829.509819     2463      15317    99.75
#
#         start_y   end_x  end_y  result_id  action_id     type_name  \
# 0         34.68   32.55  14.96          1          0          pass
# 1         14.96   53.55  17.00          1          1          pass
# 2         17.00   36.75  19.72          1          2          pass
# 3         19.72   43.05   3.40          1          3          pass
# 4          3.40   75.60   8.16          1          4          pass
# ...         ...     ...    ...        ...        ...           ...
# 389146    36.72   87.15  36.72          0       1148          shot
# 389147    31.96   23.10  27.20          1       1149  interception
# 389148    27.20    0.00   3.40          1       1150       dribble
# 389149     3.40    5.25   4.76          0       1151          pass
# 389150    63.24  105.00   0.00          1       1152  interception
#
#        bodypart_name        player_name
# 0               foot       A. Lacazette
# 1               foot         R. Holding
# 2               head            M. Özil
# 3               head     Mohamed Elneny
# 4               foot           Bellerín
# ...              ...                ...
# 389146    foot_right           Y. Ōsako
# 389147          foot          R. Knoche
# 389148          foot  J. Błaszczykowski
# 389149          foot  J. Błaszczykowski
# 389150          foot     L. Bittencourt
#
# [2320430 rows x 14 columns]

# %%
print(all_df["type_name"].unique())
# Out:
# ['pass' 'interception' 'dribble' 'take_on' 'tackle' 'foul'
#  'freekick_short' 'cross' 'shot' 'clearance' 'throw_in' 'goalkick'
#  'corner_short' 'corner_crossed' 'keeper_save' 'freekick_crossed'
#  'shot_freekick' 'bad_touch' 'shot_penalty']

# %% [markdown]
# ## Pre-process

# %%
GOAL_CENTER_X: int = 105
GOAL_CENTER_Y: int = 34

UPPER_CROSSBAR_X: int = 105
UPPER_CROSSBAR_Y: int = 38

LOWER_CROSSBAR_X: int = 105
LOWER_CROSSBAR_Y: int = 30


def get_shot_angle(shot_pos_x, shot_pos_y):
    v1 = np.array([UPPER_CROSSBAR_X - shot_pos_x, UPPER_CROSSBAR_Y - shot_pos_y])
    v2 = np.array([LOWER_CROSSBAR_X - shot_pos_x, LOWER_CROSSBAR_Y - shot_pos_y])
    return np.arccos(np.dot(v1 / np.linalg.norm(v1), v2 / np.linalg.norm(v2)))

def calcular_media_global():
    # Filtrar jogadores com dados válidos
    jogadores_validos = ranking_df[ranking_df['playerankScore'].notna()]
    media_global = np.sum(jogadores_validos['playerankScore'] * jogadores_validos['minutesPlayed']) / jogadores_validos['minutesPlayed'].sum()
    return media_global

media_rank_global = calcular_media_global()

def calcular_ranking_medio(player_id):
    jogador_rankings = ranking_df[ranking_df['playerId'] == player_id]
    if jogador_rankings.empty:
        return media_rank_global
    ranking_ponderado = np.sum(jogador_rankings['playerankScore'] * jogador_rankings['minutesPlayed']) / jogador_rankings['minutesPlayed'].sum()
    return ranking_ponderado

def calculate_distance(x1, y1, x2, y2):
    return sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)

def discretize_start_x(x):
    if x < 26.25:
        return 'defensive'
    elif x < 52.5:
        return 'pre-defensive'
    elif x < 78.75:
        return 'pre-attacking'
    else:
        return 'attacking'

def discretize_start_y(y):
    if y < 22.67:
        return 'left'
    elif y < 45.33:
        return 'center'
    else:
        return 'right'

def generate_shots_with_counts_events(df):
    shot_data = []
    result_ids = []
    grouped = df.groupby(['game_id', 'period_id'])
    
    for (game_id, period_id), group in grouped:
        group = group.sort_values(by='time_seconds').reset_index(drop=True)
        start_index = 0

        while start_index < len(group):
            shot_index = group[start_index:].index[group['type_name'][start_index:] == 'shot']
            if len(shot_index) == 0:
                break
            shot_index = shot_index[0]

            shot_row = group.loc[shot_index]
            play_events = group.loc[start_index:shot_index]
            
            for idx in play_events.index[::-1]:
                if play_events.loc[idx, 'team_id'] != shot_row['team_id']:
                    start_index = idx + 1
                    break
            else:
                start_index = play_events.index[0]

            play_events = group.loc[start_index:shot_index]

            player_rank = calcular_ranking_medio(shot_row['player_id'])
            
            play_distance = 0
            play_distance_towards_goal = 0
            play_distances_to_goal = []

            for i in range(1, len(play_events)):
                x1, y1 = play_events.iloc[i - 1][['start_x', 'start_y']]
                x2, y2 = play_events.iloc[i][['start_x', 'start_y']]
                dist = calculate_distance(x1, y1, x2, y2)
                play_distance += dist
                play_distance_towards_goal += x2 - x1
                play_distances_to_goal.append(sqrt((x2 - GOAL_CENTER_X) ** 2 + (y2 - GOAL_CENTER_Y) ** 2))

            if len(play_events) > 1:
                play_mean_distance_to_the_goal = np.mean(play_distances_to_goal)
                play_std_distance_to_the_goal = np.std(play_distances_to_goal)
            else:
                play_mean_distance_to_the_goal = 0
                play_std_distance_to_the_goal = 0

            play_duration = play_events['time_seconds'].iloc[-1] - play_events['time_seconds'].iloc[0]
            ratio_distance = play_distance_towards_goal / play_distance if play_distance != 0 else 0
            total_time_per_play = play_duration / len(play_events) if len(play_events) != 0 else 0
            play_speed = play_distance / play_duration if play_duration != 0 else 0
            play_speed_towards_goal = play_distance_towards_goal / play_duration if play_duration != 0 else 0

            shot_data.append({
                'game_id': game_id,
                'period_id': period_id,
                'team_id': shot_row['team_id'],
                'player_id': shot_row['player_id'],
                'time_seconds': shot_row['time_seconds'],
                'start_x': shot_row['start_x'],
                'start_y': shot_row['start_y'],
                # 'disc_start_x': discretize_start_x(shot_row['start_x']),
                # 'disc_start_y': discretize_start_y(shot_row['start_y']),
                'num_events': len(play_events),
                'num_passes': (play_events['type_name'] == 'pass').sum(),
                'num_dribbles': (play_events['type_name'] == 'dribble').sum(),
                'play_duration': play_duration,
                'player_rank': player_rank,
                'bodypart_name': shot_row['bodypart_name'],
                'play_distance': play_distance,
                'play_mean_distance_to_the_goal': play_mean_distance_to_the_goal,
                'play_std_distance_to_the_goal': play_std_distance_to_the_goal,
                'play_distance_towards_goal': play_distance_towards_goal,
                'ratio_distance': ratio_distance,
                'total_time_per_play': total_time_per_play,
                'play_speed': play_speed,
                'play_speed_towards_goal': play_speed_towards_goal,
            })

            result_ids.append(shot_row['result_id'])
            start_index = shot_index + 1

    shots_df = pd.DataFrame(shot_data)
    shots_df["shot_distance_from_goal"] = shots_df.apply(lambda x: sqrt((x["start_x"] - GOAL_CENTER_X)**2 + (x["start_y"] - GOAL_CENTER_Y)**2), axis=1)
    shots_df["shot_angle_from_goal"] = shots_df[["start_x", "start_y"]].apply(lambda pos: get_shot_angle(pos["start_x"], pos["start_y"]), axis=1)
    shots_df["result_id"] = result_ids
    return shots_df

shots_df = generate_shots_with_counts_events(all_df)

# %%
shots_df.head()
# Out:
#    game_id  period_id  team_id  player_id  time_seconds  start_x  start_y  \
# 0  2499719          1     1609      25413     94.595788    92.40    40.12
# 1  2499719          1     1631      26150    179.854785    89.25    32.64
# 2  2499719          1     1631      14763    254.745027   100.80    32.64
# 3  2499719          1     1609       7868    425.824035    85.05    45.56
# 4  2499719          1     1609       7868    815.462015    78.75    47.60
#
#    num_events  num_passes  num_dribbles  ...  play_mean_distance_to_the_goal  \
# 0           7           4             0  ...                       30.932864
# 1           2           0             0  ...                       15.808608
# 2           7           3             0  ...                       21.086920
# 3           6           3             1  ...                       57.591081
# 4           1           0             0  ...                        0.000000
#
#    play_std_distance_to_the_goal play_distance_towards_goal  ratio_distance  \
# 0                       8.413575                      24.15        0.154870
# 1                       0.000000                      -9.45       -0.258190
# 2                      12.262251                       4.20        0.034728
# 3                      22.443334                      75.60        0.783021
# 4                       0.000000                       0.00        0.000000
#
#    total_time_per_play  play_speed  play_speed_towards_goal  \
# 0             2.836950    7.852377                 1.216095
# 1             2.273328    8.050087                -2.078450
# 2             2.705084    6.386817                 0.221805
# 3             2.161246    7.445480                 5.829970
# 4             0.000000    0.000000                 0.000000
#
#    shot_distance_from_goal  shot_angle_from_goal  result_id
# 0                14.007655              0.509981          1
# 1                15.808608              0.494098          0
# 2                 4.414703              1.467310          1
# 3                23.057235              0.300168          0
# 4                29.563872              0.240030          0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Binary Goal/Not Goal

# %%
import os
import sys

# Obter o caminho absoluto do diretório do notebook atual
notebook_dir = os.getcwd()

# Caminho absoluto do diretório SSDpp-numeric
ssdpp_numeric_dir = os.path.abspath(os.path.join(notebook_dir, '..', 'SSDpp-numeric'))

# Adicionar o caminho ao sys.path
sys.path.append(ssdpp_numeric_dir)

# Agora, você pode importar o módulo
from _classes import SSDC

shots_df_cp = shots_df.copy()
shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds"], inplace=True, axis=1)

# %%
shots_df_cp.dtypes
# Out:
# start_x                           float64
# start_y                           float64
# num_events                          int64
# num_passes                          int64
# num_dribbles                        int64
# play_duration                     float64
# player_rank                       float64
# bodypart_name                      object
# play_distance                     float64
# play_mean_distance_to_the_goal    float64
# play_std_distance_to_the_goal     float64
# play_distance_towards_goal        float64
# ratio_distance                    float64
# total_time_per_play               float64
# play_speed                        float64
# play_speed_towards_goal           float64
# shot_distance_from_goal           float64
# shot_angle_from_goal              float64
# result_id                           int64
# dtype: object

# %%
for col in ["bodypart_name"]:
    shots_df_cp[col]=pd.Categorical(shots_df_cp[col])
shots_df_cp.dtypes
# Out:
# start_x                            float64
# start_y                            float64
# num_events                           int64
# num_passes                           int64
# num_dribbles                         int64
# play_duration                      float64
# player_rank                        float64
# bodypart_name                     category
# play_distance                      float64
# play_mean_distance_to_the_goal     float64
# play_std_distance_to_the_goal      float64
# play_distance_towards_goal         float64
# ratio_distance                     float64
# total_time_per_play                float64
# play_speed                         float64
# play_speed_towards_goal            float64
# shot_distance_from_goal            float64
# shot_angle_from_goal               float64
# result_id                            int64
# dtype: object

# %%
task_name = "discovery"
target_type = "binary"

# load class and fit to data
model = SSDC(task = task_name,max_depth=3, beam_width=25,max_rules=20,n_cutpoints=3)
model.fit(shots_df_cp)
# Out:
# /home/grad/ccomp/18/matheuspimenta/Descritivo/projeto-ad/SSDpp-numeric/src/util/_read_dataset.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1 0 2 ... 0 1 0]' has dtype incompatible with category, please explicitly cast to a compatible dtype first.
#   df.loc[:,colname] = df.loc[:,colname].cat.codes #transform this column to codes
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# Iteration: 20
# Iteration: 21
# Iteration: 22
# Iteration: 23
# Iteration: 24
# Iteration: 25
# Iteration: 26
# Iteration: 27
# Iteration: 28
# Iteration: 29
# Iteration: 30
# Iteration: 31
# Iteration: 32
# Iteration: 33
# Iteration: 34
# Iteration: 35
# Iteration: 36
# Iteration: 37
# Iteration: 38
# Iteration: 39
# Iteration: 40
# Iteration: 41
# Iteration: 42
# Iteration: 43
# Iteration: 44
# Iteration: 45
# Iteration: 46
# Iteration: 47
# Iteration: 48
# Iteration: 49
# Iteration: 50
# Iteration: 51
# Iteration: 52
# Iteration: 53
# Iteration: 54
# Iteration: 55
# Iteration: 56
# Iteration: 57
# Iteration: 58
# Iteration: 59
# Iteration: 60
# Iteration: 61
# Iteration: 62
# Iteration: 63
# Iteration: 64
# Iteration: 65
# Iteration: 66
# Iteration: 67
# Iteration: 68
# Iteration: 69
# Iteration: 70
# Iteration: 71
# Iteration: 72
# Iteration: 73
# Iteration: 74
# Iteration: 75
# Iteration: 76
# Iteration: 77
# Iteration: 78
# Iteration: 79
# Iteration: 80
# Iteration: 81
# Iteration: 82
# Iteration: 83
# Iteration: 84
# Iteration: 85
# Iteration: 86
# Iteration: 87
# Iteration: 88
# Iteration: 89
# Iteration: 90
# Iteration: 91
# Iteration: 92
# Iteration: 93
# Iteration: 94
# Iteration: 95
# Iteration: 96
# Iteration: 97
# Iteration: 98
# Iteration: 99
# Iteration: 100
# Iteration: 101
# Iteration: 102
# Iteration: 103
# Iteration: 104
# Iteration: 105
# Iteration: 106
# Iteration: 107
# Iteration: 108

# %%
model_estat = pd.DataFrame(model.statistic_rules)

# %%
df_model = pd.DataFrame(model.antecedent_description, columns=['Subgrupros'])

# %%
result_model = pd.concat([df_model, model_estat], axis=1)
result_model['WRAcc'] = (result_model['usage']/result_model['usage_default'])*((result_model['mean'])-(result_model['RSS_default_pattern']/result_model['usage_default']))

# %%
result_model
# Out:
#                                             Subgrupros  usage      mean  \
# 0    shot_distance_from_goal >= 24.89650778723795 A...    351  0.002849
# 1    27.200000000000003 <= start_y <= 34.0 AND shot...    301  0.003322
# 2    shot_distance_from_goal >= 24.89650778723795 A...    505  0.003960
# 3    shot_distance_from_goal >= 24.89650778723795 A...    208  0.004808
# 4    shot_distance_from_goal >= 24.89650778723795 A...    226  0.004425
# ..                                                 ...    ...       ...
# 102  shot_angle_from_goal <= 0.5591113717173855 AND...     88  0.022727
# 103  2.069372000000385 <= play_duration <= 16.30900...    195  0.035897
# 104  start_x >= 91.35 AND num_dribbles >= 1.0 AND 0...   1171  0.145175
# 105  play_speed >= 6.866680189143164 AND 1.51258485...     50  0.020000
# 106  play_distance_towards_goal <= -1.0499999999999...    803  0.074720
#
#      mean2  variance2      RSS2  variance  RSS_default_pattern  usage_default  \
# 0      0.0       0.00  0.022285  0.002841             4.699930          40110
# 1      0.0       0.00  0.022285  0.003311             4.142801          39809
# 2      0.0       0.00  0.022285  0.003945             7.204771          39304
# 3      0.0       0.00  0.022285  0.004785             3.106541          39096
# 4      0.0       0.00  0.022285  0.004405             3.307107          38870
# ..     ...        ...       ...       ...                  ...            ...
# 102    0.0       0.00  0.022285  0.022211             2.558314          10971
# 103    0.5       0.25  0.811168  0.034609             7.694986          10776
# 104    0.0       0.00  0.022285  0.124099           147.158097           9605
# 105    0.0       0.00  0.022285  0.019600             1.346012           9555
# 106    0.0       0.00  0.022285  0.069137            56.280482           8752
#
#      RSS_default_uncovered     WRAcc
# 0              3815.459977  0.000024
# 1              3811.317176  0.000024
# 2              3804.112405  0.000049
# 3              3801.005864  0.000025
# 4              3797.698757  0.000025
# ..                     ...       ...
# 102            1046.027425  0.000180
# 103            1038.332440  0.000637
# 104             891.174343  0.015831
# 105             889.828331  0.000104
# 106             833.547848  0.006266
#
# [107 rows x 11 columns]

# %%
sorted_df = result_model.sort_values(by=['WRAcc'], ascending=False)
for sg in sorted_df["Subgrupros"].tolist():
    print(sg)
# Out:
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND start_x >= 95.55
# start_x >= 91.35 AND num_dribbles >= 1.0 AND 0.3590221107608225 <= shot_angle_from_goal <= 0.5591113717173855
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND start_x >= 95.55
# shot_angle_from_goal >= 0.5591113717173857 AND num_events <= 1.0 AND start_x >= 95.55
# 34.68 <= start_y <= 40.8 AND start_x >= 95.55 AND play_speed >= 8.975720268508816
# start_x >= 91.35 AND 16.80000000000001 <= play_distance_towards_goal <= 46.199999999999996 AND 34.68 <= start_y <= 40.8
# play_distance_towards_goal <= -1.0499999999999972 AND 0.9285019999999804 <= total_time_per_play <= 2.4040031818181804 AND play_mean_distance_to_the_goal <= 28.03256333340805
# player_rank >= 0.016036157894736842 AND 2.0 <= num_passes <= 3.0 AND 0.3590221107608225 <= shot_angle_from_goal <= 0.5591113717173855
# play_distance_towards_goal >= 46.2 AND 27.200000000000003 <= start_y <= 34.0 AND 12.24944488538154 <= shot_distance_from_goal <= 17.09952046111235
# start_x >= 95.55 AND 27.200000000000003 <= start_y <= 34.0 AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173
# play_distance_towards_goal >= 46.2 AND 34.68 <= start_y <= 40.8 AND 6.912831000000551 <= play_duration <= 16.30900000000065
# shot_angle_from_goal >= 0.5591113717173857 AND total_time_per_play <= 0.9284542000000329 AND 0.010288819875776397 <= player_rank <= 0.016025
# player_rank >= 0.016036157894736842 AND shot_distance_from_goal <= 12.239999999999995 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004
# player_rank >= 0.016036157894736842 AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173 AND 27.200000000000003 <= start_y <= 34.0
# start_x >= 95.55 AND 34.68 <= start_y <= 40.8 AND player_rank >= 0.016036157894736842
# shot_distance_from_goal <= 12.239999999999995 AND bodypart_name = foot_right AND 27.200000000000003 <= start_y <= 34.0
# shot_angle_from_goal >= 0.5591113717173857 AND play_mean_distance_to_the_goal >= 41.333702238082196 AND 0.0 <= ratio_distance <= 0.23419992666306966
# bodypart_name = foot_left AND shot_distance_from_goal <= 12.239999999999995 AND play_distance <= 51.69401161355543
# 27.200000000000003 <= start_y <= 34.0 AND start_x >= 95.55 AND num_passes >= 4.0
# shot_distance_from_goal <= 12.239999999999995 AND play_distance_towards_goal >= 46.2 AND 0.3590221107608225 <= shot_angle_from_goal <= 0.5591113717173855
# player_rank >= 0.016036157894736842 AND num_events <= 1.0 AND 91.35 <= start_x <= 94.5
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND 1.5125848550168577 <= play_speed_towards_goal <= 3.85430551621531
# shot_angle_from_goal <= 0.2746754310739218 AND 0.004430909090909091 <= player_rank <= 0.016025 AND play_speed <= 6.866582612367187
# play_std_distance_to_the_goal >= 15.350719150153845 AND num_passes <= 1.0 AND 28.03464899379168 <= play_mean_distance_to_the_goal <= 41.332972724918804
# shot_distance_from_goal <= 12.239999999999995 AND bodypart_name = foot_right AND 4.0 <= num_events <= 6.0
# shot_angle_from_goal >= 0.5591113717173857 AND play_std_distance_to_the_goal >= 15.350719150153845 AND total_time_per_play <= 1.7608733333333173
# 82.95 <= start_x <= 90.3 AND play_mean_distance_to_the_goal <= 12.248561691273391 AND bodypart_name = foot_right
# 91.35 <= start_x <= 94.5 AND bodypart_name = head/other AND shot_distance_from_goal >= 12.24944488538154
# 0.2746754310739222 <= shot_angle_from_goal <= 0.3589087557638423 AND 82.95 <= start_x <= 90.3 AND player_rank <= 0.004408223684210527
# 91.35 <= start_x <= 94.5 AND bodypart_name = head/other AND 0.004430909090909091 <= player_rank <= 0.010281298299845441
# 82.95 <= start_x <= 90.3 AND 0.2746754310739222 <= shot_angle_from_goal <= 0.3589087557638423 AND 0.010288819875776397 <= player_rank <= 0.016025
# 0.2746754310739222 <= shot_angle_from_goal <= 0.3589087557638423 AND 82.95 <= start_x <= 90.3 AND num_dribbles >= 1.0
# shot_distance_from_goal <= 12.239999999999995 AND play_mean_distance_to_the_goal >= 41.333702238082196 AND play_distance <= 113.09374128444435
# 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND 16.80000000000001 <= play_distance_towards_goal <= 46.199999999999996 AND start_y >= 41.48
# 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND total_time_per_play >= 2.404011166666654
# 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND 6.912831000000551 <= play_duration <= 16.30900000000065 AND player_rank <= 0.004408223684210527
# 2.069372000000385 <= play_duration <= 16.30900000000065 AND play_speed >= 8.975720268508816 AND 0.0 <= ratio_distance <= 0.23419992666306966
# start_x <= 81.9 AND shot_angle_from_goal <= 0.2746754310739218 AND play_speed >= 6.866680189143164
# shot_distance_from_goal >= 17.1236941107928 AND play_mean_distance_to_the_goal <= 12.248561691273391 AND 27.200000000000003 <= start_y <= 34.0
# bodypart_name = head/other AND 91.35 <= start_x <= 94.5 AND total_time_per_play >= 2.404011166666654
# 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND 0.004430909090909091 <= player_rank <= 0.016025 AND play_distance_towards_goal <= -1.0499999999999972
# shot_angle_from_goal <= 0.2746754310739218 AND 91.35 <= start_x <= 94.5 AND play_speed_towards_goal >= 3.8543298619265163
# start_y >= 41.48 AND start_x <= 81.9 AND 0.0 <= play_speed_towards_goal <= 1.512578105623291
# 82.95 <= start_x <= 90.3 AND player_rank <= 0.004408223684210527 AND total_time_per_play >= 2.404011166666654
# shot_angle_from_goal <= 0.2746754310739218 AND player_rank <= 0.004408223684210527 AND bodypart_name = foot_left
# player_rank <= 0.004408223684210527 AND start_x <= 81.9 AND start_y <= 27.2
# shot_distance_from_goal >= 24.89650778723795 AND player_rank <= 0.010281298299845441 AND shot_angle_from_goal >= 0.2746754310739222
# start_x <= 81.9 AND 6.912831000000551 <= play_duration <= 16.30900000000065 AND play_mean_distance_to_the_goal >= 41.333702238082196
# 0.2746754310739222 <= shot_angle_from_goal <= 0.3589087557638423 AND play_mean_distance_to_the_goal <= 12.248561691273391 AND player_rank >= 0.016036157894736842
# shot_angle_from_goal <= 0.3589087557638423 AND play_mean_distance_to_the_goal <= 12.248561691273391 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441
# play_speed <= 4.638509785023105 AND shot_angle_from_goal <= 0.2746754310739218 AND 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605
# bodypart_name = head/other AND 12.24944488538154 <= shot_distance_from_goal <= 17.09952046111235 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004
# shot_distance_from_goal >= 24.89650778723795 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND num_events <= 1.0
# play_speed_towards_goal <= -0.015112411731641373 AND 1.7610080000001744 <= total_time_per_play <= 2.4040031818181804 AND player_rank <= 0.010281298299845441
# shot_angle_from_goal <= 0.2746754310739218 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND 6.866680189143164 <= play_speed <= 8.97561547479651
# 0.2746754310739222 <= shot_angle_from_goal <= 0.3589087557638423 AND 0.0 <= play_speed_towards_goal <= 1.512578105623291 AND 6.912831000000551 <= play_duration <= 16.30900000000065
# 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND shot_distance_from_goal >= 24.89650778723795 AND 1.7610080000001744 <= total_time_per_play <= 2.4040031818181804
# shot_angle_from_goal <= 0.5591113717173855 AND bodypart_name = head/other AND 6.866680189143164 <= play_speed <= 8.97561547479651
# shot_angle_from_goal <= 0.2746754310739218 AND 16.80000000000001 <= play_distance_towards_goal <= 46.199999999999996 AND 82.95 <= start_x <= 90.3
# start_x <= 81.9 AND num_events <= 1.0 AND player_rank >= 0.016036157894736842
# shot_distance_from_goal >= 24.89650778723795 AND play_std_distance_to_the_goal >= 15.350719150153845 AND player_rank >= 0.016036157894736842
# shot_distance_from_goal >= 12.24944488538154 AND bodypart_name = head/other AND player_rank <= 0.004408223684210527
# shot_angle_from_goal <= 0.2746754310739218 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173
# 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND play_distance_towards_goal <= -1.0499999999999972 AND 6.866680189143164 <= play_speed <= 8.97561547479651
# shot_distance_from_goal >= 24.89650778723795 AND 4.639406895108031 <= play_speed <= 6.866582612367187 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004
# start_x <= 81.9 AND num_events <= 1.0 AND shot_distance_from_goal <= 24.886333598985605
# shot_distance_from_goal >= 24.89650778723795 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND num_passes <= 1.0
# start_x <= 81.9 AND 27.200000000000003 <= start_y <= 34.0 AND num_events >= 7.0
# shot_angle_from_goal <= 0.2746754310739218 AND 0.0 <= play_distance_towards_goal <= 46.199999999999996 AND play_std_distance_to_the_goal >= 15.350719150153845
# shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND 0.010288819875776397 <= player_rank <= 0.016025
# start_x <= 81.9 AND player_rank <= 0.004408223684210527 AND 2.069372000000385 <= play_duration <= 6.911589999999933
# play_speed >= 6.866680189143164 AND 1.5125848550168577 <= play_speed_towards_goal <= 3.85430551621531 AND play_duration <= 2.0693500000001563
# shot_distance_from_goal >= 24.89650778723795 AND play_std_distance_to_the_goal >= 15.350719150153845 AND 2.0 <= num_passes <= 3.0
# start_x <= 81.9 AND 6.912831000000551 <= play_duration <= 16.30900000000065 AND play_distance_towards_goal <= -1.0499999999999972
# start_x <= 81.9 AND 27.200000000000003 <= start_y <= 34.0 AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173
# start_x <= 81.9 AND start_y >= 41.48 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441
# player_rank <= 0.004408223684210527 AND shot_distance_from_goal >= 24.89650778723795 AND bodypart_name = foot_left
# shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND play_distance <= 113.09374128444435
# 91.35 <= start_x <= 94.5 AND bodypart_name = head/other AND 0.0 <= play_distance_towards_goal <= 16.800000000000004
# play_distance <= 21.463913902175435 AND 28.03464899379168 <= play_mean_distance_to_the_goal <= 41.332972724918804 AND play_duration >= 2.069372000000385
# play_distance_towards_goal <= -1.0499999999999972 AND player_rank <= 0.004408223684210527 AND total_time_per_play >= 1.7610080000001744
# start_x <= 81.9 AND 0.0 <= play_speed_towards_goal <= 1.512578105623291 AND play_distance_towards_goal >= 46.2
# shot_distance_from_goal >= 24.89650778723795 AND player_rank <= 0.004408223684210527 AND 12.24944488538154 <= play_mean_distance_to_the_goal <= 28.03256333340805
# 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND num_dribbles >= 1.0 AND play_speed <= 4.638509785023105
# shot_distance_from_goal >= 24.89650778723795 AND num_dribbles >= 1.0 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004
# start_y <= 27.2 AND play_distance_towards_goal <= -1.0499999999999972 AND play_speed <= 4.638509785023105
# 0.2746754310739222 <= shot_angle_from_goal <= 0.3589087557638423 AND play_duration <= 2.0693500000001563 AND 4.639406895108031 <= play_speed <= 8.97561547479651
# 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND ratio_distance <= -0.002088480953773431 AND num_dribbles >= 1.0
# start_x <= 81.9 AND 6.912831000000551 <= play_duration <= 16.30900000000065 AND play_speed >= 8.975720268508816
# shot_angle_from_goal <= 0.3589087557638423 AND play_mean_distance_to_the_goal <= 12.248561691273391 AND play_speed >= 4.639406895108031
# 82.95 <= start_x <= 90.3 AND bodypart_name = head/other AND 0.9285019999999804 <= total_time_per_play <= 2.4040031818181804
# play_distance_towards_goal <= -1.0499999999999972 AND 28.03464899379168 <= play_mean_distance_to_the_goal <= 41.332972724918804 AND 34.68 <= start_y <= 40.8
# shot_distance_from_goal >= 24.89650778723795 AND 27.200000000000003 <= start_y <= 34.0 AND play_distance_towards_goal >= 46.2
# shot_angle_from_goal <= 0.2746754310739218 AND player_rank <= 0.004408223684210527 AND shot_distance_from_goal <= 17.09952046111235
# shot_angle_from_goal <= 0.2746754310739218 AND 27.200000000000003 <= start_y <= 34.0 AND play_mean_distance_to_the_goal >= 41.333702238082196
# play_speed <= 4.638509785023105 AND play_speed_towards_goal >= 3.8543298619265163 AND play_duration >= 2.069372000000385
# shot_distance_from_goal >= 24.89650778723795 AND play_speed <= 4.638509785023105 AND 0.2342718553376869 <= ratio_distance <= 0.5334145947719459
# play_distance_towards_goal <= -1.0499999999999972 AND 28.03464899379168 <= play_mean_distance_to_the_goal <= 41.332972724918804 AND play_duration >= 16.313611000000947
# shot_distance_from_goal >= 24.89650778723795 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND 12.24944488538154 <= play_mean_distance_to_the_goal <= 28.03256333340805
# shot_distance_from_goal >= 24.89650778723795 AND play_speed >= 8.975720268508816 AND 2.0 <= num_passes <= 3.0
# shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND play_speed <= 4.638509785023105
# shot_angle_from_goal <= 0.2746754310739218 AND play_mean_distance_to_the_goal <= 12.248561691273391 AND 82.95 <= start_x <= 90.3
# shot_distance_from_goal >= 24.89650778723795 AND 12.24944488538154 <= play_mean_distance_to_the_goal <= 28.03256333340805 AND 27.200000000000003 <= start_y <= 34.0
# shot_distance_from_goal >= 24.89650778723795 AND 2.0 <= num_passes <= 3.0 AND 82.95 <= start_x <= 90.3
# shot_distance_from_goal >= 24.89650778723795 AND play_speed >= 8.975720268508816 AND total_time_per_play <= 0.9284542000000329
# 27.200000000000003 <= start_y <= 34.0 AND shot_angle_from_goal <= 0.2746754310739218 AND play_speed <= 4.638509785023105
# shot_distance_from_goal >= 24.89650778723795 AND 21.463913902175438 <= play_distance <= 51.69401161355543 AND 7.181128065994731 <= play_std_distance_to_the_goal <= 15.350716739940347

# %%
sorted_df
# Out:
#                                             Subgrupros  usage      mean  \
# 16   shot_angle_from_goal >= 0.5591113717173857 AND...   1530  0.358824
# 104  start_x >= 91.35 AND num_dribbles >= 1.0 AND 0...   1171  0.145175
# 13   shot_angle_from_goal >= 0.5591113717173857 AND...    957  0.385580
# 5    shot_angle_from_goal >= 0.5591113717173857 AND...    878  0.431663
# 96   34.68 <= start_y <= 40.8 AND start_x >= 95.55 ...    592  0.168919
# ..                                                 ...    ...       ...
# 6    shot_distance_from_goal >= 24.89650778723795 A...    196  0.005102
# 4    shot_distance_from_goal >= 24.89650778723795 A...    226  0.004425
# 3    shot_distance_from_goal >= 24.89650778723795 A...    208  0.004808
# 1    27.200000000000003 <= start_y <= 34.0 AND shot...    301  0.003322
# 0    shot_distance_from_goal >= 24.89650778723795 A...    351  0.002849
#
#      mean2  variance2      RSS2  variance  RSS_default_pattern  usage_default  \
# 16     0.5       0.25  0.811168  0.229885           449.356104          32221
# 104    0.0       0.00  0.022285  0.124099           147.158097           9605
# 13     0.5       0.25  0.811168  0.236908           301.761325          35050
# 5      0.5       0.25  0.811168  0.245330           308.769892          37992
# 96     0.0       0.00  0.022285  0.140385            85.484722          12623
# ..     ...        ...       ...       ...                  ...            ...
# 6      0.0       0.00  0.022285  0.005076             2.972830          37796
# 4      0.0       0.00  0.022285  0.004405             3.307107          38870
# 3      0.0       0.00  0.022285  0.004785             3.106541          39096
# 1      0.0       0.00  0.022285  0.003311             4.142801          39809
# 0      0.0       0.00  0.022285  0.002841             4.699930          40110
#
#      RSS_default_uncovered     WRAcc
# 16             2676.763813  0.016376
# 104             891.174343  0.015831
# 13             3154.005147  0.010293
# 5              3488.928865  0.009788
# 96             1202.489521  0.007604
# ..                     ...       ...
# 6              3485.956035  0.000026
# 4              3797.698757  0.000025
# 3              3801.005864  0.000025
# 1              3811.317176  0.000024
# 0              3815.459977  0.000024
#
# [107 rows x 11 columns]

# %%
print(model) # returns the list of if-then-else if rules/subgroups with their respective antecedent description and consequent statistics
# Out:
# IF x in shot_distance_from_goal >= 24.89650778723795 AND 21.463913902175438 <= play_distance <= 51.69401161355543 AND 7.181128065994731 <= play_std_distance_to_the_goal <= 15.350716739940347 THEN mean = 0.002849002849002849; std = 0.05329996277455758 ,
# ELSE IF x in 27.200000000000003 <= start_y <= 34.0 AND shot_angle_from_goal <= 0.2746754310739218 AND play_speed <= 4.638509785023105 THEN mean = 0.0033222591362126247; std = 0.057543216198301564 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND num_dribbles >= 1.0 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004 THEN mean = 0.0039603960396039604; std = 0.06280693674120275 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND play_speed >= 8.975720268508816 AND total_time_per_play <= 0.9284542000000329 THEN mean = 0.004807692307692308; std = 0.06917064697085654 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 2.0 <= num_passes <= 3.0 AND 82.95 <= start_x <= 90.3 THEN mean = 0.004424778761061947; std = 0.06637168141592921 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND num_events <= 1.0 AND start_x >= 95.55 THEN mean = 0.4316628701594533; std = 0.49530802202786484 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 12.24944488538154 <= play_mean_distance_to_the_goal <= 28.03256333340805 AND 27.200000000000003 <= start_y <= 34.0 THEN mean = 0.00510204081632653; std = 0.07124612267229052 ,
# ELSE IF x in shot_angle_from_goal <= 0.2746754310739218 AND play_mean_distance_to_the_goal <= 12.248561691273391 AND 82.95 <= start_x <= 90.3 THEN mean = 0.004273504273504274; std = 0.06523221163450323 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND play_speed <= 4.638509785023105 THEN mean = 0.005376344086021506; std = 0.0731261855308357 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND 0.010288819875776397 <= player_rank <= 0.016025 THEN mean = 0.008869179600886918; std = 0.09375775836747657 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND play_speed >= 8.975720268508816 AND 2.0 <= num_passes <= 3.0 THEN mean = 0.00546448087431694; std = 0.07371987739471061 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 4.639406895108031 <= play_speed <= 6.866582612367187 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004 THEN mean = 0.008605851979345954; std = 0.09236769614456966 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND 12.24944488538154 <= play_mean_distance_to_the_goal <= 28.03256333340805 THEN mean = 0.006493506493506494; std = 0.0803202394600843 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND start_x >= 95.55 THEN mean = 0.38557993730407525; std = 0.48673200968567965 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND player_rank <= 0.004408223684210527 AND 12.24944488538154 <= play_mean_distance_to_the_goal <= 28.03256333340805 THEN mean = 0.010256410256410256; std = 0.10075324463788973 ,
# ELSE IF x in shot_angle_from_goal <= 0.2746754310739218 AND player_rank <= 0.004408223684210527 AND bodypart_name = foot_left THEN mean = 0.012681159420289856; std = 0.11189435917885693 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND start_x >= 95.55 THEN mean = 0.3588235294117647; std = 0.4794628867245628 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND play_std_distance_to_the_goal >= 15.350719150153845 AND 2.0 <= num_passes <= 3.0 THEN mean = 0.012987012987012988; std = 0.11321815437767983 ,
# ELSE IF x in play_distance_towards_goal <= -1.0499999999999972 AND 28.03464899379168 <= play_mean_distance_to_the_goal <= 41.332972724918804 AND play_duration >= 16.313611000000947 THEN mean = 0.005376344086021506; std = 0.0731261855308357 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND play_speed <= 4.638509785023105 AND 0.2342718553376869 <= ratio_distance <= 0.5334145947719459 THEN mean = 0.008620689655172414; std = 0.0924465973686518 ,
# ELSE IF x in play_speed <= 4.638509785023105 AND play_speed_towards_goal >= 3.8543298619265163 AND play_duration >= 2.069372000000385 THEN mean = 0.01098901098901099; std = 0.10425091187368282 ,
# ELSE IF x in start_x <= 81.9 AND 0.0 <= play_speed_towards_goal <= 1.512578105623291 AND play_distance_towards_goal >= 46.2 THEN mean = 0.012987012987012988; std = 0.11321815437767983 ,
# ELSE IF x in shot_angle_from_goal <= 0.2746754310739218 AND 27.200000000000003 <= start_y <= 34.0 AND play_mean_distance_to_the_goal >= 41.333702238082196 THEN mean = 0.009523809523809525; std = 0.09712418121129116 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND num_events <= 1.0 THEN mean = 0.01618705035971223; std = 0.12619441255604133 ,
# ELSE IF x in 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND shot_distance_from_goal >= 24.89650778723795 AND 1.7610080000001744 <= total_time_per_play <= 2.4040031818181804 THEN mean = 0.01662049861495845; std = 0.12784466215195933 ,
# ELSE IF x in shot_angle_from_goal <= 0.2746754310739218 AND player_rank <= 0.004408223684210527 AND shot_distance_from_goal <= 17.09952046111235 THEN mean = 0.00909090909090909; std = 0.09491187735373227 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND num_passes <= 1.0 THEN mean = 0.01652892561983471; std = 0.12749792248381417 ,
# ELSE IF x in start_x <= 81.9 AND num_events <= 1.0 AND shot_distance_from_goal <= 24.886333598985605 THEN mean = 0.016736401673640166; std = 0.12828208967996566 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 27.200000000000003 <= start_y <= 34.0 AND play_distance_towards_goal >= 46.2 THEN mean = 0.012658227848101266; std = 0.11179444134592212 ,
# ELSE IF x in player_rank <= 0.004408223684210527 AND start_x <= 81.9 AND start_y <= 27.2 THEN mean = 0.02145922746781116; std = 0.14490938211273932 ,
# ELSE IF x in play_distance_towards_goal <= -1.0499999999999972 AND 28.03464899379168 <= play_mean_distance_to_the_goal <= 41.332972724918804 AND 34.68 <= start_y <= 40.8 THEN mean = 0.008695652173913044; std = 0.09284415871331575 ,
# ELSE IF x in play_distance <= 21.463913902175435 AND 28.03464899379168 <= play_mean_distance_to_the_goal <= 41.332972724918804 AND play_duration >= 2.069372000000385 THEN mean = 0.011494252873563218; std = 0.10659331604018049 ,
# ELSE IF x in 82.95 <= start_x <= 90.3 AND bodypart_name = head/other AND 0.9285019999999804 <= total_time_per_play <= 2.4040031818181804 THEN mean = 0.00819672131147541; std = 0.09016393442622951 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND play_distance <= 113.09374128444435 THEN mean = 0.012345679012345678; std = 0.11042310999998964 ,
# ELSE IF x in start_x <= 81.9 AND player_rank <= 0.004408223684210527 AND 2.069372000000385 <= play_duration <= 6.911589999999933 THEN mean = 0.017857142857142856; std = 0.13243211584099399 ,
# ELSE IF x in player_rank <= 0.004408223684210527 AND shot_distance_from_goal >= 24.89650778723795 AND bodypart_name = foot_left THEN mean = 0.014084507042253521; std = 0.11783944035691203 ,
# ELSE IF x in shot_angle_from_goal <= 0.3589087557638423 AND play_mean_distance_to_the_goal <= 12.248561691273391 AND play_speed >= 4.639406895108031 THEN mean = 0.0136986301369863; std = 0.11623673115395301 ,
# ELSE IF x in 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND play_distance_towards_goal <= -1.0499999999999972 AND 6.866680189143164 <= play_speed <= 8.97561547479651 THEN mean = 0.019801980198019802; std = 0.1393192799947553 ,
# ELSE IF x in start_x <= 81.9 AND 6.912831000000551 <= play_duration <= 16.30900000000065 AND play_speed >= 8.975720268508816 THEN mean = 0.0125; std = 0.11110243021644485 ,
# ELSE IF x in shot_angle_from_goal <= 0.2746754310739218 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173 THEN mean = 0.021739130434782608; std = 0.14583052027172536 ,
# ELSE IF x in start_x <= 81.9 AND start_y >= 41.48 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 THEN mean = 0.01694915254237288; std = 0.12908090009938827 ,
# ELSE IF x in play_speed <= 4.638509785023105 AND shot_angle_from_goal <= 0.2746754310739218 AND 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 THEN mean = 0.025236593059936908; std = 0.15684293873383037 ,
# ELSE IF x in shot_angle_from_goal <= 0.3589087557638423 AND play_mean_distance_to_the_goal <= 12.248561691273391 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 THEN mean = 0.025396825396825397; std = 0.1573271326141443 ,
# ELSE IF x in start_x <= 81.9 AND 27.200000000000003 <= start_y <= 34.0 AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173 THEN mean = 0.018867924528301886; std = 0.1360585386967543 ,
# ELSE IF x in start_x <= 81.9 AND 6.912831000000551 <= play_duration <= 16.30900000000065 AND play_distance_towards_goal <= -1.0499999999999972 THEN mean = 0.02; std = 0.13999999999999999 ,
# ELSE IF x in start_y >= 41.48 AND start_x <= 81.9 AND 0.0 <= play_speed_towards_goal <= 1.512578105623291 THEN mean = 0.028350515463917526; std = 0.16597217759867974 ,
# ELSE IF x in 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND ratio_distance <= -0.002088480953773431 AND num_dribbles >= 1.0 THEN mean = 0.011764705882352941; std = 0.10782531046954918 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND play_std_distance_to_the_goal >= 15.350719150153845 AND total_time_per_play <= 1.7608733333333173 THEN mean = 0.2929936305732484; std = 0.4522292993630574 ,
# ELSE IF x in shot_distance_from_goal >= 12.24944488538154 AND bodypart_name = head/other AND player_rank <= 0.004408223684210527 THEN mean = 0.01606425702811245; std = 0.12572269753010862 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND play_mean_distance_to_the_goal >= 41.333702238082196 AND 0.0 <= ratio_distance <= 0.23419992666306966 THEN mean = 0.250814332247557; std = 0.4334818369744794 ,
# ELSE IF x in 0.2746754310739222 <= shot_angle_from_goal <= 0.3589087557638423 AND play_duration <= 2.0693500000001563 AND 4.639406895108031 <= play_speed <= 8.97561547479651 THEN mean = 0.009523809523809525; std = 0.09712418121129114 ,
# ELSE IF x in 0.2746754310739222 <= shot_angle_from_goal <= 0.3589087557638423 AND 0.0 <= play_speed_towards_goal <= 1.512578105623291 AND 6.912831000000551 <= play_duration <= 16.30900000000065 THEN mean = 0.023696682464454975; std = 0.1521024316197271 ,
# ELSE IF x in 0.2746754310739222 <= shot_angle_from_goal <= 0.3589087557638423 AND 82.95 <= start_x <= 90.3 AND player_rank <= 0.004408223684210527 THEN mean = 0.03571428571428571; std = 0.1855768722395226 ,
# ELSE IF x in start_x <= 81.9 AND 27.200000000000003 <= start_y <= 34.0 AND num_events >= 7.0 THEN mean = 0.022556390977443608; std = 0.1484843432942218 ,
# ELSE IF x in bodypart_name = head/other AND 12.24944488538154 <= shot_distance_from_goal <= 17.09952046111235 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004 THEN mean = 0.02880658436213992; std = 0.1672625632337578 ,
# ELSE IF x in start_x <= 81.9 AND num_events <= 1.0 AND player_rank >= 0.016036157894736842 THEN mean = 0.028169014084507043; std = 0.16545549471085538 ,
# ELSE IF x in shot_angle_from_goal <= 0.2746754310739218 AND 16.80000000000001 <= play_distance_towards_goal <= 46.199999999999996 AND 82.95 <= start_x <= 90.3 THEN mean = 0.02702702702702703; std = 0.16216216216216217 ,
# ELSE IF x in player_rank >= 0.016036157894736842 AND shot_distance_from_goal <= 12.239999999999995 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004 THEN mean = 0.23641304347826086; std = 0.42487870781154335 ,
# ELSE IF x in start_x >= 95.55 AND 34.68 <= start_y <= 40.8 AND player_rank >= 0.016036157894736842 THEN mean = 0.2553191489361702; std = 0.43404602974549844 ,
# ELSE IF x in start_y <= 27.2 AND play_distance_towards_goal <= -1.0499999999999972 AND play_speed <= 4.638509785023105 THEN mean = 0.01694915254237288; std = 0.12908090009938827 ,
# ELSE IF x in shot_angle_from_goal <= 0.2746754310739218 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND 6.866680189143164 <= play_speed <= 8.97561547479651 THEN mean = 0.027624309392265192; std = 0.16389388921758374 ,
# ELSE IF x in 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND 0.004430909090909091 <= player_rank <= 0.016025 AND play_distance_towards_goal <= -1.0499999999999972 THEN mean = 0.033003300330033; std = 0.17864513006896848 ,
# ELSE IF x in shot_distance_from_goal <= 12.239999999999995 AND play_mean_distance_to_the_goal >= 41.333702238082196 AND play_distance <= 113.09374128444435 THEN mean = 0.2894736842105263; std = 0.45351810367405493 ,
# ELSE IF x in 82.95 <= start_x <= 90.3 AND 0.2746754310739222 <= shot_angle_from_goal <= 0.3589087557638423 AND 0.010288819875776397 <= player_rank <= 0.016025 THEN mean = 0.03940886699507389; std = 0.1945656912131182 ,
# ELSE IF x in start_x <= 81.9 AND 6.912831000000551 <= play_duration <= 16.30900000000065 AND play_mean_distance_to_the_goal >= 41.333702238082196 THEN mean = 0.035; std = 0.18377975949489103 ,
# ELSE IF x in shot_angle_from_goal <= 0.2746754310739218 AND 91.35 <= start_x <= 94.5 AND play_speed_towards_goal >= 3.8543298619265163 THEN mean = 0.03571428571428571; std = 0.18557687223952254 ,
# ELSE IF x in shot_distance_from_goal >= 17.1236941107928 AND play_mean_distance_to_the_goal <= 12.248561691273391 AND 27.200000000000003 <= start_y <= 34.0 THEN mean = 0.039634146341463415; std = 0.19509813116800193 ,
# ELSE IF x in 0.2746754310739222 <= shot_angle_from_goal <= 0.3589087557638423 AND 82.95 <= start_x <= 90.3 AND num_dribbles >= 1.0 THEN mean = 0.0421455938697318; std = 0.20092123528163833 ,
# ELSE IF x in shot_distance_from_goal <= 12.239999999999995 AND bodypart_name = foot_right AND 27.200000000000003 <= start_y <= 34.0 THEN mean = 0.22340425531914893; std = 0.4165270627755721 ,
# ELSE IF x in 0.2746754310739222 <= shot_angle_from_goal <= 0.3589087557638423 AND play_mean_distance_to_the_goal <= 12.248561691273391 AND player_rank >= 0.016036157894736842 THEN mean = 0.03225806451612903; std = 0.17668469596940845 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND total_time_per_play <= 0.9284542000000329 AND 0.010288819875776397 <= player_rank <= 0.016025 THEN mean = 0.2106537530266344; std = 0.4077729139636767 ,
# ELSE IF x in play_std_distance_to_the_goal >= 15.350719150153845 AND num_passes <= 1.0 AND 28.03464899379168 <= play_mean_distance_to_the_goal <= 41.332972724918804 THEN mean = 0.22950819672131148; std = 0.42051656847149704 ,
# ELSE IF x in start_x <= 81.9 AND shot_angle_from_goal <= 0.2746754310739218 AND play_speed >= 6.866680189143164 THEN mean = 0.043795620437956206; std = 0.20464008421717061 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND play_std_distance_to_the_goal >= 15.350719150153845 AND player_rank >= 0.016036157894736842 THEN mean = 0.027777777777777776; std = 0.16433554953054486 ,
# ELSE IF x in 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND total_time_per_play >= 2.404011166666654 THEN mean = 0.04477611940298507; std = 0.2068120367246421 ,
# ELSE IF x in shot_distance_from_goal <= 12.239999999999995 AND play_distance_towards_goal >= 46.2 AND 0.3590221107608225 <= shot_angle_from_goal <= 0.5591113717173855 THEN mean = 0.21031746031746032; std = 0.40753407980569395 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND player_rank <= 0.010281298299845441 AND shot_angle_from_goal >= 0.2746754310739222 THEN mean = 0.0335195530726257; std = 0.17998886808477113 ,
# ELSE IF x in player_rank >= 0.016036157894736842 AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173 AND 27.200000000000003 <= start_y <= 34.0 THEN mean = 0.20303030303030303; std = 0.4022548931731302 ,
# ELSE IF x in 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND num_dribbles >= 1.0 AND play_speed <= 4.638509785023105 THEN mean = 0.01639344262295082; std = 0.12698306053139075 ,
# ELSE IF x in shot_angle_from_goal <= 0.2746754310739218 AND 0.0 <= play_distance_towards_goal <= 46.199999999999996 AND play_std_distance_to_the_goal >= 15.350719150153845 THEN mean = 0.025; std = 0.15612494995995996 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND 1.5125848550168577 <= play_speed_towards_goal <= 3.85430551621531 THEN mean = 0.22388059701492538; std = 0.4168429863811624 ,
# ELSE IF x in 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND 16.80000000000001 <= play_distance_towards_goal <= 46.199999999999996 AND start_y >= 41.48 THEN mean = 0.045576407506702415; std = 0.20856461489304803 ,
# ELSE IF x in 27.200000000000003 <= start_y <= 34.0 AND start_x >= 95.55 AND num_passes >= 4.0 THEN mean = 0.205761316872428; std = 0.40425684576931076 ,
# ELSE IF x in player_rank >= 0.016036157894736842 AND 2.0 <= num_passes <= 3.0 AND 0.3590221107608225 <= shot_angle_from_goal <= 0.5591113717173855 THEN mean = 0.1794425087108014; std = 0.38372241891551656 ,
# ELSE IF x in shot_distance_from_goal <= 12.239999999999995 AND bodypart_name = foot_right AND 4.0 <= num_events <= 6.0 THEN mean = 0.2246376811594203; std = 0.4173434956516502 ,
# ELSE IF x in 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND 6.912831000000551 <= play_duration <= 16.30900000000065 AND player_rank <= 0.004408223684210527 THEN mean = 0.0456140350877193; std = 0.20864657890973345 ,
# ELSE IF x in start_x >= 95.55 AND 27.200000000000003 <= start_y <= 34.0 AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173 THEN mean = 0.17973231357552583; std = 0.38396433302106947 ,
# ELSE IF x in play_distance_towards_goal <= -1.0499999999999972 AND player_rank <= 0.004408223684210527 AND total_time_per_play >= 1.7610080000001744 THEN mean = 0.011494252873563218; std = 0.10659331604018049 ,
# ELSE IF x in bodypart_name = head/other AND 91.35 <= start_x <= 94.5 AND total_time_per_play >= 2.404011166666654 THEN mean = 0.02922077922077922; std = 0.16842483570575245 ,
# ELSE IF x in play_speed_towards_goal <= -0.015112411731641373 AND 1.7610080000001744 <= total_time_per_play <= 2.4040031818181804 AND player_rank <= 0.010281298299845441 THEN mean = 0.029850746268656716; std = 0.1701754365819609 ,
# ELSE IF x in 91.35 <= start_x <= 94.5 AND bodypart_name = head/other AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 THEN mean = 0.04381443298969072; std = 0.20468201789967438 ,
# ELSE IF x in 91.35 <= start_x <= 94.5 AND bodypart_name = head/other AND 0.0 <= play_distance_towards_goal <= 16.800000000000004 THEN mean = 0.018518518518518517; std = 0.13481684980149108 ,
# ELSE IF x in player_rank >= 0.016036157894736842 AND num_events <= 1.0 AND 91.35 <= start_x <= 94.5 THEN mean = 0.20418848167539266; std = 0.4031073624067049 ,
# ELSE IF x in shot_angle_from_goal <= 0.2746754310739218 AND 0.004430909090909091 <= player_rank <= 0.016025 AND play_speed <= 6.866582612367187 THEN mean = 0.056466302367941715; std = 0.23081997111349326 ,
# ELSE IF x in bodypart_name = foot_left AND shot_distance_from_goal <= 12.239999999999995 AND play_distance <= 51.69401161355543 THEN mean = 0.20408163265306123; std = 0.40302893179860205 ,
# ELSE IF x in play_distance_towards_goal >= 46.2 AND 27.200000000000003 <= start_y <= 34.0 AND 12.24944488538154 <= shot_distance_from_goal <= 17.09952046111235 THEN mean = 0.19248826291079812; std = 0.39425439953459185 ,
# ELSE IF x in 34.68 <= start_y <= 40.8 AND start_x >= 95.55 AND play_speed >= 8.975720268508816 THEN mean = 0.16891891891891891; std = 0.37468028737869646 ,
# ELSE IF x in 91.35 <= start_x <= 94.5 AND bodypart_name = head/other AND shot_distance_from_goal >= 12.24944488538154 THEN mean = 0.052486187845303865; std = 0.22300535404059546 ,
# ELSE IF x in 82.95 <= start_x <= 90.3 AND player_rank <= 0.004408223684210527 AND total_time_per_play >= 2.404011166666654 THEN mean = 0.03968253968253968; std = 0.19521228374998162 ,
# ELSE IF x in play_distance_towards_goal >= 46.2 AND 34.68 <= start_y <= 40.8 AND 6.912831000000551 <= play_duration <= 16.30900000000065 THEN mean = 0.1836734693877551; std = 0.3872176726736791 ,
# ELSE IF x in 82.95 <= start_x <= 90.3 AND play_mean_distance_to_the_goal <= 12.248561691273391 AND bodypart_name = foot_right THEN mean = 0.05421686746987952; std = 0.2264451340868976 ,
# ELSE IF x in start_x >= 91.35 AND 16.80000000000001 <= play_distance_towards_goal <= 46.199999999999996 AND 34.68 <= start_y <= 40.8 THEN mean = 0.1711111111111111; std = 0.3766060259282 ,
# ELSE IF x in shot_angle_from_goal <= 0.5591113717173855 AND bodypart_name = head/other AND 6.866680189143164 <= play_speed <= 8.97561547479651 THEN mean = 0.022727272727272728; std = 0.14903269373413638 ,
# ELSE IF x in 2.069372000000385 <= play_duration <= 16.30900000000065 AND play_speed >= 8.975720268508816 AND 0.0 <= ratio_distance <= 0.23419992666306966 THEN mean = 0.035897435897435895; std = 0.18603443227914926 ,
# ELSE IF x in start_x >= 91.35 AND num_dribbles >= 1.0 AND 0.3590221107608225 <= shot_angle_from_goal <= 0.5591113717173855 THEN mean = 0.14517506404782238; std = 0.35227725561911205 ,
# ELSE IF x in play_speed >= 6.866680189143164 AND 1.5125848550168577 <= play_speed_towards_goal <= 3.85430551621531 AND play_duration <= 2.0693500000001563 THEN mean = 0.02; std = 0.13999999999999999 ,
# ELSE IF x in play_distance_towards_goal <= -1.0499999999999972 AND 0.9285019999999804 <= total_time_per_play <= 2.4040031818181804 AND play_mean_distance_to_the_goal <= 28.03256333340805 THEN mean = 0.074719800747198; std = 0.26293868510262447 ,
# ELSE mean = 0.10555843899063296std  = 0.30727163056251666

# %%
model.number_rules # returns the number of subgroups in the list
# Out:
# 107

# %%
model.rule_sets # returns a list of the index of coverage of the subgroups description (with overlap between coverages)
# Saída bem grande - Cuidado se a GUI não truncar

# %%
model.measures # returns a dictionary of subgroup discovery measure results for the rule list and subgroups
# Out:
# {'avg_supp': 684.1028037383178,
#  'kl_supp': 0.7169719667748936,
#  'wkl_supp': 432.6348434739755,
#  'avg_usg': 296.3457943925234,
#  'kl_usg': 0.6448379556807088,
#  'wkl_usg': 175.89627054846014,
#  'wacc_supp': 74.83138464708257,
#  'wacc_usg': 30.653376148302037,
#  'jacc_avg': 0.009275922562741885,
#  'n_rules': 107,
#  'avg_items': 3.0,
#  'wkl_sum': 18820.90094868523,
#  'std_rules': 0.20336728392326056,
#  'top1_std': 0.05329996277455758,
#  'length_orig': 13946.180983824217,
#  'length_final': -2038.5245487765715,
#  'length_ratio': -0.14617080841995372,
#  'runtime': 884.4460203647614}

# %% [markdown]
# ## xG

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from xgboost import XGBClassifier

# %%
# constans
RANDOM_STATE: int = 123
TEST_SIZE: float  = 0.3

shots_df_cp = shots_df.copy()

# Random Forest Classifier
rfc = RandomForestClassifier(random_state=RANDOM_STATE)
X = shots_df_cp[["bodypart_name", "shot_distance_from_goal", "shot_angle_from_goal"]]
X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
y = shots_df_cp["result_id"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)
rfc.fit(X=X_train, y=y_train)
y_pred = rfc.predict(X=X_test)
classification_report(y_test, y_pred, output_dict=True)
# Out:
# /tmp/ipykernel_19460/1970605821.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["bodypart_name"] = X["bodypart_name"].apply(lambda val: 0 if val == "foot_right" else 1 if val == "foot_left" else 2)
# {'0': {'precision': 0.9070434415858287,
#   'recall': 0.9876010286554004,
#   'f1-score': 0.9456096381304138,
#   'support': 10888.0},
#  '1': {'precision': 0.5246478873239436,
#   'recall': 0.11910471622701839,
#   'f1-score': 0.19413680781758957,
#   'support': 1251.0},
#  'accuracy': 0.8980970425899992,
#  'macro avg': {'precision': 0.7158456644548862,
#   'recall': 0.5533528724412095,
#   'f1-score': 0.5698732229740017,
#   'support': 12139.0},
#  'weighted avg': {'precision': 0.8676351840372977,
#   'recall': 0.8980970425899992,
#   'f1-score': 0.8681656550410867,
#   'support': 12139.0}}

# %%
shots_df_cp["xg"] = rfc.predict(X=X)
shots_df_cp["bodypart_name"]=pd.Categorical(shots_df_cp["bodypart_name"])
shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds", "result_id"], inplace=True, axis=1)

task_name = "discovery"
target_type = "binary"

# load class and fit to data
model = SSDC(task = task_name,max_depth=3, beam_width=25,max_rules=20,n_cutpoints=3)
model.fit(shots_df_cp)
# Out:
# /home/grad/ccomp/18/matheuspimenta/Descritivo/projeto-ad/SSDpp-numeric/src/util/_read_dataset.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1 0 2 ... 0 1 0]' has dtype incompatible with category, please explicitly cast to a compatible dtype first.
#   df.loc[:,colname] = df.loc[:,colname].cat.codes #transform this column to codes
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# Iteration: 20
# Iteration: 21
# Iteration: 22
# Iteration: 23
# Iteration: 24
# Iteration: 25
# Iteration: 26
# Iteration: 27
# Iteration: 28
# Iteration: 29
# Iteration: 30
# Iteration: 31
# Iteration: 32
# Iteration: 33
# Iteration: 34
# Iteration: 35
# Iteration: 36
# Iteration: 37
# Iteration: 38
# Iteration: 39
# Iteration: 40
# Iteration: 41
# Iteration: 42
# Iteration: 43
# Iteration: 44
# Iteration: 45
# Iteration: 46
# Iteration: 47
# Iteration: 48
# Iteration: 49
# Iteration: 50
# Iteration: 51
# Iteration: 52
# Iteration: 53
# Iteration: 54
# Iteration: 55
# Iteration: 56
# Iteration: 57
# Iteration: 58
# Iteration: 59
# Iteration: 60
# Iteration: 61
# Iteration: 62
# Iteration: 63
# Iteration: 64
# Iteration: 65
# Iteration: 66
# Iteration: 67
# Iteration: 68
# Iteration: 69
# Iteration: 70
# Iteration: 71
# Iteration: 72
# Iteration: 73
# Iteration: 74
# Iteration: 75
# Iteration: 76

# %%
model_estat = pd.DataFrame(model.statistic_rules)
df_model = pd.DataFrame(model.antecedent_description, columns=['Subgrupros'])
result_model = pd.concat([df_model, model_estat], axis=1)
result_model['WRAcc'] = (result_model['usage']/result_model['usage_default'])*((result_model['mean'])-(result_model['RSS_default_pattern']/result_model['usage_default']))
result_model
# Out:
#                                            Subgrupros  usage      mean  mean2  \
# 0   play_mean_distance_to_the_goal <= 12.248561691...     13  0.615385    0.0
# 1   play_mean_distance_to_the_goal <= 12.248561691...     17  0.411765    0.5
# 2   shot_angle_from_goal >= 0.5591113717173857 AND...    878  0.275626    0.5
# 3   start_x <= 94.5 AND shot_angle_from_goal >= 0....  20775  0.000048    0.0
# 4   shot_angle_from_goal >= 0.5591113717173857 AND...    173  0.317919    0.0
# ..                                                ...    ...       ...    ...
# 70  28.03464899379168 <= play_mean_distance_to_the...      3  0.333333    0.0
# 71  27.200000000000003 <= start_y <= 34.0 AND 4.63...     14  0.142857    0.0
# 72  play_distance_towards_goal >= 0.0 AND num_even...    196  0.005102    0.0
# 73    0.004430909090909091 <= player_rank <= 0.016025    186  0.037634    0.0
# 74  start_y <= 34.0 AND player_rank <= 0.004408223...     57  0.052632    0.0
#
#     variance2      RSS2  variance  RSS_default_pattern  usage_default  \
# 0        0.00  0.001068  0.236686             7.637203          40448
# 1        0.25  0.954851  0.242215             6.685557          40431
# 2        0.25  0.954851  0.199656           231.284264          39553
# 3        0.00  0.001068  0.000048            12.047856          18778
# 4        0.00  0.001068  0.216847            52.550430          18605
# ..        ...       ...       ...                  ...            ...
# 70       0.00  0.001068  0.222222             0.955385            629
# 71       0.00  0.001068  0.122449             1.915041            615
# 72       0.00  0.001068  0.005076             1.058449            419
# 73       0.00  0.001068  0.036218             6.775805            233
# 74       0.00  0.001068  0.049861             2.891787            176
#
#     RSS_default_uncovered     WRAcc
# 0              905.756188  0.000198
# 1              899.070631  0.000173
# 2              667.786367  0.005989
# 3              655.738511 -0.000657
# 4              603.188081  0.002930
# ..                    ...       ...
# 70              16.550198  0.001583
# 71              14.635156  0.003181
# 72              13.576708  0.001205
# 73               6.800903  0.006828
# 74               3.909117  0.011724
#
# [75 rows x 11 columns]

# %%
sorted_df = result_model.sort_values(by=['WRAcc'], ascending=False)
for sg in sorted_df["Subgrupros"].tolist():
    print(sg)
# Out:
# start_y <= 34.0 AND player_rank <= 0.004408223684210527
# play_speed >= 8.975720268508816 AND play_duration >= 2.069372000000385 AND 0.004430909090909091 <= player_rank <= 0.016025
# 0.004430909090909091 <= player_rank <= 0.016025
# shot_angle_from_goal >= 0.5591113717173857 AND num_events <= 1.0 AND start_x >= 95.55
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND play_distance >= 113.10223961707167
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND 34.68 <= start_y <= 40.8
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173
# 27.200000000000003 <= start_y <= 34.0 AND 4.639406895108031 <= play_speed <= 6.866582612367187 AND num_dribbles >= 1.0
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND play_distance_towards_goal <= -1.0499999999999972
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND ratio_distance <= 0.23419992666306966
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND player_rank <= 0.004408223684210527
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND 21.463913902175438 <= play_distance <= 51.69401161355543
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND 0.0 <= play_speed_towards_goal <= 1.512578105623291
# total_time_per_play >= 0.9285019999999804 AND 0.004430909090909091 <= player_rank <= 0.016025
# 2.069372000000385 <= play_duration <= 6.911589999999933 AND 34.68 <= start_y <= 40.8 AND player_rank >= 0.016036157894736842
# play_mean_distance_to_the_goal <= 28.03256333340805 AND num_dribbles >= 1.0 AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173
# player_rank >= 0.016036157894736842 AND play_std_distance_to_the_goal >= 15.350719150153845 AND play_mean_distance_to_the_goal <= 41.332972724918804
# 0.010288819875776397 <= player_rank <= 0.016025 AND num_passes >= 4.0 AND start_y >= 34.68
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND total_time_per_play <= 0.9284542000000329
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND total_time_per_play >= 2.404011166666654
# player_rank >= 0.010288819875776397 AND total_time_per_play <= 0.9284542000000329 AND 0.2342718553376869 <= ratio_distance <= 0.5334145947719459
# 34.68 <= start_y <= 40.8 AND play_distance_towards_goal <= -1.0499999999999972 AND 6.866680189143164 <= play_speed <= 8.97561547479651
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND play_std_distance_to_the_goal >= 15.350719150153845
# play_speed_towards_goal <= 1.512578105623291 AND play_distance_towards_goal >= 46.2 AND player_rank >= 0.016036157894736842
# 21.463913902175438 <= play_distance <= 51.69401161355543 AND 0.0 <= ratio_distance <= 0.23419992666306966 AND 0.004430909090909091 <= player_rank <= 0.016025
# 28.03464899379168 <= play_mean_distance_to_the_goal <= 41.332972724918804 AND 0.0 <= ratio_distance <= 0.5334145947719459 AND total_time_per_play <= 2.4040031818181804
# play_distance_towards_goal >= 0.0 AND num_events >= 2.0
# 2.069372000000385 <= play_duration <= 16.30900000000065 AND total_time_per_play <= 0.9284542000000329 AND play_mean_distance_to_the_goal <= 12.248561691273391
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND play_distance >= 113.10223961707167
# ratio_distance <= -0.002088480953773431 AND 4.639406895108031 <= play_speed <= 6.866582612367187 AND play_duration <= 6.911589999999933
# player_rank >= 0.016036157894736842 AND start_x <= 81.9 AND 6.866680189143164 <= play_speed <= 8.97561547479651
# bodypart_name = foot_right AND play_distance_towards_goal >= 46.2 AND 7.181128065994731 <= play_std_distance_to_the_goal <= 15.350716739940347
# player_rank >= 0.016036157894736842 AND num_events >= 7.0 AND play_mean_distance_to_the_goal <= 28.03256333340805
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND 6.866680189143164 <= play_speed <= 8.97561547479651
# play_speed_towards_goal <= -0.015112411731641373 AND play_duration >= 16.313611000000947 AND num_dribbles <= 0.0
# play_speed_towards_goal <= 1.512578105623291 AND player_rank >= 0.016036157894736842 AND 28.03464899379168 <= play_mean_distance_to_the_goal <= 41.332972724918804
# num_events >= 7.0 AND player_rank <= 0.016025
# bodypart_name = foot_left AND shot_angle_from_goal >= 0.5591113717173857 AND play_speed <= 6.866582612367187
# 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND start_y <= 27.2
# start_x <= 90.3 AND player_rank <= 0.016025
# 0.010288819875776397 <= player_rank <= 0.016025 AND 12.24944488538154 <= play_mean_distance_to_the_goal <= 28.03256333340805 AND start_y >= 34.68
# play_speed >= 8.975720268508816 AND num_events >= 4.0
# 21.463913902175438 <= play_distance <= 51.69401161355543 AND 1.5125848550168577 <= play_speed_towards_goal <= 3.85430551621531 AND bodypart_name = foot_right
# play_distance <= 21.463913902175435 AND 6.866680189143164 <= play_speed <= 8.97561547479651 AND 0.0 <= play_speed_towards_goal <= 3.85430551621531
# play_mean_distance_to_the_goal <= 12.248561691273391 AND 51.69687987997585 <= play_distance <= 113.09374128444435 AND play_speed_towards_goal <= 3.85430551621531
# 6.866680189143164 <= play_speed <= 8.97561547479651 AND player_rank <= 0.010281298299845441
# 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173 AND 0.0 <= ratio_distance <= 0.23419992666306966 AND play_distance_towards_goal >= 16.80000000000001
# player_rank >= 0.010288819875776397 AND 7.181128065994731 <= play_std_distance_to_the_goal <= 15.350716739940347 AND play_speed_towards_goal <= 3.85430551621531
# play_distance <= 51.69401161355543 AND ratio_distance >= 0.5334433957059415 AND 6.866680189143164 <= play_speed <= 8.97561547479651
# shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND 2.069372000000385 <= play_duration <= 6.911589999999933
# 21.463913902175438 <= play_distance <= 51.69401161355543 AND num_dribbles >= 1.0 AND 2.0 <= num_passes <= 3.0
# play_std_distance_to_the_goal <= 7.180606032785665 AND ratio_distance >= 0.5334433957059415 AND num_dribbles <= 0.0
# bodypart_name = foot_right AND player_rank >= 0.004430909090909091
# 12.24944488538154 <= play_mean_distance_to_the_goal <= 41.332972724918804 AND play_distance >= 113.10223961707167
# 0.3590221107608225 <= shot_angle_from_goal <= 0.5591113717173855 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441
# play_distance <= 21.463913902175435 AND play_distance_towards_goal >= 16.80000000000001 AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173
# shot_angle_from_goal <= 0.5591113717173855 AND start_x >= 91.35
# shot_distance_from_goal >= 24.89650778723795 AND start_x >= 95.55 AND play_speed >= 4.639406895108031
# play_mean_distance_to_the_goal <= 12.248561691273391 AND num_events >= 4.0
# 2.0 <= num_events <= 3.0 AND play_mean_distance_to_the_goal >= 12.24944488538154
# shot_angle_from_goal >= 0.5591113717173857 AND play_distance <= 21.463913902175435 AND num_passes >= 2.0
# start_y >= 41.48 AND play_speed_towards_goal <= 1.512578105623291 AND player_rank <= 0.004408223684210527
# start_y <= 27.2 AND play_std_distance_to_the_goal <= 15.350716739940347
# play_mean_distance_to_the_goal <= 12.248561691273391 AND num_dribbles >= 1.0 AND 16.80000000000001 <= play_distance_towards_goal <= 46.199999999999996
# bodypart_name = foot_left AND play_speed_towards_goal <= 1.512578105623291 AND start_y <= 40.8
# play_mean_distance_to_the_goal <= 12.248561691273391 AND 4.0 <= num_events <= 6.0 AND 0.010288819875776397 <= player_rank <= 0.016025
# start_x <= 81.9 AND bodypart_name = head/other
# start_x <= 81.9 AND bodypart_name = foot_right AND num_events >= 2.0
# start_x <= 94.5 AND 21.463913902175438 <= play_distance <= 113.09374128444435
# 91.35 <= start_x <= 94.5 AND 16.80000000000001 <= play_distance_towards_goal <= 46.199999999999996 AND player_rank >= 0.004430909090909091
# start_y <= 27.2 AND start_x >= 82.95
# start_y >= 41.48 AND 0.004430909090909091 <= player_rank <= 0.016025
# start_x <= 81.9 AND 12.24944488538154 <= play_mean_distance_to_the_goal <= 41.332972724918804 AND player_rank <= 0.016025
# 12.24944488538154 <= shot_distance_from_goal <= 24.886333598985605
# start_x <= 94.5 AND shot_angle_from_goal >= 0.2746754310739222

# %%
sorted_df
# Out:
#                                            Subgrupros  usage      mean  mean2  \
# 74  start_y <= 34.0 AND player_rank <= 0.004408223...     57  0.052632    0.0
# 68  play_speed >= 8.975720268508816 AND play_durat...    460  0.041304    0.0
# 73    0.004430909090909091 <= player_rank <= 0.016025    186  0.037634    0.0
# 2   shot_angle_from_goal >= 0.5591113717173857 AND...    878  0.275626    0.5
# 16  shot_angle_from_goal >= 0.5591113717173857 AND...    259  0.185328    0.0
# ..                                                ...    ...       ...    ...
# 22               start_y <= 27.2 AND start_x >= 82.95   1276  0.000784    0.0
# 20  start_y >= 41.48 AND 0.004430909090909091 <= p...   1217  0.000822    0.0
# 18  start_x <= 81.9 AND 12.24944488538154 <= play_...   2395  0.000418    0.0
# 14  12.24944488538154 <= shot_distance_from_goal <...   4448  0.000225    0.0
# 3   start_x <= 94.5 AND shot_angle_from_goal >= 0....  20775  0.000048    0.0
#
#     variance2      RSS2  variance  RSS_default_pattern  usage_default  \
# 74       0.00  0.001068  0.049861             2.891787            176
# 68       0.00  0.001068  0.039598            18.367515            793
# 73       0.00  0.001068  0.036218             6.775805            233
# 2        0.25  0.954851  0.199656           231.284264          39553
# 16       0.00  0.001068  0.150982            45.919876          12268
# ..        ...       ...       ...                  ...            ...
# 22       0.00  0.001068  0.000783             1.635180           7322
# 20       0.00  0.001068  0.000821             1.603674           8645
# 18       0.00  0.001068  0.000417             2.232738           9865
# 14       0.00  0.001068  0.000225             3.329062          12564
# 3        0.00  0.001068  0.000048            12.047856          18778
#
#     RSS_default_uncovered     WRAcc
# 74               3.909117  0.011724
# 68              19.499124  0.010524
# 73               6.800903  0.006828
# 2              667.786367  0.005989
# 16             173.463208  0.003834
# ..                    ...       ...
# 22             155.561469  0.000098
# 20             165.805792  0.000090
# 18             168.364850  0.000046
# 14             227.033104 -0.000014
# 3              655.738511 -0.000657
#
# [75 rows x 11 columns]

# %%
print(model) # returns the list of if-then-else if rules/subgroups with their respective antecedent description and consequent statistics
# Out:
# IF x in play_mean_distance_to_the_goal <= 12.248561691273391 AND num_dribbles >= 1.0 AND 16.80000000000001 <= play_distance_towards_goal <= 46.199999999999996 THEN mean = 0.6153846153846154; std = 0.48650425541051995 ,
# ELSE IF x in play_mean_distance_to_the_goal <= 12.248561691273391 AND 4.0 <= num_events <= 6.0 AND 0.010288819875776397 <= player_rank <= 0.016025 THEN mean = 0.4117647058823529; std = 0.49215295678475035 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND num_events <= 1.0 AND start_x >= 95.55 THEN mean = 0.275626423690205; std = 0.4468293838300615 ,
# ELSE IF x in start_x <= 94.5 AND shot_angle_from_goal >= 0.2746754310739222 THEN mean = 4.8134777376654636e-05; std = 0.006937756151657537 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND 0.0 <= play_speed_towards_goal <= 1.512578105623291 THEN mean = 0.3179190751445087; std = 0.4656678395635336 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND total_time_per_play >= 2.404011166666654 THEN mean = 0.28225806451612906; std = 0.4500982665282525 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND 21.463913902175438 <= play_distance <= 51.69401161355543 THEN mean = 0.28061224489795916; std = 0.4492983562303417 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND play_distance <= 21.463913902175435 AND num_passes >= 2.0 THEN mean = 0.3333333333333333; std = 0.4714045207910317 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND player_rank <= 0.004408223684210527 THEN mean = 0.26066350710900477; std = 0.43899663229988284 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND 34.68 <= start_y <= 40.8 THEN mean = 0.25475285171102663; std = 0.43572220078408475 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND play_distance_towards_goal <= -1.0499999999999972 THEN mean = 0.24324324324324326; std = 0.42904075314560924 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND 2.069372000000385 <= play_duration <= 6.911589999999933 THEN mean = 0.25; std = 0.4330127018922193 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND ratio_distance <= 0.23419992666306966 THEN mean = 0.22844827586206898; std = 0.4198328966597507 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173 THEN mean = 0.19672131147540983; std = 0.39751985747482443 ,
# ELSE IF x in 12.24944488538154 <= shot_distance_from_goal <= 24.886333598985605 THEN mean = 0.0002248201438848921; std = 0.014992318025835664 ,
# ELSE IF x in bodypart_name = foot_left AND shot_angle_from_goal >= 0.5591113717173857 AND play_speed <= 6.866582612367187 THEN mean = 0.21621621621621623; std = 0.4116634111277788 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND play_distance >= 113.10223961707167 THEN mean = 0.18532818532818532; std = 0.3885635714412084 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND start_x >= 95.55 AND play_speed >= 4.639406895108031 THEN mean = 0.375; std = 0.4841229182759271 ,
# ELSE IF x in start_x <= 81.9 AND 12.24944488538154 <= play_mean_distance_to_the_goal <= 41.332972724918804 AND player_rank <= 0.016025 THEN mean = 0.0004175365344467641; std = 0.020429444380334134 ,
# ELSE IF x in 91.35 <= start_x <= 94.5 AND 16.80000000000001 <= play_distance_towards_goal <= 46.199999999999996 AND player_rank >= 0.004430909090909091 THEN mean = 0.3333333333333333; std = 0.4714045207910317 ,
# ELSE IF x in start_y >= 41.48 AND 0.004430909090909091 <= player_rank <= 0.016025 THEN mean = 0.0008216926869350862; std = 0.028653403079971634 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_left AND play_distance >= 113.10223961707167 THEN mean = 0.19148936170212766; std = 0.3934732342320624 ,
# ELSE IF x in start_y <= 27.2 AND start_x >= 82.95 THEN mean = 0.0007836990595611285; std = 0.027983653716860638 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND total_time_per_play <= 0.9284542000000329 THEN mean = 0.1724137931034483; std = 0.37773969483114905 ,
# ELSE IF x in play_distance <= 21.463913902175435 AND play_distance_towards_goal >= 16.80000000000001 AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173 THEN mean = 0.2857142857142857; std = 0.4517539514526256 ,
# ELSE IF x in 0.3590221107608225 <= shot_angle_from_goal <= 0.5591113717173855 AND 0.004430909090909091 <= player_rank <= 0.010281298299845441 THEN mean = 0.5; std = 0.5 ,
# ELSE IF x in start_x <= 94.5 AND 21.463913902175438 <= play_distance <= 113.09374128444435 THEN mean = 0.0009216589861751152; std = 0.030344843563418097 ,
# ELSE IF x in start_x <= 81.9 AND bodypart_name = head/other THEN mean = 0.25; std = 0.4330127018922193 ,
# ELSE IF x in start_x <= 81.9 AND bodypart_name = foot_right AND num_events >= 2.0 THEN mean = 0.0014204545454545455; std = 0.03766214086239449 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND play_std_distance_to_the_goal >= 15.350719150153845 THEN mean = 0.1267605633802817; std = 0.3327045580568371 ,
# ELSE IF x in 21.463913902175438 <= play_distance <= 51.69401161355543 AND num_dribbles >= 1.0 AND 2.0 <= num_passes <= 3.0 THEN mean = 0.2857142857142857; std = 0.4517539514526256 ,
# ELSE IF x in bodypart_name = foot_left AND play_speed_towards_goal <= 1.512578105623291 AND start_y <= 40.8 THEN mean = 0.002347417840375587; std = 0.04839325851663922 ,
# ELSE IF x in start_y <= 27.2 AND play_std_distance_to_the_goal <= 15.350716739940347 THEN mean = 0.002688172043010753; std = 0.05177785022650058 ,
# ELSE IF x in 2.069372000000385 <= play_duration <= 16.30900000000065 AND total_time_per_play <= 0.9284542000000329 AND play_mean_distance_to_the_goal <= 12.248561691273391 THEN mean = 0.3125; std = 0.46351240544347894 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173857 AND bodypart_name = foot_right AND 6.866680189143164 <= play_speed <= 8.97561547479651 THEN mean = 0.10810810810810811; std = 0.31051689981286645 ,
# ELSE IF x in start_y >= 41.48 AND play_speed_towards_goal <= 1.512578105623291 AND player_rank <= 0.004408223684210527 THEN mean = 0.0026041666666666665; std = 0.05096454633015867 ,
# ELSE IF x in play_mean_distance_to_the_goal <= 12.248561691273391 AND num_events >= 4.0 THEN mean = 0.3333333333333333; std = 0.4714045207910317 ,
# ELSE IF x in play_mean_distance_to_the_goal <= 12.248561691273391 AND 51.69687987997585 <= play_distance <= 113.09374128444435 AND play_speed_towards_goal <= 3.85430551621531 THEN mean = 0.2857142857142857; std = 0.45175395145262565 ,
# ELSE IF x in ratio_distance <= -0.002088480953773431 AND 4.639406895108031 <= play_speed <= 6.866582612367187 AND play_duration <= 6.911589999999933 THEN mean = 0.13333333333333333; std = 0.33993463423951903 ,
# ELSE IF x in play_distance <= 21.463913902175435 AND 6.866680189143164 <= play_speed <= 8.97561547479651 AND 0.0 <= play_speed_towards_goal <= 3.85430551621531 THEN mean = 0.18181818181818182; std = 0.385694607919935 ,
# ELSE IF x in 2.0 <= num_events <= 3.0 AND play_mean_distance_to_the_goal >= 12.24944488538154 THEN mean = 0.0031746031746031746; std = 0.05625411157672808 ,
# ELSE IF x in 21.463913902175438 <= play_distance <= 51.69401161355543 AND 1.5125848550168577 <= play_speed_towards_goal <= 3.85430551621531 AND bodypart_name = foot_right THEN mean = 0.25; std = 0.4330127018922193 ,
# ELSE IF x in 21.463913902175438 <= play_distance <= 51.69401161355543 AND 0.0 <= ratio_distance <= 0.23419992666306966 AND 0.004430909090909091 <= player_rank <= 0.016025 THEN mean = 0.09836065573770492; std = 0.29780167417352377 ,
# ELSE IF x in shot_angle_from_goal <= 0.5591113717173855 AND start_x >= 91.35 THEN mean = 0.0035587188612099642; std = 0.05954875633694484 ,
# ELSE IF x in player_rank >= 0.016036157894736842 AND num_events >= 7.0 AND play_mean_distance_to_the_goal <= 28.03256333340805 THEN mean = 0.14285714285714285; std = 0.3499271061118826 ,
# ELSE IF x in bodypart_name = foot_right AND play_distance_towards_goal >= 46.2 AND 7.181128065994731 <= play_std_distance_to_the_goal <= 15.350716739940347 THEN mean = 0.14285714285714285; std = 0.3499271061118826 ,
# ELSE IF x in player_rank >= 0.016036157894736842 AND play_std_distance_to_the_goal >= 15.350719150153845 AND play_mean_distance_to_the_goal <= 41.332972724918804 THEN mean = 0.1038961038961039; std = 0.30512571751872025 ,
# ELSE IF x in 12.24944488538154 <= play_mean_distance_to_the_goal <= 41.332972724918804 AND play_distance >= 113.10223961707167 THEN mean = 0.0033783783783783786; std = 0.05802555418012727 ,
# ELSE IF x in bodypart_name = foot_right AND player_rank >= 0.004430909090909091 THEN mean = 0.0038314176245210726; std = 0.061779752860525255 ,
# ELSE IF x in play_speed_towards_goal <= 1.512578105623291 AND player_rank >= 0.016036157894736842 AND 28.03464899379168 <= play_mean_distance_to_the_goal <= 41.332972724918804 THEN mean = 0.2222222222222222; std = 0.41573970964154905 ,
# ELSE IF x in 34.68 <= start_y <= 40.8 AND play_distance_towards_goal <= -1.0499999999999972 AND 6.866680189143164 <= play_speed <= 8.97561547479651 THEN mean = 0.10204081632653061; std = 0.30270197906512913 ,
# ELSE IF x in play_std_distance_to_the_goal <= 7.180606032785665 AND ratio_distance >= 0.5334433957059415 AND num_dribbles <= 0.0 THEN mean = 0.00392156862745098; std = 0.0624995194137617 ,
# ELSE IF x in play_distance <= 51.69401161355543 AND ratio_distance >= 0.5334433957059415 AND 6.866680189143164 <= play_speed <= 8.97561547479651 THEN mean = 0.3333333333333333; std = 0.4714045207910317 ,
# ELSE IF x in 2.069372000000385 <= play_duration <= 6.911589999999933 AND 34.68 <= start_y <= 40.8 AND player_rank >= 0.016036157894736842 THEN mean = 0.08108108108108109; std = 0.27295959292870475 ,
# ELSE IF x in player_rank >= 0.010288819875776397 AND 7.181128065994731 <= play_std_distance_to_the_goal <= 15.350716739940347 AND play_speed_towards_goal <= 3.85430551621531 THEN mean = 0.004132231404958678; std = 0.06414948221595053 ,
# ELSE IF x in player_rank >= 0.016036157894736842 AND start_x <= 81.9 AND 6.866680189143164 <= play_speed <= 8.97561547479651 THEN mean = 0.2; std = 0.4000000000000001 ,
# ELSE IF x in 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173 AND 0.0 <= ratio_distance <= 0.23419992666306966 AND play_distance_towards_goal >= 16.80000000000001 THEN mean = 0.3333333333333333; std = 0.4714045207910317 ,
# ELSE IF x in play_mean_distance_to_the_goal <= 28.03256333340805 AND num_dribbles >= 1.0 AND 0.9285019999999804 <= total_time_per_play <= 1.7608733333333173 THEN mean = 0.10416666666666667; std = 0.30547663122114954 ,
# ELSE IF x in 6.866680189143164 <= play_speed <= 8.97561547479651 AND player_rank <= 0.010281298299845441 THEN mean = 0.004901960784313725; std = 0.0698421904351716 ,
# ELSE IF x in play_speed_towards_goal <= 1.512578105623291 AND play_distance_towards_goal >= 46.2 AND player_rank >= 0.016036157894736842 THEN mean = 0.125; std = 0.33071891388307384 ,
# ELSE IF x in play_speed >= 8.975720268508816 AND num_events >= 4.0 THEN mean = 0.005494505494505495; std = 0.07392101124765775 ,
# ELSE IF x in 0.010288819875776397 <= player_rank <= 0.016025 AND 12.24944488538154 <= play_mean_distance_to_the_goal <= 28.03256333340805 AND start_y >= 34.68 THEN mean = 0.25; std = 0.4330127018922193 ,
# ELSE IF x in player_rank >= 0.010288819875776397 AND total_time_per_play <= 0.9284542000000329 AND 0.2342718553376869 <= ratio_distance <= 0.5334145947719459 THEN mean = 0.08333333333333333; std = 0.27638539919628335 ,
# ELSE IF x in 0.004430909090909091 <= player_rank <= 0.010281298299845441 AND start_y <= 27.2 THEN mean = 0.25; std = 0.4330127018922193 ,
# ELSE IF x in start_x <= 90.3 AND player_rank <= 0.016025 THEN mean = 0.006289308176100629; std = 0.07905537792438068 ,
# ELSE IF x in 0.010288819875776397 <= player_rank <= 0.016025 AND num_passes >= 4.0 AND start_y >= 34.68 THEN mean = 0.07692307692307693; std = 0.26646935501059654 ,
# ELSE IF x in num_events >= 7.0 AND player_rank <= 0.016025 THEN mean = 0.00819672131147541; std = 0.09016393442622951 ,
# ELSE IF x in play_speed_towards_goal <= -0.015112411731641373 AND play_duration >= 16.313611000000947 AND num_dribbles <= 0.0 THEN mean = 0.16666666666666666; std = 0.372677996249965 ,
# ELSE IF x in play_speed >= 8.975720268508816 AND play_duration >= 2.069372000000385 AND 0.004430909090909091 <= player_rank <= 0.016025 THEN mean = 0.041304347826086954; std = 0.19899321263990027 ,
# ELSE IF x in total_time_per_play >= 0.9285019999999804 AND 0.004430909090909091 <= player_rank <= 0.016025 THEN mean = 0.012422360248447204; std = 0.07881104062391006 ,
# ELSE IF x in 28.03464899379168 <= play_mean_distance_to_the_goal <= 41.332972724918804 AND 0.0 <= ratio_distance <= 0.5334145947719459 AND total_time_per_play <= 2.4040031818181804 THEN mean = 0.3333333333333333; std = 0.4714045207910317 ,
# ELSE IF x in 27.200000000000003 <= start_y <= 34.0 AND 4.639406895108031 <= play_speed <= 6.866582612367187 AND num_dribbles >= 1.0 THEN mean = 0.14285714285714285; std = 0.34992710611188266 ,
# ELSE IF x in play_distance_towards_goal >= 0.0 AND num_events >= 2.0 THEN mean = 0.00510204081632653; std = 0.07124612267229052 ,
# ELSE IF x in 0.004430909090909091 <= player_rank <= 0.016025 THEN mean = 0.03763440860215054; std = 0.19031043032718128 ,
# ELSE IF x in start_y <= 34.0 AND player_rank <= 0.004408223684210527 THEN mean = 0.05263157894736842; std = 0.2232968782694361 ,
# ELSE mean = 0.023108672548874224std  = 0.1502486665560987

# %%
model.measures # returns a dictionary of subgroup discovery measure results for the rule list and subgroups
# Out:
# {'avg_supp': 3682.4266666666667,
#  'kl_supp': 1.966790483388603,
#  'wkl_supp': 4617.175197078464,
#  'avg_usg': 537.1333333333333,
#  'kl_usg': 3.7084867126734693,
#  'wkl_usg': 1639.4285734560622,
#  'wacc_supp': 73.65881779161828,
#  'wacc_usg': 21.421526902449273,
#  'jacc_avg': 0.027238584748455048,
#  'n_rules': 75,
#  'avg_items': 2.68,
#  'wkl_sum': 122957.14300920462,
#  'std_rules': 0.29333622266514464,
#  'top1_std': 0.48650425541051995,
#  'length_orig': -27816.141328954418,
#  'length_final': -149145.16585375989,
#  'length_ratio': 0.18650380768109345,
#  'runtime': 203.72930884361267}

# %% [markdown]
# ## VAEP

# %%
from tqdm import tqdm
import socceraction.spadl as spd
from socceraction.vaep import features as ft
import socceraction.vaep.labels as lab
import socceraction.vaep.formula as fm
import xgboost as xgb
import sklearn.metrics as mt

# %%
def features_transform(spadl):
    spadl.loc[spadl.result_id.isin([2, 3]), ["result_id"]] = 0
    spadl.loc[spadl.result_name.isin(["offside", "owngoal"]), ["result_name"]] = "fail"

    xfns = [
        ft.actiontype_onehot,
        ft.bodypart_onehot,
        ft.result_onehot,
        ft.goalscore,
        ft.startlocation,
        ft.endlocation,
        ft.team,
        ft.time,
        ft.time_delta
    ]

    features = []
    for game in tqdm(np.unique(spadl.game_id).tolist()):
        match_actions = spadl.loc[spadl.game_id == game].reset_index(drop=True)
        match_states = ft.gamestates(actions=match_actions)
        match_feats = pd.concat([fn(match_states) for fn in xfns], axis=1)
        features.append(match_feats)
    features = pd.concat(features).reset_index(drop=True)

    return features

def labels_transform(spadl):
    yfns = [lab.scores, lab.concedes]

    labels = []
    for game in tqdm(np.unique(spadl.game_id).tolist()):
        match_actions = spadl.loc[spadl.game_id == game].reset_index(drop=True)
        labels.append(pd.concat([fn(actions=match_actions) for fn in yfns], axis=1))

    labels = pd.concat(labels).reset_index(drop=True)

    return labels

def train_vaep(X_train, y_train, X_test, y_test):
    models = {}
    for m in ["scores", "concedes"]:
        models[m] = xgb.XGBClassifier(random_state=0, n_estimators=50, max_depth=3)

        print("training " + m + " model")
        models[m].fit(X_train, y_train[m])

        p = sum(y_train[m]) / len(y_train[m])
        base = [p] * len(y_train[m])
        y_train_pred = models[m].predict_proba(X_train)[:, 1]
        train_brier = mt.brier_score_loss(y_train[m], y_train_pred) / mt.brier_score_loss(y_train[m], base)
        print(m + " Train NBS: " + str(train_brier))
        print()

        p = sum(y_test[m]) / len(y_test[m])
        base = [p] * len(y_test[m])
        y_test_pred = models[m].predict_proba(X_test)[:, 1]
        test_brier = mt.brier_score_loss(y_test[m], y_test_pred) / mt.brier_score_loss(y_test[m], base)
        print(m + " Test NBS: " + str(test_brier))
        print()

        print("----------------------------------------")

    return models

def generate_predictions(features, models):
    preds = {}
    for m in ["scores", "concedes"]:
        preds[m] = models[m].predict_proba(features)[:, 1]
    preds = pd.DataFrame(preds)

    return preds

def calculate_action_values(spadl, predictions):
    action_values = fm.value(actions=spadl, Pscores=predictions["scores"], Pconcedes=predictions["concedes"])
    action_values = pd.concat([
        spadl[["original_event_id", "player_id", "action_id", "game_id", "start_x", "start_y", "end_x", "end_y", "type_name", "result_name"]],
        predictions.rename(columns={"scores": "Pscores", "concedes": "Pconcedes"}),
        action_values
    ], axis=1)

    return action_values

# %%
spadl = {}
for league in LEAGUES:
    spadl[league] = pd.read_csv(f"../data/spadl_format/{league}.csv")

features = {}
for league in LEAGUES:
    features[league] = features_transform(spadl[league])

labels = {}
for league in LEAGUES:
    labels[league] = labels_transform(spadl[league])

models = train_vaep(X_train=features["England"], y_train=labels["England"], X_test=features["Spain"], y_test=labels["Spain"])
# Out:
# 100%|██████████| 380/380 [00:06<00:00, 61.42it/s]
# 100%|██████████| 380/380 [00:06<00:00, 62.72it/s]
# 100%|██████████| 380/380 [00:06<00:00, 62.87it/s]
# 100%|██████████| 380/380 [00:06<00:00, 61.77it/s]
# 100%|██████████| 306/306 [00:04<00:00, 61.64it/s]
# 100%|██████████| 380/380 [00:07<00:00, 54.04it/s]
# 100%|██████████| 380/380 [00:07<00:00, 53.59it/s]
# 100%|██████████| 380/380 [00:07<00:00, 53.33it/s]
# 100%|██████████| 380/380 [00:07<00:00, 53.64it/s]
# 100%|██████████| 306/306 [00:05<00:00, 52.97it/s]
# training scores model
# scores Train NBS: 0.8452471194228581
#
# scores Test NBS: 0.8503677630926355
#
# ----------------------------------------
# training concedes model
# concedes Train NBS: 0.9660641623881886
#
# concedes Test NBS: 0.9766251611701147
#
# ----------------------------------------

# %%
preds = {}
action_values = {}

for league in LEAGUES:
    preds[league] = generate_predictions(features=features[league], models=models)
    action_values[league] = calculate_action_values(spadl=spadl[league], predictions=preds[league])

all_action_values = pd.concat([df for df in action_values.values()])

# %%
shots_df_cp = shots_df.copy()
all_action_values_cp = all_action_values.copy()
all_action_values_cp.drop(["original_event_id", "result_name", "action_id", "type_name"], inplace=True, axis=1)

shots_df_cp = shots_df_cp.merge(all_action_values_cp, on=['game_id', 'player_id', 'start_x', 'start_y'], how='left')

# %%
shots_df_cp
# Out:
#        game_id  period_id  team_id  player_id  time_seconds  start_x  start_y  \
# 0      2499719          1     1609      25413     94.595788    92.40    40.12
# 1      2499719          1     1631      26150    179.854785    89.25    32.64
# 2      2499719          1     1631      14763    254.745027   100.80    32.64
# 3      2499719          1     1609       7868    425.824035    85.05    45.56
# 4      2499719          1     1609       7868    815.462015    78.75    47.60
# ...        ...        ...      ...        ...           ...      ...      ...
# 40778  2576338          2     3193     116269   1152.032980    99.75    37.40
# 40779  2576338          2     3193       3548   1251.730517    97.65    42.16
# 40780  2576338          2     3193      21177   2065.034482    94.50    36.72
# 40781  2576338          2     3193     349102   2367.252041    82.95    46.24
# 40782  2576338          2     3193      21177   2579.867806    97.65    38.76
#
#        num_events  num_passes  num_dribbles  ...  shot_distance_from_goal  \
# 0               7           4             0  ...                14.007655
# 1               2           0             0  ...                15.808608
# 2               7           3             0  ...                 4.414703
# 3               6           3             1  ...                23.057235
# 4               1           0             0  ...                29.563872
# ...           ...         ...           ...  ...                      ...
# 40778           9           5             2  ...                 6.254798
# 40779          20          16             2  ...                10.982172
# 40780           1           0             0  ...                10.846585
# 40781           3           2             0  ...                25.219439
# 40782           5           3             0  ...                 8.756717
#
#        shot_angle_from_goal result_id  end_x    end_y   Pscores  Pconcedes  \
# 0                  0.509981         1  105.0  37.4000  0.978135   0.002137
# 1                  0.494098         0  105.0  40.8000  0.018184   0.007322
# 2                  1.467310         1  105.0  34.0000  0.977107   0.002290
# 3                  0.300168         0  105.0  40.8000  0.021434   0.002819
# 4                  0.240030         0  105.0  37.4000  0.017245   0.005117
# ...                     ...       ...    ...      ...       ...        ...
# 40778              1.067542         0  105.0  40.8000  0.034776   0.009745
# 40779              0.512084         0  105.0  40.8000  0.029877   0.010725
# 40780              0.690619         1  105.0  34.0000  0.977372   0.007182
# 40781              0.277183         0  105.0  40.8000  0.015293   0.006782
# 40782              0.769664         0  105.0  30.3416  0.046821   0.008009
#
#        offensive_value  defensive_value  vaep_value
# 0             0.902766        -0.000387    0.902379
# 1            -0.020396        -0.003519   -0.023916
# 2             0.885530         0.000666    0.886196
# 3            -0.004685        -0.001744   -0.006429
# 4            -0.019283        -0.002159   -0.021442
# ...                ...              ...         ...
# 40778        -0.081321        -0.004355   -0.085676
# 40779        -0.052057        -0.005569   -0.057625
# 40780         0.950002        -0.002297    0.947704
# 40781        -0.020930        -0.003574   -0.024504
# 40782        -0.062798        -0.004205   -0.067003
#
# [40783 rows x 31 columns]

# %%
task_name = "discovery"
target_type = "numeric"
shots_df_cp.drop(["Pconcedes", "offensive_value", "defensive_value", "vaep_value", "end_x", "end_y"], inplace=True, axis=1)
shots_df_cp.drop(["game_id", "period_id", "team_id", "player_id", "time_seconds"], inplace=True, axis=1)
shots_df_cp["bodypart_name"]=pd.Categorical(shots_df_cp["bodypart_name"])


# load class and fit to data
model = SSDC(task = task_name,max_depth=3, beam_width=25,max_rules=20,n_cutpoints=3)
model.fit(shots_df_cp)
# Out:
# /home/grad/ccomp/18/matheuspimenta/Descritivo/projeto-ad/SSDpp-numeric/src/util/_read_dataset.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1 0 2 ... 0 1 0]' has dtype incompatible with category, please explicitly cast to a compatible dtype first.
#   df.loc[:,colname] = df.loc[:,colname].cat.codes #transform this column to codes
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# Iteration: 20
# Iteration: 21
# Iteration: 22
# Iteration: 23
# Iteration: 24
# Iteration: 25
# Iteration: 26
# Iteration: 27
# Iteration: 28
# Iteration: 29
# Iteration: 30
# Iteration: 31
# Iteration: 32
# Iteration: 33
# Iteration: 34
# Iteration: 35
# Iteration: 36
# Iteration: 37
# Iteration: 38
# Iteration: 39
# Iteration: 40
# Iteration: 41
# Iteration: 42
# Iteration: 43
# Iteration: 44
# Iteration: 45
# Iteration: 46
# Iteration: 47
# Iteration: 48
# Iteration: 49
# Iteration: 50
# Iteration: 51
# Iteration: 52
# Iteration: 53
# Iteration: 54
# Iteration: 55
# Iteration: 56
# Iteration: 57
# Iteration: 58
# Iteration: 59
# Iteration: 60
# Iteration: 61
# Iteration: 62
# Iteration: 63
# Iteration: 64
# Iteration: 65
# Iteration: 66
# Iteration: 67
# Iteration: 68
# Iteration: 69
# Iteration: 70
# Iteration: 71
# Iteration: 72
# Iteration: 73
# Iteration: 74
# Iteration: 75
# Iteration: 76
# Iteration: 77
# Iteration: 78
# Iteration: 79
# Iteration: 80
# Iteration: 81
# Iteration: 82
# Iteration: 83
# Iteration: 84
# Iteration: 85
# Iteration: 86
# Iteration: 87
# Iteration: 88
# Iteration: 89
# Iteration: 90
# Iteration: 91
# Iteration: 92
# Iteration: 93
# Iteration: 94
# Iteration: 95
# Iteration: 96
# Iteration: 97
# Iteration: 98
# Iteration: 99
# Iteration: 100
# Iteration: 101
# Iteration: 102
# Iteration: 103
# Iteration: 104
# Iteration: 105
# Iteration: 106
# Iteration: 107
# Iteration: 108
# Iteration: 109
# Iteration: 110
# Iteration: 111
# Iteration: 112
# Iteration: 113
# Iteration: 114
# Iteration: 115
# Iteration: 116
# Iteration: 117
# Iteration: 118
# Iteration: 119
# Iteration: 120
# Iteration: 121
# Iteration: 122
# Iteration: 123
# Iteration: 124
# Iteration: 125
# Iteration: 126
# Iteration: 127
# Iteration: 128
# Iteration: 129
# Iteration: 130
# Iteration: 131
# Iteration: 132
# Iteration: 133
# Iteration: 134
# Iteration: 135
# Iteration: 136
# Iteration: 137
# Iteration: 138
# Iteration: 139
# Iteration: 140
# Iteration: 141
# Iteration: 142
# Iteration: 143
# Iteration: 144

# %%
model_estat = pd.DataFrame(model.statistic_rules)
df_model = pd.DataFrame(model.antecedent_description, columns=['Subgrupros'])
result_model = pd.concat([df_model, model_estat], axis=1)
result_model['WRAcc'] = (result_model['usage']/result_model['usage_default'])*((result_model['mean'])-(result_model['RSS_default_pattern']/result_model['usage_default']))
result_model
# Out:
#                                             Subgrupros  usage      mean  \
# 0    shot_distance_from_goal >= 24.89650778723795 A...    100  0.014956
# 1    shot_distance_from_goal >= 24.89650778723795 A...     74  0.014970
# 2    shot_angle_from_goal <= 0.27450461081080996 AN...     85  0.013576
# 3    shot_distance_from_goal >= 24.89650778723795 A...     48  0.016209
# 4    shot_distance_from_goal >= 24.89650778723795 A...     27  0.014927
# ..                                                 ...    ...       ...
# 138  ratio_distance <= 0.23457108157942888 AND 2.07...    603  0.085151
# 139  shot_angle_from_goal <= 0.27450461081080996 AN...     14  0.012783
# 140  shot_angle_from_goal <= 0.27450461081080996 AN...    354  0.077358
# 141  0.3587982134468687 <= shot_angle_from_goal <= ...   1110  0.174933
# 142  shot_distance_from_goal >= 12.24944488538154 A...   1535  0.100125
#
#         mean2     variance2      RSS2  variance  RSS_default_pattern  \
# 0    0.027534  3.477994e-06  0.019096  0.000028             1.215711
# 1    0.027373  9.964049e-09  0.019152  0.000026             0.895103
# 2    0.045727  1.778339e-04  0.012997  0.000046             1.059123
# 3    0.035898  7.335277e-06  0.015976  0.000064             0.565919
# 4    0.025123  4.719439e-07  0.020044  0.000024             0.325194
# ..        ...           ...       ...       ...                  ...
# 138  0.068333  5.502902e-06  0.006486  0.050806            31.597913
# 139  0.019572  4.873330e-07  0.022328  0.000024             0.176838
# 140  0.092632  1.613054e-04  0.002448  0.046143            17.134647
# 141  0.074366  8.518305e-05  0.005345  0.114926           130.317752
# 142  0.080905  2.598926e-05  0.003982  0.065588           101.638801
#
#      usage_default  RSS_default_uncovered     WRAcc
# 0            40683            3491.705836  0.000037
# 1            40609            3490.804467  0.000027
# 2            40524            3489.741252  0.000028
# 3            40476            3489.168383  0.000019
# 4            40449            3488.839404  0.000010
# ..             ...                    ...       ...
# 138          10687             901.767381  0.004638
# 139          10673             901.590046  0.000017
# 140          10319             884.440992  0.002597
# 141           9209             754.111331  0.019380
# 142           7674             652.453762  0.017378
#
# [143 rows x 11 columns]

# %%
sorted_df = result_model.sort_values(by=['WRAcc'], ascending=False)
for sg in sorted_df["Subgrupros"].tolist():
    print(sg)
# Out:
# 0.3587982134468687 <= shot_angle_from_goal <= 0.5565136053620864 AND 0.01028948787061995 <= player_rank <= 0.016036157894736842 AND start_x >= 91.35
# shot_distance_from_goal >= 12.24944488538154 AND ratio_distance <= 0.23457108157942888 AND start_y <= 34.0
# shot_angle_from_goal >= 0.5591113717173855 AND bodypart_name = foot_right AND start_x >= 95.55
# shot_angle_from_goal >= 0.5591113717173855 AND total_time_per_play <= 1.7631443333333057 AND 0.004435614702154626 <= player_rank <= 0.016036157894736842
# shot_distance_from_goal <= 17.09952046111235 AND player_rank >= 0.01604481397970688 AND num_dribbles >= 1.0
# 0.3587982134468687 <= shot_angle_from_goal <= 0.5565136053620864 AND player_rank >= 0.01604481397970688 AND play_std_distance_to_the_goal <= 7.195667700015349
# shot_angle_from_goal >= 0.5591113717173855 AND bodypart_name = foot_left AND start_x >= 95.55
# start_x >= 91.35 AND 27.200000000000003 <= start_y <= 40.8 AND play_std_distance_to_the_goal >= 15.352753779569
# shot_angle_from_goal >= 0.5591113717173855 AND play_speed_towards_goal >= 1.5151898195672555 AND 12.389116336130769 <= play_mean_distance_to_the_goal <= 28.086885352488757
# play_speed_towards_goal >= 3.856313999035368 AND 27.200000000000003 <= start_y <= 34.0 AND 12.24944488538154 <= shot_distance_from_goal <= 17.09952046111235
# shot_distance_from_goal <= 12.239999999999995 AND play_std_distance_to_the_goal >= 15.352753779569 AND total_time_per_play <= 2.4047902592592605
# shot_angle_from_goal >= 0.5591113717173855 AND num_events <= 1.0 AND start_x >= 95.55
# 34.68 <= start_y <= 40.8 AND start_x >= 95.55 AND num_events <= 1.0
# ratio_distance <= 0.23457108157942888 AND 2.0765519999999924 <= play_duration <= 6.9251429999999345 AND 82.95 <= start_x <= 94.5
# shot_distance_from_goal <= 12.239999999999995 AND total_time_per_play <= 0.9302880000000187 AND 0.01028948787061995 <= player_rank <= 0.016036157894736842
# shot_distance_from_goal <= 12.239999999999995 AND player_rank >= 0.01604481397970688 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004
# shot_distance_from_goal <= 12.239999999999995 AND bodypart_name = foot_right AND 27.200000000000003 <= start_y <= 34.0
# 12.24944488538154 <= shot_distance_from_goal <= 17.09952046111235 AND bodypart_name = head/other AND start_y >= 27.200000000000003
# shot_angle_from_goal >= 0.5591113717173855 AND 0.0 <= ratio_distance <= 0.23457108157942888 AND play_mean_distance_to_the_goal >= 41.36508436005718
# start_x >= 95.55 AND 34.68 <= start_y <= 40.8 AND player_rank >= 0.01604481397970688
# shot_angle_from_goal <= 0.27450461081080996 AND total_time_per_play >= 1.763152249999962 AND play_speed_towards_goal >= 3.856313999035368
# shot_angle_from_goal >= 0.5591113717173855 AND bodypart_name = foot_left AND 0.004435614702154626 <= player_rank <= 0.010288819875776397
# 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND player_rank <= 0.004430909090909091 AND 12.389116336130769 <= play_mean_distance_to_the_goal <= 28.086885352488757
# start_x <= 90.3 AND 51.77083735077114 <= play_distance <= 113.15070408910965 AND 0.234646057969521 <= ratio_distance <= 0.5339473149855147
# 82.95 <= start_x <= 90.3 AND 0.2746029401357196 <= shot_angle_from_goal <= 0.3587982134468684 AND num_events >= 7.0
# shot_angle_from_goal >= 0.5591113717173855 AND play_std_distance_to_the_goal >= 15.352753779569 AND total_time_per_play <= 1.7631443333333057
# num_events <= 1.0 AND 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND bodypart_name = foot_right
# 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND num_dribbles >= 1.0 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397
# shot_angle_from_goal <= 0.3587982134468684 AND 82.95 <= start_x <= 90.3 AND play_speed <= 4.641349632294605
# shot_distance_from_goal >= 17.1236941107928 AND play_duration >= 6.92674500000021 AND num_events <= 3.0
# start_x <= 81.9 AND 4.641377505446126 <= play_speed <= 6.864853427180291 AND num_passes >= 4.0
# shot_angle_from_goal <= 0.27450461081080996 AND bodypart_name = foot_right AND 21.494334137162753 <= play_distance <= 51.76966761281916
# shot_angle_from_goal <= 0.27450461081080996 AND player_rank <= 0.004430909090909091 AND bodypart_name = foot_left
# bodypart_name = head/other AND 82.95 <= start_x <= 94.5 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397
# 82.95 <= start_x <= 90.3 AND start_y >= 41.48 AND 21.494334137162753 <= play_distance <= 51.76966761281916
# start_x <= 81.9 AND play_mean_distance_to_the_goal <= 12.36283043185764 AND player_rank <= 0.004430909090909091
# shot_distance_from_goal >= 24.89650778723795 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND play_mean_distance_to_the_goal <= 28.086885352488757
# shot_distance_from_goal >= 17.1236941107928 AND ratio_distance <= -0.002088480953773431 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397
# start_x <= 81.9 AND 0.0 <= play_speed_towards_goal <= 1.5145461337964412 AND start_y >= 41.48
# 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND play_distance >= 113.16162197606944
# 0.2746029401357196 <= shot_angle_from_goal <= 0.3587982134468684 AND play_mean_distance_to_the_goal <= 12.36283043185764 AND player_rank >= 0.01604481397970688
# bodypart_name = head/other AND 12.24944488538154 <= shot_distance_from_goal <= 17.09952046111235 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004
# shot_angle_from_goal <= 0.27450461081080996 AND num_events <= 1.0 AND start_y <= 40.8
# shot_distance_from_goal >= 17.1236941107928 AND 7.196612429896831 <= play_std_distance_to_the_goal <= 15.350719150153845 AND play_mean_distance_to_the_goal <= 28.086885352488757
# shot_angle_from_goal <= 0.27450461081080996 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND play_mean_distance_to_the_goal >= 41.36508436005718
# shot_distance_from_goal >= 24.89650778723795 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND 1.5151898195672555 <= play_speed_towards_goal <= 3.8559805229649715
# shot_angle_from_goal <= 0.27450461081080996 AND play_distance_towards_goal <= 46.199999999999996 AND play_std_distance_to_the_goal >= 15.352753779569
# bodypart_name = head/other AND 12.24944488538154 <= shot_distance_from_goal <= 17.09952046111235 AND player_rank <= 0.004430909090909091
# bodypart_name = head/other AND 91.35 <= start_x <= 94.5 AND num_passes >= 2.0
# shot_angle_from_goal <= 0.27450461081080996 AND 2.0765519999999924 <= play_duration <= 6.9251429999999345 AND 1.5151898195672555 <= play_speed_towards_goal <= 3.8559805229649715
# play_speed_towards_goal <= -0.015112411731641373 AND 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND 6.864962518632317 <= play_speed <= 8.97107615188608
# shot_distance_from_goal >= 24.89650778723795 AND 4.641377505446126 <= play_speed <= 6.864853427180291 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004
# start_x <= 81.9 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND 1.763152249999962 <= total_time_per_play <= 2.4047902592592605
# player_rank <= 0.004430909090909091 AND shot_distance_from_goal >= 24.89650778723795 AND 0.234646057969521 <= ratio_distance <= 0.5339473149855147
# start_x <= 81.9 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND play_distance <= 51.76966761281916
# shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND 0.01028948787061995 <= player_rank <= 0.016036157894736842
# start_x <= 81.9 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND play_std_distance_to_the_goal >= 15.352753779569
# shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004
# shot_distance_from_goal >= 24.89650778723795 AND play_std_distance_to_the_goal >= 15.352753779569 AND 2.0 <= num_passes <= 3.0
# shot_angle_from_goal <= 0.27450461081080996 AND num_events <= 1.0 AND 82.95 <= start_x <= 90.3
# shot_distance_from_goal >= 24.89650778723795 AND 21.494334137162753 <= play_distance <= 51.76966761281916 AND 7.196612429896831 <= play_std_distance_to_the_goal <= 15.350719150153845
# shot_distance_from_goal >= 24.89650778723795 AND player_rank <= 0.004430909090909091 AND 12.389116336130769 <= play_mean_distance_to_the_goal <= 28.086885352488757
# shot_distance_from_goal >= 24.89650778723795 AND ratio_distance <= 0.23457108157942888 AND play_distance_towards_goal >= 46.2
# shot_distance_from_goal >= 24.89650778723795 AND 82.95 <= start_x <= 90.3 AND 2.0 <= num_passes <= 3.0
# shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND play_distance <= 113.15070408910965
# start_y <= 27.2 AND play_distance_towards_goal <= -1.0499999999999972 AND play_speed <= 4.641349632294605
# 27.200000000000003 <= start_y <= 34.0 AND shot_angle_from_goal <= 0.27450461081080996 AND play_speed <= 4.641349632294605
# play_speed <= 4.641349632294605 AND shot_angle_from_goal <= 0.27450461081080996 AND 7.196612429896831 <= play_std_distance_to_the_goal <= 15.350719150153845
# shot_distance_from_goal >= 24.89650778723795 AND 12.389116336130769 <= play_mean_distance_to_the_goal <= 28.086885352488757 AND 0.0 <= play_speed_towards_goal <= 1.5145461337964412
# play_distance_towards_goal <= -1.0499999999999972 AND 28.095041593726133 <= play_mean_distance_to_the_goal <= 41.36396470801768 AND shot_angle_from_goal >= 0.3587982134468687
# start_x <= 81.9 AND play_distance <= 21.49433413716275 AND play_speed >= 8.971750141469606
# bodypart_name = head/other AND shot_distance_from_goal >= 12.24944488538154 AND num_events <= 1.0
# 82.95 <= start_x <= 90.3 AND bodypart_name = head/other AND 2.0765519999999924 <= play_duration <= 16.322411999999986
# ratio_distance <= 0.23457108157942888 AND 2.0 <= num_events <= 3.0 AND 6.92674500000021 <= play_duration <= 16.322411999999986
# 0.2746029401357196 <= shot_angle_from_goal <= 0.3587982134468684 AND play_duration <= 2.076061999999638 AND 6.864962518632317 <= play_speed <= 8.97107615188608
# shot_angle_from_goal <= 0.27450461081080996 AND 21.494334137162753 <= play_distance <= 51.76966761281916 AND total_time_per_play >= 2.404795999999957
# shot_distance_from_goal >= 24.89650778723795 AND play_speed >= 8.971750141469606 AND 0.234646057969521 <= ratio_distance <= 0.5339473149855147
# total_time_per_play <= 1.7631443333333057 AND shot_angle_from_goal >= 0.5591113717173855 AND start_y <= 27.2
# shot_distance_from_goal >= 24.89650778723795 AND 4.641377505446126 <= play_speed <= 6.864853427180291 AND play_mean_distance_to_the_goal <= 28.086885352488757
# play_speed_towards_goal <= -0.015112411731641373 AND 28.095041593726133 <= play_mean_distance_to_the_goal <= 41.36396470801768 AND play_distance >= 113.16162197606944
# play_speed <= 4.641349632294605 AND start_x <= 81.9 AND num_events >= 7.0
# shot_angle_from_goal <= 0.3587982134468684 AND player_rank <= 0.010288819875776397 AND bodypart_name = head/other
# shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND ratio_distance >= 0.5339754270167693
# shot_distance_from_goal >= 24.89650778723795 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND play_mean_distance_to_the_goal <= 28.086885352488757
# total_time_per_play <= 1.7631443333333057 AND shot_distance_from_goal <= 12.239999999999995 AND play_distance_towards_goal >= 46.2
# shot_distance_from_goal >= 24.89650778723795 AND play_std_distance_to_the_goal >= 15.352753779569 AND total_time_per_play <= 1.7631443333333057
# shot_angle_from_goal <= 0.3587982134468684 AND play_mean_distance_to_the_goal <= 12.36283043185764 AND play_duration >= 2.0765519999999924
# shot_distance_from_goal >= 24.89650778723795 AND 21.494334137162753 <= play_distance <= 51.76966761281916 AND total_time_per_play <= 0.9302880000000187
# start_x <= 81.9 AND 27.200000000000003 <= start_y <= 34.0 AND play_speed >= 8.971750141469606
# ratio_distance <= -0.002088480953773431 AND 1.763152249999962 <= total_time_per_play <= 2.4047902592592605 AND play_speed <= 4.641349632294605
# 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND num_dribbles >= 1.0 AND total_time_per_play <= 0.9302880000000187
# shot_angle_from_goal <= 0.27450461081080996 AND play_mean_distance_to_the_goal <= 12.36283043185764 AND play_speed >= 4.641377505446126
# shot_distance_from_goal <= 12.239999999999995 AND 0.01028948787061995 <= player_rank <= 0.016036157894736842 AND play_distance <= 21.49433413716275
# shot_angle_from_goal <= 0.27450461081080996 AND 21.494334137162753 <= play_distance <= 113.15070408910965 AND total_time_per_play <= 0.9302880000000187
# shot_angle_from_goal <= 0.27450461081080996 AND 27.200000000000003 <= start_y <= 34.0 AND play_speed >= 8.971750141469606
# bodypart_name = head/other AND 91.35 <= start_x <= 94.5 AND shot_angle_from_goal <= 0.3587982134468684
# shot_distance_from_goal >= 24.89650778723795 AND 4.641377505446126 <= play_speed <= 6.864853427180291 AND total_time_per_play <= 0.9302880000000187
# shot_angle_from_goal <= 0.27450461081080996 AND 34.68 <= start_y <= 40.8 AND player_rank <= 0.004430909090909091
# player_rank <= 0.004430909090909091 AND 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND bodypart_name = head/other
# shot_distance_from_goal >= 24.89650778723795 AND play_speed >= 8.971750141469606 AND 2.0 <= num_passes <= 3.0
# play_mean_distance_to_the_goal <= 12.36283043185764 AND num_passes >= 2.0
# shot_distance_from_goal >= 17.1236941107928 AND play_speed_towards_goal <= -0.015112411731641373 AND num_events >= 7.0
# shot_distance_from_goal >= 24.89650778723795 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004 AND play_std_distance_to_the_goal >= 15.352753779569
# shot_distance_from_goal >= 24.89650778723795 AND play_std_distance_to_the_goal >= 15.352753779569 AND play_mean_distance_to_the_goal <= 41.36396470801768
# 0.2746029401357196 <= shot_angle_from_goal <= 0.3587982134468684 AND play_distance <= 21.49433413716275 AND total_time_per_play >= 2.404795999999957
# shot_distance_from_goal >= 24.89650778723795 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND play_speed <= 4.641349632294605
# shot_angle_from_goal <= 0.27450461081080996 AND player_rank <= 0.004430909090909091 AND shot_distance_from_goal <= 12.239999999999995
# shot_angle_from_goal <= 0.27450461081080996 AND total_time_per_play <= 0.9302880000000187 AND 0.234646057969521 <= ratio_distance <= 0.5339473149855147
# play_distance <= 51.76966761281916 AND num_events >= 7.0
# shot_distance_from_goal >= 24.89650778723795 AND num_dribbles >= 1.0 AND play_distance <= 21.49433413716275
# 0.2746029401357196 <= shot_angle_from_goal <= 0.3587982134468684 AND play_distance <= 21.49433413716275 AND num_dribbles >= 1.0
# shot_distance_from_goal >= 17.1236941107928 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND bodypart_name = head/other
# shot_angle_from_goal <= 0.27450461081080996 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND bodypart_name = head/other
# shot_angle_from_goal <= 0.27450461081080996 AND bodypart_name = foot_right AND 34.68 <= start_y <= 40.8
# shot_angle_from_goal >= 0.5591113717173855 AND 0.004435614702154626 <= player_rank <= 0.016036157894736842 AND start_y >= 41.48
# shot_angle_from_goal <= 0.27450461081080996 AND play_speed <= 4.641349632294605 AND play_speed_towards_goal >= 3.856313999035368
# 27.200000000000003 <= start_y <= 40.8 AND 0.234646057969521 <= ratio_distance <= 0.5339473149855147 AND shot_distance_from_goal >= 24.89650778723795
# shot_distance_from_goal >= 24.89650778723795 AND 0.0 <= play_speed_towards_goal <= 1.5145461337964412 AND ratio_distance >= 0.5339754270167693
# start_x <= 81.9 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND num_events <= 1.0
# start_x <= 81.9 AND total_time_per_play <= 1.7631443333333057 AND play_distance_towards_goal >= 46.2
# start_x >= 95.55 AND 27.200000000000003 <= start_y <= 40.8 AND bodypart_name = foot_right
# start_x <= 81.9 AND play_distance <= 21.49433413716275 AND total_time_per_play >= 2.404795999999957
# 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND start_y >= 41.48 AND start_x <= 81.9
# shot_distance_from_goal >= 17.1236941107928 AND play_speed_towards_goal <= -0.015112411731641373 AND start_x >= 95.55
# start_y <= 27.2 AND play_distance_towards_goal <= -1.0499999999999972 AND play_std_distance_to_the_goal >= 15.352753779569
# shot_angle_from_goal <= 0.3587982134468684 AND num_events <= 1.0 AND bodypart_name = head/other
# shot_distance_from_goal <= 12.239999999999995 AND play_distance <= 21.49433413716275 AND total_time_per_play >= 1.763152249999962
# shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND play_mean_distance_to_the_goal <= 28.086885352488757
# shot_angle_from_goal >= 0.5591113717173855 AND play_mean_distance_to_the_goal >= 41.36508436005718 AND play_distance_towards_goal <= -1.0499999999999972
# start_x <= 81.9 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND play_mean_distance_to_the_goal <= 28.086885352488757
# shot_distance_from_goal >= 24.89650778723795 AND 21.494334137162753 <= play_distance <= 51.76966761281916 AND play_duration >= 16.32346000000007
# 82.95 <= start_x <= 90.3 AND 0.2746029401357196 <= shot_angle_from_goal <= 0.3587982134468684 AND bodypart_name = head/other
# shot_distance_from_goal >= 24.89650778723795 AND 2.0 <= num_events <= 3.0 AND play_duration >= 16.32346000000007
# shot_distance_from_goal >= 24.89650778723795 AND 4.641377505446126 <= play_speed <= 6.864853427180291 AND play_duration <= 2.076061999999638
# start_x <= 81.9 AND play_distance <= 21.49433413716275 AND num_events >= 4.0
# start_x <= 81.9 AND total_time_per_play <= 0.9302880000000187 AND num_passes >= 2.0
# start_x <= 81.9 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND play_distance <= 21.49433413716275
# shot_angle_from_goal <= 0.27450461081080996 AND play_speed_towards_goal >= 3.856313999035368 AND 34.68 <= start_y <= 40.8
# shot_distance_from_goal >= 24.89650778723795 AND 21.494334137162753 <= play_distance <= 51.76966761281916 AND play_duration <= 2.076061999999638
# start_x <= 81.9 AND total_time_per_play <= 1.7631443333333057 AND play_std_distance_to_the_goal >= 15.352753779569
# shot_distance_from_goal >= 24.89650778723795 AND play_duration >= 16.32346000000007 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004
# shot_distance_from_goal >= 24.89650778723795 AND 12.389116336130769 <= play_mean_distance_to_the_goal <= 28.086885352488757 AND play_distance >= 113.16162197606944
# start_x <= 81.9 AND play_duration <= 2.076061999999638 AND play_mean_distance_to_the_goal >= 41.36508436005718

# %%
sorted_df
# Out:
#                                             Subgrupros  usage      mean  \
# 141  0.3587982134468687 <= shot_angle_from_goal <= ...   1110  0.174933
# 142  shot_distance_from_goal >= 12.24944488538154 A...   1535  0.100125
# 32   shot_angle_from_goal >= 0.5591113717173855 AND...   1541  0.373655
# 131  shot_angle_from_goal >= 0.5591113717173855 AND...   1200  0.185037
# 117  shot_distance_from_goal <= 17.09952046111235 A...   1194  0.196700
# ..                                                 ...    ...       ...
# 6    shot_distance_from_goal >= 24.89650778723795 A...     15  0.013311
# 69   start_x <= 81.9 AND total_time_per_play <= 1.7...      8  0.016429
# 47   shot_distance_from_goal >= 24.89650778723795 A...     11  0.012700
# 19   shot_distance_from_goal >= 24.89650778723795 A...     12  0.013705
# 34   start_x <= 81.9 AND play_duration <= 2.0760619...      8  0.012566
#
#         mean2     variance2      RSS2  variance  RSS_default_pattern  \
# 141  0.074366  8.518305e-05  0.005345  0.114926           130.317752
# 142  0.080905  2.598926e-05  0.003982  0.065588           101.638801
# 32   0.103559  1.761895e-05  0.000975  0.204126           408.788127
# 131  0.078270  4.799500e-06  0.004420  0.120118           148.332292
# 117  0.083260  7.539112e-05  0.003674  0.128163           159.138781
# ..        ...           ...       ...       ...                  ...
# 6    0.018049  4.321264e-06  0.022984  0.000018             0.187000
# 69   0.019142  1.058677e-05  0.022531  0.000015             0.093656
# 47   0.015356  8.778807e-07  0.024147  0.000008             0.138696
# 19   0.022982  1.582401e-04  0.021226  0.000120             0.142968
# 34   0.014121  1.834725e-06  0.024694  0.000003             0.101220
#
#      usage_default  RSS_default_uncovered     WRAcc
# 141           9209             754.111331  0.019380
# 142           7674             652.453762  0.017378
# 32           32981            2454.022978  0.016879
# 131          12564            1051.198919  0.016545
# 117          15891            1397.681071  0.014027
# ..             ...                    ...       ...
# 6            40407            3488.324367  0.000005
# 69           27178            2318.036788  0.000005
# 47           30282            2395.560162  0.000005
# 19           38091            3317.412080  0.000004
# 34           32661            2447.206991  0.000003
#
# [143 rows x 11 columns]

# %%
print(model) # returns the list of if-then-else if rules/subgroups with their respective antecedent description and consequent statistics
# Out:
# IF x in shot_distance_from_goal >= 24.89650778723795 AND 21.494334137162753 <= play_distance <= 51.76966761281916 AND total_time_per_play <= 0.9302880000000187 THEN mean = 0.01495601904578507; std = 0.005268209066171192 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 4.641377505446126 <= play_speed <= 6.864853427180291 AND total_time_per_play <= 0.9302880000000187 THEN mean = 0.014970493383353224; std = 0.005117488021428324 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND 27.200000000000003 <= start_y <= 34.0 AND play_speed >= 8.971750141469606 THEN mean = 0.013576278128825567; std = 0.0067685245227837275 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND num_dribbles >= 1.0 AND play_distance <= 21.49433413716275 THEN mean = 0.016209051847302664; std = 0.00797320320355895 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 21.494334137162753 <= play_distance <= 51.76966761281916 AND play_duration >= 16.32346000000007 THEN mean = 0.014927467296796816; std = 0.004937433473812363 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND play_mean_distance_to_the_goal <= 28.086885352488757 THEN mean = 0.01543501816276047; std = 0.008059175983476205 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 21.494334137162753 <= play_distance <= 51.76966761281916 AND play_duration <= 2.076061999999638 THEN mean = 0.013311289312938849; std = 0.004194866668317766 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 4.641377505446126 <= play_speed <= 6.864853427180291 AND play_duration <= 2.076061999999638 THEN mean = 0.01654031313955784; std = 0.00802682724739517 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 21.494334137162753 <= play_distance <= 51.76966761281916 AND 7.196612429896831 <= play_std_distance_to_the_goal <= 15.350719150153845 THEN mean = 0.01742830540242062; std = 0.053389611042515814 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004 AND play_std_distance_to_the_goal >= 15.352753779569 THEN mean = 0.013435998886254512; std = 0.004292380872023567 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 0.0 <= play_speed_towards_goal <= 1.5145461337964412 AND ratio_distance >= 0.5339754270167693 THEN mean = 0.015077695638562242; std = 0.0058181346443416 ,
# ELSE IF x in 27.200000000000003 <= start_y <= 34.0 AND shot_angle_from_goal <= 0.27450461081080996 AND play_speed <= 4.641349632294605 THEN mean = 0.015785051550779302; std = 0.05600686277598148 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004 THEN mean = 0.018416257881114204; std = 0.06512933838990649 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 82.95 <= start_x <= 90.3 AND 2.0 <= num_passes <= 3.0 THEN mean = 0.02123318532582264; std = 0.0621465445059775 ,
# ELSE IF x in shot_distance_from_goal <= 12.239999999999995 AND play_distance <= 21.49433413716275 AND total_time_per_play >= 1.763152249999962 THEN mean = 0.036661400544372474; std = 0.00783382200897693 ,
# ELSE IF x in 34.68 <= start_y <= 40.8 AND start_x >= 95.55 AND num_events <= 1.0 THEN mean = 0.4584578944601908; std = 0.4696280074172624 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND play_speed >= 8.971750141469606 AND 0.234646057969521 <= ratio_distance <= 0.5339473149855147 THEN mean = 0.01577526398049378; std = 0.011279038002664535 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND play_mean_distance_to_the_goal <= 12.36283043185764 AND play_speed >= 4.641377505446126 THEN mean = 0.03363320965852056; std = 0.007613236723419913 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND num_events <= 1.0 AND 82.95 <= start_x <= 90.3 THEN mean = 0.024105724377431356; std = 0.06292928710384893 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 12.389116336130769 <= play_mean_distance_to_the_goal <= 28.086885352488757 AND play_distance >= 113.16162197606944 THEN mean = 0.013704650880148014; std = 0.010957484895431129 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND 0.01028948787061995 <= player_rank <= 0.016036157894736842 THEN mean = 0.021065861954989416; std = 0.0793261388877831 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 2.0 <= num_events <= 3.0 AND play_duration >= 16.32346000000007 THEN mean = 0.014141631844852651; std = 0.005529153207485406 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173855 AND num_events <= 1.0 AND start_x >= 95.55 THEN mean = 0.42556475839305635; std = 0.46367088818241453 ,
# ELSE IF x in start_x <= 81.9 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND play_distance <= 21.49433413716275 THEN mean = 0.01300015066517517; std = 0.00532401958435186 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 12.389116336130769 <= play_mean_distance_to_the_goal <= 28.086885352488757 AND 0.0 <= play_speed_towards_goal <= 1.5145461337964412 THEN mean = 0.02202073046211879; std = 0.07741310329688778 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173855 AND bodypart_name = foot_left AND start_x >= 95.55 THEN mean = 0.3965820420119071; std = 0.4582220687745163 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND player_rank <= 0.004430909090909091 AND bodypart_name = foot_left THEN mean = 0.029137022453118357; std = 0.10218080355819185 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND play_mean_distance_to_the_goal <= 28.086885352488757 THEN mean = 0.014438903904952033; std = 0.005312294871091098 ,
# ELSE IF x in play_speed <= 4.641349632294605 AND start_x <= 81.9 AND num_events >= 7.0 THEN mean = 0.015010467001063897; std = 0.0054946789847282905 ,
# ELSE IF x in start_x <= 81.9 AND play_distance <= 21.49433413716275 AND total_time_per_play >= 2.404795999999957 THEN mean = 0.01314431585131153; std = 0.004859535291939099 ,
# ELSE IF x in start_x <= 81.9 AND play_distance <= 21.49433413716275 AND num_events >= 4.0 THEN mean = 0.015488499833736569; std = 0.0053273985024778914 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND bodypart_name = head/other THEN mean = 0.028103122576361612; std = 0.008027717540993518 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173855 AND bodypart_name = foot_right AND start_x >= 95.55 THEN mean = 0.37365530578251555; std = 0.45180277467730884 ,
# ELSE IF x in start_x <= 81.9 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND play_distance <= 51.76966761281916 THEN mean = 0.026305688290635888; std = 0.10833252485107503 ,
# ELSE IF x in start_x <= 81.9 AND play_duration <= 2.076061999999638 AND play_mean_distance_to_the_goal >= 41.36508436005718 THEN mean = 0.012566324905492365; std = 0.0018614376413101767 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND play_mean_distance_to_the_goal <= 28.086885352488757 THEN mean = 0.029755661876877414; std = 0.11900306552493375 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND play_std_distance_to_the_goal >= 15.352753779569 AND total_time_per_play <= 1.7631443333333057 THEN mean = 0.015201755651991956; std = 0.0052874613400373475 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND ratio_distance >= 0.5339754270167693 THEN mean = 0.016930416199313694; std = 0.011323268772431184 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 4.641377505446126 <= play_speed <= 6.864853427180291 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004 THEN mean = 0.027610904184183566; std = 0.1148646033541137 ,
# ELSE IF x in play_distance_towards_goal <= -1.0499999999999972 AND 28.095041593726133 <= play_mean_distance_to_the_goal <= 41.36396470801768 AND shot_angle_from_goal >= 0.3587982134468687 THEN mean = 0.027948838123811943; std = 0.009731887197484957 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND player_rank <= 0.004430909090909091 AND shot_distance_from_goal <= 12.239999999999995 THEN mean = 0.03229140667688279; std = 0.008265946862581343 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 4.641377505446126 <= play_speed <= 6.864853427180291 AND play_mean_distance_to_the_goal <= 28.086885352488757 THEN mean = 0.03388563099137524; std = 0.022800833094235345 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND player_rank <= 0.004430909090909091 AND 12.389116336130769 <= play_mean_distance_to_the_goal <= 28.086885352488757 THEN mean = 0.02818166451175618; std = 0.10930747576070986 ,
# ELSE IF x in start_x <= 81.9 AND total_time_per_play <= 0.9302880000000187 AND num_passes >= 2.0 THEN mean = 0.01567000170637454; std = 0.0037451182500047153 ,
# ELSE IF x in start_x <= 81.9 AND play_mean_distance_to_the_goal <= 12.36283043185764 AND player_rank <= 0.004430909090909091 THEN mean = 0.032836712013017764; std = 0.13157870085671955 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND 34.68 <= start_y <= 40.8 AND player_rank <= 0.004430909090909091 THEN mean = 0.011653675502031178; std = 0.004086212602334912 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND play_std_distance_to_the_goal >= 15.352753779569 AND play_mean_distance_to_the_goal <= 41.36396470801768 THEN mean = 0.015628240526550347; std = 0.005586850768432972 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND play_duration >= 16.32346000000007 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004 THEN mean = 0.01269971892576326; std = 0.0027901018840953036 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND play_std_distance_to_the_goal >= 15.352753779569 AND 2.0 <= num_passes <= 3.0 THEN mean = 0.028382424881324322; std = 0.11739190628446951 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND play_speed <= 4.641349632294605 AND play_speed_towards_goal >= 3.856313999035368 THEN mean = 0.02251577404835685; std = 0.011324080448652641 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND 1.5151898195672555 <= play_speed_towards_goal <= 3.8559805229649715 THEN mean = 0.032914166413338004; std = 0.1327705152146731 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND play_speed <= 4.641349632294605 THEN mean = 0.012639864201785303; std = 0.005773477010628762 ,
# ELSE IF x in play_speed_towards_goal <= -0.015112411731641373 AND 28.095041593726133 <= play_mean_distance_to_the_goal <= 41.36396470801768 AND play_distance >= 113.16162197606944 THEN mean = 0.01928442198827508; std = 0.010471310326433392 ,
# ELSE IF x in shot_angle_from_goal <= 0.3587982134468684 AND play_mean_distance_to_the_goal <= 12.36283043185764 AND play_duration >= 2.0765519999999924 THEN mean = 0.03287192439716874; std = 0.008440608412585428 ,
# ELSE IF x in play_speed <= 4.641349632294605 AND shot_angle_from_goal <= 0.27450461081080996 AND 7.196612429896831 <= play_std_distance_to_the_goal <= 15.350719150153845 THEN mean = 0.03174332438134833; std = 0.09727165002506898 ,
# ELSE IF x in shot_angle_from_goal <= 0.3587982134468684 AND num_events <= 1.0 AND bodypart_name = head/other THEN mean = 0.02834009446881034; std = 0.006815834900765112 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND num_events >= 7.0 AND play_distance <= 113.15070408910965 THEN mean = 0.028657124756813743; std = 0.11867295805383561 ,
# ELSE IF x in 82.95 <= start_x <= 90.3 AND 0.2746029401357196 <= shot_angle_from_goal <= 0.3587982134468684 AND bodypart_name = head/other THEN mean = 0.021342321468347854; std = 0.004107086352171396 ,
# ELSE IF x in player_rank <= 0.004430909090909091 AND shot_distance_from_goal >= 24.89650778723795 AND 0.234646057969521 <= ratio_distance <= 0.5339473149855147 THEN mean = 0.0339019564743459; std = 0.13817666090409567 ,
# ELSE IF x in play_speed_towards_goal <= -0.015112411731641373 AND 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND 6.864962518632317 <= play_speed <= 8.97107615188608 THEN mean = 0.041951571699177875; std = 0.13171556298715478 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND total_time_per_play <= 0.9302880000000187 AND 0.234646057969521 <= ratio_distance <= 0.5339473149855147 THEN mean = 0.03585375810507685; std = 0.018798871361994044 ,
# ELSE IF x in num_events <= 1.0 AND 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND bodypart_name = foot_right THEN mean = 0.051726589715257884; std = 0.16111841182328057 ,
# ELSE IF x in start_x <= 81.9 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND num_events <= 1.0 THEN mean = 0.015029338593392269; std = 0.0033202526827769514 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND ratio_distance <= 0.23457108157942888 AND play_distance_towards_goal >= 46.2 THEN mean = 0.028358314419165254; std = 0.11644049618906309 ,
# ELSE IF x in start_x <= 81.9 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND play_mean_distance_to_the_goal <= 28.086885352488757 THEN mean = 0.014540153996724831; std = 0.0037915971262217937 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND 21.494334137162753 <= play_distance <= 51.76966761281916 AND total_time_per_play >= 2.404795999999957 THEN mean = 0.019309222436277196; std = 0.011303961231688161 ,
# ELSE IF x in start_x <= 81.9 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND 1.763152249999962 <= total_time_per_play <= 2.4047902592592605 THEN mean = 0.03811932115453144; std = 0.14900917653009313 ,
# ELSE IF x in start_x <= 81.9 AND total_time_per_play <= 1.7631443333333057 AND play_distance_towards_goal >= 46.2 THEN mean = 0.013037997931241989; std = 0.003833566341436985 ,
# ELSE IF x in 82.95 <= start_x <= 90.3 AND bodypart_name = head/other AND 2.0765519999999924 <= play_duration <= 16.322411999999986 THEN mean = 0.0214113337493947; std = 0.004808008917048108 ,
# ELSE IF x in start_x <= 81.9 AND total_time_per_play <= 1.7631443333333057 AND play_std_distance_to_the_goal >= 15.352753779569 THEN mean = 0.01642875769175589; std = 0.0038355493120539154 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND play_distance_towards_goal <= 46.199999999999996 AND play_std_distance_to_the_goal >= 15.352753779569 THEN mean = 0.04672138610294496; std = 0.1561883563489551 ,
# ELSE IF x in start_y <= 27.2 AND play_distance_towards_goal <= -1.0499999999999972 AND play_std_distance_to_the_goal >= 15.352753779569 THEN mean = 0.023344518473515145; std = 0.011398994769641596 ,
# ELSE IF x in start_y <= 27.2 AND play_distance_towards_goal <= -1.0499999999999972 AND play_speed <= 4.641349632294605 THEN mean = 0.0319500181870535; std = 0.09507886788880993 ,
# ELSE IF x in shot_distance_from_goal >= 24.89650778723795 AND play_speed >= 8.971750141469606 AND 2.0 <= num_passes <= 3.0 THEN mean = 0.013715830013840174; std = 0.006662056527321839 ,
# ELSE IF x in start_x <= 81.9 AND play_distance <= 21.49433413716275 AND play_speed >= 8.971750141469606 THEN mean = 0.026845859314369804; std = 0.10460475828601834 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173855 AND play_std_distance_to_the_goal >= 15.352753779569 AND total_time_per_play <= 1.7631443333333057 THEN mean = 0.3111154096806125; std = 0.42447921741103717 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173855 AND play_mean_distance_to_the_goal >= 41.36508436005718 AND play_distance_towards_goal <= -1.0499999999999972 THEN mean = 0.030015491570035618; std = 0.010310649062742684 ,
# ELSE IF x in 82.95 <= start_x <= 90.3 AND 0.2746029401357196 <= shot_angle_from_goal <= 0.3587982134468684 AND num_events >= 7.0 THEN mean = 0.0544440814124876; std = 0.17577589152052941 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND num_events <= 1.0 AND start_y <= 40.8 THEN mean = 0.04740673249730174; std = 0.16192642025432666 ,
# ELSE IF x in shot_distance_from_goal >= 17.1236941107928 AND ratio_distance <= -0.002088480953773431 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 THEN mean = 0.04958232993966331; std = 0.16391692138028063 ,
# ELSE IF x in bodypart_name = head/other AND shot_distance_from_goal >= 12.24944488538154 AND num_events <= 1.0 THEN mean = 0.0635466883280154; std = 0.032970941492793115 ,
# ELSE IF x in bodypart_name = head/other AND 12.24944488538154 <= shot_distance_from_goal <= 17.09952046111235 AND player_rank <= 0.004430909090909091 THEN mean = 0.046278923171436996; std = 0.12509066831134846 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173855 AND 0.0 <= ratio_distance <= 0.23457108157942888 AND play_mean_distance_to_the_goal >= 41.36508436005718 THEN mean = 0.26589358279367736; std = 0.40908257697203776 ,
# ELSE IF x in bodypart_name = head/other AND 12.24944488538154 <= shot_distance_from_goal <= 17.09952046111235 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004 THEN mean = 0.05479209088937827; std = 0.15219253740932934 ,
# ELSE IF x in shot_distance_from_goal <= 12.239999999999995 AND player_rank >= 0.01604481397970688 AND 0.0 <= play_distance_towards_goal <= 16.800000000000004 THEN mean = 0.25932969888333096; std = 0.40063284968780916 ,
# ELSE IF x in start_x <= 81.9 AND 27.200000000000003 <= start_y <= 34.0 AND play_speed >= 8.971750141469606 THEN mean = 0.015718394263901495; std = 0.0049487053857578496 ,
# ELSE IF x in start_x >= 95.55 AND 27.200000000000003 <= start_y <= 40.8 AND bodypart_name = foot_right THEN mean = 0.031287262216210365; std = 0.006702203873182756 ,
# ELSE IF x in start_x <= 81.9 AND 0.0 <= play_speed_towards_goal <= 1.5145461337964412 AND start_y >= 41.48 THEN mean = 0.04534499353112679; std = 0.16848508510083934 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 AND play_mean_distance_to_the_goal >= 41.36508436005718 THEN mean = 0.050502691286426316; std = 0.1569436794144608 ,
# ELSE IF x in 0.2746029401357196 <= shot_angle_from_goal <= 0.3587982134468684 AND play_distance <= 21.49433413716275 AND total_time_per_play >= 2.404795999999957 THEN mean = 0.02070756450295448; std = 0.007938528856655028 ,
# ELSE IF x in start_x >= 95.55 AND 34.68 <= start_y <= 40.8 AND player_rank >= 0.01604481397970688 THEN mean = 0.27475210988645304; std = 0.4107961538689875 ,
# ELSE IF x in 0.2746029401357196 <= shot_angle_from_goal <= 0.3587982134468684 AND play_distance <= 21.49433413716275 AND num_dribbles >= 1.0 THEN mean = 0.02434165185938279; std = 0.010419807000254815 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND 2.0765519999999924 <= play_duration <= 6.9251429999999345 AND 1.5151898195672555 <= play_speed_towards_goal <= 3.8559805229649715 THEN mean = 0.047241046521553975; std = 0.15765467750449488 ,
# ELSE IF x in start_x <= 81.9 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND play_std_distance_to_the_goal >= 15.352753779569 THEN mean = 0.040543654925745576; std = 0.15064345732430698 ,
# ELSE IF x in 0.2746029401357196 <= shot_angle_from_goal <= 0.3587982134468684 AND play_duration <= 2.076061999999638 AND 6.864962518632317 <= play_speed <= 8.97107615188608 THEN mean = 0.025615838604668775; std = 0.01170139200853678 ,
# ELSE IF x in shot_distance_from_goal <= 12.239999999999995 AND bodypart_name = foot_right AND 27.200000000000003 <= start_y <= 34.0 THEN mean = 0.25964546229154567; std = 0.3999912828795404 ,
# ELSE IF x in 0.2746029401357196 <= shot_angle_from_goal <= 0.3587982134468684 AND play_mean_distance_to_the_goal <= 12.36283043185764 AND player_rank >= 0.01604481397970688 THEN mean = 0.05480581960192758; std = 0.1712088676075128 ,
# ELSE IF x in play_mean_distance_to_the_goal <= 12.36283043185764 AND num_passes >= 2.0 THEN mean = 0.03663117202619712; std = 0.008647269879330635 ,
# ELSE IF x in shot_angle_from_goal <= 0.3587982134468684 AND 82.95 <= start_x <= 90.3 AND play_speed <= 4.641349632294605 THEN mean = 0.06074401375254845; std = 0.1881509842841345 ,
# ELSE IF x in player_rank <= 0.004430909090909091 AND 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND bodypart_name = head/other THEN mean = 0.026837870478630066; std = 0.005443962224632856 ,
# ELSE IF x in shot_distance_from_goal >= 17.1236941107928 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND bodypart_name = head/other THEN mean = 0.030217169497448664; std = 0.006524064522404002 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173855 AND bodypart_name = foot_left AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 THEN mean = 0.26173701582841535; std = 0.4021622682774213 ,
# ELSE IF x in shot_distance_from_goal >= 17.1236941107928 AND play_speed_towards_goal <= -0.015112411731641373 AND start_x >= 95.55 THEN mean = 0.027056042104959488; std = 0.009456372174454532 ,
# ELSE IF x in shot_distance_from_goal <= 12.239999999999995 AND total_time_per_play <= 0.9302880000000187 AND 0.01028948787061995 <= player_rank <= 0.016036157894736842 THEN mean = 0.2342042827212825; std = 0.385903602845205 ,
# ELSE IF x in 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND num_dribbles >= 1.0 AND total_time_per_play <= 0.9302880000000187 THEN mean = 0.02584324050694704; std = 0.008041920753321994 ,
# ELSE IF x in shot_distance_from_goal >= 17.1236941107928 AND 7.196612429896831 <= play_std_distance_to_the_goal <= 15.350719150153845 AND play_mean_distance_to_the_goal <= 28.086885352488757 THEN mean = 0.049710521866262965; std = 0.14597446614194937 ,
# ELSE IF x in 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND num_dribbles >= 1.0 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 THEN mean = 0.06699520205759457; std = 0.19731721075980257 ,
# ELSE IF x in 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND 6.92674500000021 <= play_duration <= 16.322411999999986 AND play_distance >= 113.16162197606944 THEN mean = 0.05601988786899407; std = 0.1659671469507413 ,
# ELSE IF x in 12.24944488538154 <= shot_distance_from_goal <= 17.09952046111235 AND bodypart_name = head/other AND start_y >= 27.200000000000003 THEN mean = 0.07989782476996796; std = 0.21081124505781654 ,
# ELSE IF x in play_speed_towards_goal >= 3.856313999035368 AND 27.200000000000003 <= start_y <= 34.0 AND 12.24944488538154 <= shot_distance_from_goal <= 17.09952046111235 THEN mean = 0.22733591477358675; std = 0.3837054275624164 ,
# ELSE IF x in bodypart_name = head/other AND 82.95 <= start_x <= 94.5 AND 0.004435614702154626 <= player_rank <= 0.010288819875776397 THEN mean = 0.06065184035004224; std = 0.16568812227612453 ,
# ELSE IF x in shot_distance_from_goal <= 12.239999999999995 AND play_std_distance_to_the_goal >= 15.352753779569 AND total_time_per_play <= 2.4047902592592605 THEN mean = 0.22291664032869646; std = 0.3776676127492039 ,
# ELSE IF x in total_time_per_play <= 1.7631443333333057 AND shot_angle_from_goal >= 0.5591113717173855 AND start_y <= 27.2 THEN mean = 0.0311959034556316; std = 0.005659421240759175 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND 21.494334137162753 <= play_distance <= 113.15070408910965 AND total_time_per_play <= 0.9302880000000187 THEN mean = 0.03117413818836212; std = 0.009468715154727126 ,
# ELSE IF x in start_x <= 81.9 AND 4.641377505446126 <= play_speed <= 6.864853427180291 AND num_passes >= 4.0 THEN mean = 0.06054282959435234; std = 0.19771418649700118 ,
# ELSE IF x in shot_distance_from_goal >= 17.1236941107928 AND play_speed_towards_goal <= -0.015112411731641373 AND num_events >= 7.0 THEN mean = 0.01792121589339028; std = 0.008080654317926988 ,
# ELSE IF x in 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND player_rank <= 0.004430909090909091 AND 12.389116336130769 <= play_mean_distance_to_the_goal <= 28.086885352488757 THEN mean = 0.07173776962751582; std = 0.21102423178887178 ,
# ELSE IF x in shot_distance_from_goal <= 17.09952046111235 AND player_rank >= 0.01604481397970688 AND num_dribbles >= 1.0 THEN mean = 0.19669959137927573; std = 0.3579986369002909 ,
# ELSE IF x in bodypart_name = head/other AND 91.35 <= start_x <= 94.5 AND shot_angle_from_goal <= 0.3587982134468684 THEN mean = 0.02931423665334781; std = 0.009444157840595645 ,
# ELSE IF x in bodypart_name = head/other AND 91.35 <= start_x <= 94.5 AND num_passes >= 2.0 THEN mean = 0.044803532634806985; std = 0.11408111166300663 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND play_speed_towards_goal >= 3.856313999035368 AND 34.68 <= start_y <= 40.8 THEN mean = 0.011895413335878402; std = 0.00279821558588678 ,
# ELSE IF x in shot_distance_from_goal <= 12.239999999999995 AND 0.01028948787061995 <= player_rank <= 0.016036157894736842 AND play_distance <= 21.49433413716275 THEN mean = 0.0395304705016315; std = 0.009827803030209603 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND bodypart_name = foot_right AND 21.494334137162753 <= play_distance <= 51.76966761281916 THEN mean = 0.05817960717007652; std = 0.1863852813059264 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173855 AND play_speed_towards_goal >= 1.5151898195672555 AND 12.389116336130769 <= play_mean_distance_to_the_goal <= 28.086885352488757 THEN mean = 0.2086638791917138; std = 0.36920583598299594 ,
# ELSE IF x in 17.1236941107928 <= shot_distance_from_goal <= 24.886333598985605 AND start_y >= 41.48 AND start_x <= 81.9 THEN mean = 0.015534265898168087; std = 0.003927053847534945 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173855 AND 0.004435614702154626 <= player_rank <= 0.016036157894736842 AND start_y >= 41.48 THEN mean = 0.027709576818678115; std = 0.0037185653184548025 ,
# ELSE IF x in start_x <= 90.3 AND 51.77083735077114 <= play_distance <= 113.15070408910965 AND 0.234646057969521 <= ratio_distance <= 0.5339473149855147 THEN mean = 0.07173191269066974; std = 0.21304586009032037 ,
# ELSE IF x in 27.200000000000003 <= start_y <= 40.8 AND 0.234646057969521 <= ratio_distance <= 0.5339473149855147 AND shot_distance_from_goal >= 24.89650778723795 THEN mean = 0.013888018589247675; std = 0.0038357657966749453 ,
# ELSE IF x in start_x >= 91.35 AND 27.200000000000003 <= start_y <= 40.8 AND play_std_distance_to_the_goal >= 15.352753779569 THEN mean = 0.20188956322035276; std = 0.36172340361487376 ,
# ELSE IF x in total_time_per_play <= 1.7631443333333057 AND shot_distance_from_goal <= 12.239999999999995 AND play_distance_towards_goal >= 46.2 THEN mean = 0.032780690118670464; std = 0.0075399411895786675 ,
# ELSE IF x in play_distance <= 51.76966761281916 AND num_events >= 7.0 THEN mean = 0.034014560864306986; std = 0.00901676868604041 ,
# ELSE IF x in shot_angle_from_goal >= 0.5591113717173855 AND total_time_per_play <= 1.7631443333333057 AND 0.004435614702154626 <= player_rank <= 0.016036157894736842 THEN mean = 0.18503684950216362; std = 0.3465800981908186 ,
# ELSE IF x in shot_angle_from_goal <= 0.3587982134468684 AND player_rank <= 0.010288819875776397 AND bodypart_name = head/other THEN mean = 0.028848128570687203; std = 0.006912458496172185 ,
# ELSE IF x in shot_distance_from_goal >= 17.1236941107928 AND play_duration >= 6.92674500000021 AND num_events <= 3.0 THEN mean = 0.06147702981029205; std = 0.19238970110203507 ,
# ELSE IF x in ratio_distance <= -0.002088480953773431 AND 1.763152249999962 <= total_time_per_play <= 2.4047902592592605 AND play_speed <= 4.641349632294605 THEN mean = 0.026210430456558242; std = 0.019770971567378247 ,
# ELSE IF x in 0.3587982134468687 <= shot_angle_from_goal <= 0.5565136053620864 AND player_rank >= 0.01604481397970688 AND play_std_distance_to_the_goal <= 7.195667700015349 THEN mean = 0.19398324440956394; std = 0.35735315576663923 ,
# ELSE IF x in 82.95 <= start_x <= 90.3 AND start_y >= 41.48 AND 21.494334137162753 <= play_distance <= 51.76966761281916 THEN mean = 0.05087355828627643; std = 0.1638491868560512 ,
# ELSE IF x in ratio_distance <= 0.23457108157942888 AND 2.0 <= num_events <= 3.0 AND 6.92674500000021 <= play_duration <= 16.322411999999986 THEN mean = 0.02967540002255528; std = 0.005829170022365099 ,
# ELSE IF x in ratio_distance <= 0.23457108157942888 AND 2.0765519999999924 <= play_duration <= 6.9251429999999345 AND 82.95 <= start_x <= 94.5 THEN mean = 0.08515064907607747; std = 0.22540273915018033 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND bodypart_name = foot_right AND 34.68 <= start_y <= 40.8 THEN mean = 0.01278331403487495; std = 0.004894204715608169 ,
# ELSE IF x in shot_angle_from_goal <= 0.27450461081080996 AND total_time_per_play >= 1.763152249999962 AND play_speed_towards_goal >= 3.856313999035368 THEN mean = 0.07735753827465246; std = 0.21480949926444046 ,
# ELSE IF x in 0.3587982134468687 <= shot_angle_from_goal <= 0.5565136053620864 AND 0.01028948787061995 <= player_rank <= 0.016036157894736842 AND start_x >= 91.35 THEN mean = 0.17493295047541257; std = 0.33900679185569443 ,
# ELSE IF x in shot_distance_from_goal >= 12.24944488538154 AND ratio_distance <= 0.23457108157942888 AND start_y <= 34.0 THEN mean = 0.10012538459194455; std = 0.2561015312033253 ,
# ELSE mean = 0.12523086std  = 0.29265454291290316

# %%
model.measures # returns a dictionary of subgroup discovery measure results for the rule list and subgroups
# Out:
# {'avg_supp': 562.993006993007,
#  'kl_supp': 1.6390851829561517,
#  'wkl_supp': 402.2477673171634,
#  'avg_usg': 231.53146853146853,
#  'kl_usg': 2.7814217744271406,
#  'wkl_usg': 195.84574290760034,
#  'wacc_supp': 65.55431005961451,
#  'wacc_usg': 23.198445390517517,
#  'jacc_avg': 0.00727756738351278,
#  'n_rules': 143,
#  'avg_items': 2.986013986013986,
#  'wkl_sum': 28005.941235786864,
#  'std_rules': 0.10786167430611895,
#  'top1_std': 0.005268209066171192,
#  'length_orig': 11189.475277420263,
#  'length_final': -11136.88223119207,
#  'length_ratio': -0.9952997754654035,
#  'runtime': 1296.4728603363037}
